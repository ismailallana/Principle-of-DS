# %% [markdown]
# # Data mining

# %% [markdown]
# ## EXERCISE: Association analysis from scratch
#
# [Adapted from http://aimotion.blogspot.com.au/2013/01/machine-learning-and-data-mining.html.]
#
# [For more on efficient approaches, see http://www-users.cs.umn.edu/~kumar/dmbook/ch6.pdf.]
#
# Refer to slides for definitions (itemset, support, frequent itemset, confidence, etc).

# %% [markdown]
# ### Generate frequent itemsets
#
# Let's find all sets of items with a support greater than some threshold.
#
# We define 4 functions for generating frequent itemsets:
# * createC1 - Create first candidate itemsets for k=1
# * scanD - Identify itemsets that meet the support threshold
# * aprioriGen - Generate the next list of candidates
# * apriori - Generate all frequent itemsets
#
# See slides for explanation of functions.

# %%
def createC1(dataset):
    "Create a list of candidate item sets of size one."
    c1 = []
    for transaction in dataset:
        for item in transaction:
            if not [item] in c1:
                c1.append([item])
    c1.sort()
    #frozenset because it will be a ket of a dictionary.                         
    return list(map(frozenset, c1))



def scanD(dataset, candidates, min_support):
    "Returns all candidates that meets a minimum support level"
    sscnt = {}
    for tid in dataset:
        for can in candidates:
            if can.issubset(tid):
                sscnt.setdefault(can, 0)
                sscnt[can] += 1

    num_items = float(len(dataset))
    retlist = []
    support_data = {}
    for key in sscnt:
        support = sscnt[key] / num_items
        if support >= min_support:
            retlist.insert(0, key)
            support_data[key] = support
    return retlist, support_data


def aprioriGen(freq_sets, k):
    "Generate the joint transactions from candidate sets"
    retList = []
    lenLk = len(freq_sets)
    for i in range(lenLk):
        for j in range(i + 1, lenLk):
            L1 = list(freq_sets[i])[:k - 2]
            L2 = list(freq_sets[j])[:k - 2]
            L1.sort()
            L2.sort()
            if L1 == L2:
                retList.append(freq_sets[i] | freq_sets[j]) # | is set union
    return retList


def apriori(dataset, min_support=0.5):
    "Generate a list of candidate item sets"
    C1 = createC1(dataset)
    D = list(map(set, dataset))
    L1, support_data = scanD(D, C1, min_support)
    L = [L1]
    k = 2
    while (len(L[k - 2]) > 0):
        Ck = aprioriGen(L[k - 2], k)
        Lk, supK = scanD(D, Ck, min_support)
        support_data.update(supK)
        L.append(Lk)
        k += 1

    return L, support_data

# %% [markdown]
# ### Itemset generation on sample data

# %%
MIN_SUPPORT=0.5

# Sample data
#DATASET = [['Mango', 'Onion', 'Apple'], ['Corn', 'Onion', 'Eggs'], ['Mango', 'Corn', 'Onion', 'Eggs'], ['Mango', 'Eggs']]
DATASET = [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]
print('Dataset in list-of-lists format:\n', DATASET, '\n')

# Generate a first candidate itemsets for k=1
C1 = createC1(DATASET)
print('Initial 1-itemset candidates:\n', C1, '\n')

# Convert data to a list of sets
D = list(map(set, DATASET))
print('Dataset in list-of-sets format:\n', D, '\n')

# Identify items that meet support threshold (0.5)
# Note that {4} isn't here as it only occurs in one transaction.
# Remove it so we don't generate any further candidate itemsets containing {4}.
L1, support_data = scanD(D, C1, MIN_SUPPORT)
print('1-itemsets that appear in at least 50% of transactions:\n', L1, '\n')

# Generate the next list of candidates
print('Next set of candidates:\n', aprioriGen(L1,2), '\n')

# Generate all candidate itemsets
L, support_data = apriori(DATASET, min_support=MIN_SUPPORT)
print('Full list of candidate itemsets:\n', L, '\n')
print('Support values for candidate itemsets:\n', support_data, '\n')
# Out:
# Dataset in list-of-lists format:
#  [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C', 'E'], ['B', 'E']]
#
# Initial 1-itemset candidates:
#  [frozenset({'A'}), frozenset({'B'}), frozenset({'C'}), frozenset({'D'}), frozenset({'E'})]
#
# Dataset in list-of-sets format:
#  [{'A', 'C', 'D'}, {'B', 'C', 'E'}, {'A', 'B', 'C', 'E'}, {'B', 'E'}]
#
# 1-itemsets that appear in at least 50% of transactions:
#  [frozenset({'E'}), frozenset({'B'}), frozenset({'C'}), frozenset({'A'})]
#
# Next set of candidates:
#  [frozenset({'B', 'E'}), frozenset({'C', 'E'}), frozenset({'A', 'E'}), frozenset({'B', 'C'}), frozenset({'A', 'B'}), frozenset({'A', 'C'})]
#
# Full list of candidate itemsets:
#  [[frozenset({'E'}), frozenset({'B'}), frozenset({'C'}), frozenset({'A'})], [frozenset({'B', 'C'}), frozenset({'C', 'E'}), frozenset({'B', 'E'}), frozenset({'A', 'C'})], [frozenset({'B', 'C', 'E'})], []]
#
# Support values for candidate itemsets:
#  {frozenset({'A'}): 0.5, frozenset({'C'}): 0.75, frozenset({'B'}): 0.75, frozenset({'E'}): 0.75, frozenset({'A', 'C'}): 0.5, frozenset({'B', 'E'}): 0.75, frozenset({'C', 'E'}): 0.5, frozenset({'B', 'C'}): 0.5, frozenset({'B', 'C', 'E'}): 0.5}

# %% [markdown]
# ### TODO Exploring support thresholds
#
# * Generate frequent itemsets with a support threshold of 0.7
# * How many frequent itemsets do we get at 0.7?
# * How many do we get at 0.3?
# * What would be a reasonable value for supermarket transaction data?
# * Do you have datasets that resemble transactions?
# * What about the apps/websites you use?

# %%
# 1 - 
l0_7, sd0_7 = apriori(DATASET, min_support=0.7)
print('Full list of candidate itemsets:\n', l0_7, '\n')
print('Support values for candidate itemsets:\n', sd0_7, '\n')

# 2 - 
temp = []
for ksets in l0_7:
    for i in ksets:
        temp.append(i)      
print('Number of frequent itemsets at 0.7:', len(temp))
##alternatively 
print('Number of frequent itemsets at 0.7:', len([i for ksets in l0_7 for i in ksets]))

# 3 - 
l0_3, sd0_3 = apriori(DATASET, min_support=0.3)

print('Number of frequent itemsets at 0.3:', len([i for ksets in l0_3 for i in ksets]))

# 4 - Much lower (e.g., 5%) to actually generate any frequent itemsets on real data

# 5 - Could imagine doing this for files to know what tends to be open at the same time.

# 6 - Many, many! E.g., Amazon, Netflix.
# Out:
# Full list of candidate itemsets:
#  [[frozenset({'E'}), frozenset({'B'}), frozenset({'C'})], [frozenset({'B', 'E'})], []]
#
# Support values for candidate itemsets:
#  {frozenset({'C'}): 0.75, frozenset({'B'}): 0.75, frozenset({'E'}): 0.75, frozenset({'B', 'E'}): 0.75}
#
# Number of frequent itemsets at 0.7: 4
# Number of frequent itemsets at 0.7: 4
# Number of frequent itemsets at 0.3: 9

# %% [markdown]
# ## *STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.*

# %% [markdown]
# ## Mine association rules
#
# Given frequent itemsets, we can create association rules.
#
# We add three more functions:
# * calc_confidence - Identify rules that meet the confidence threshold
# * rules_from_conseq - Recursively generate and evaluate candidate rules
# * generateRules - Mine all confident association rules
#
# See slides for explanation of functions.

# %%
def calc_confidence(freqSet, H, support_data, rules, min_confidence=0.7):
    "Evaluate the rule generated"
    pruned_H = []
    for conseq in H:
        conf = support_data[freqSet] / support_data[freqSet - conseq]
        if conf >= min_confidence:
            #print(freqSet - conseq, '--->', conseq, 'conf:', conf)
            rules.append((freqSet - conseq, conseq, conf))
            pruned_H.append(conseq)
    return pruned_H


def rules_from_conseq(freqSet, H, support_data, rules, min_confidence=0.7):
    "Generate a set of candidate rules"
    m = len(H[0])
    Hmp1 = createC1(H)
    Hmp1 = calc_confidence(freqSet, Hmp1,  support_data, rules, min_confidence)
    if len(Hmp1) <= len(freqSet):
        if (len(freqSet) > (m + 1)):
            Hmp1 = aprioriGen(H, m + 1)
            Hmp1 = calc_confidence(freqSet, Hmp1,  support_data, rules, min_confidence)
            if len(Hmp1) > 1:
                rules_from_conseq(freqSet, Hmp1, support_data, rules, min_confidence)

def generateRules(L, support_data, min_confidence=0.7):
    """Create the association rules
    L: list of frequent item sets
    support_data: support data for those itemsets
    min_confidence: minimum confidence threshold
    """
    rules = []
    for i in range(1, len(L)):
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]           
            if (i > 1):
                rules_from_conseq(freqSet, H1, support_data, rules, min_confidence)
            else:
                calc_confidence(freqSet, H1, support_data, rules, min_confidence)
    return rules

def print_rules(rules):
    for r in rules:
        print('{} ==> {} (c={})'.format(*r))

# %% [markdown]
# ### Rule mining on sample data

# %%
MIN_CONFIDENCE=0.7
# Mine association rules
association_rules = generateRules(L, support_data, min_confidence=MIN_CONFIDENCE)
print_rules(association_rules)
# Out:
# frozenset({'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'A'}) ==> frozenset({'C'}) (c=1.0)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'C'}) ==> frozenset({'E'}) (c=1.0)

# %% [markdown]
# ### TODO Exploring confidence thresholds
#
# * Mine rules with a confidence threshold of 0.9
# * How many rules do we get at 0.9?
# * How many do we get at 0.5?
# * What would be a reasonable value for supermarket transaction data?
# * Can we use this for recommendation (e.g., Amazon, Netflix)?

# %%
# 1 - 
r0_9 =  generateRules(L, support_data, min_confidence=0.9)
print('Rules for confidence threshold of 0.9:')
print_rules(r0_9)

# 2 - 
print('Number of rules at 0.9:', len(r0_9))

# 3 - 
r0_5 =  generateRules(L, support_data, min_confidence=0.5)
print('Rules for confidence threshold of 0.5:')
print_rules(r0_5)
print('Number of rules at 0.5:', len(r0_5))

# 4 - 70% might be reasonable; it will depend on the data and how many rules the business can use

# 5 - Absolutely, especially in session-focused recommendation ignoring user profile and history.
#     [https://en.wikipedia.org/wiki/Recommender_system]
#     [https://www.quora.com/How-does-Amazons-collaborative-filtering-recommendation-engine-work]
# Out:
# Rules for confidence threshold of 0.9:
# frozenset({'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'A'}) ==> frozenset({'C'}) (c=1.0)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'C'}) ==> frozenset({'E'}) (c=1.0)
# Number of rules at 0.9: 5
# Rules for confidence threshold of 0.5:
# frozenset({'C'}) ==> frozenset({'B'}) (c=0.6666666666666666)
# frozenset({'B'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'E'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'C'}) ==> frozenset({'A'}) (c=0.6666666666666666)
# frozenset({'A'}) ==> frozenset({'C'}) (c=1.0)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'B', 'C'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'E'}) ==> frozenset({'B', 'C'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'B', 'E'}) (c=0.6666666666666666)
# frozenset({'B'}) ==> frozenset({'C', 'E'}) (c=0.6666666666666666)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'B', 'C'}) ==> frozenset({'E'}) (c=1.0)
# Number of rules at 0.5: 17

# %% [markdown]
# ## EXERCISE: mlxtend library

# %% [markdown]
# ## Association analysis using mlxtend library

# %%
#!pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import pandas as pd
dataset =   [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]
            
             
oht = TransactionEncoder()
oht_ary = oht.fit(dataset).transform(dataset)
df = pd.DataFrame(oht_ary, columns=oht.columns_)
print (df)           
 
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
print('Support values for candidate itemsets:\n', frequent_itemsets, '\n')

 
rules= association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
#rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
print (rules.as_matrix(columns=['antecedents','consequents','confidence']))
#print(rules[{'antecedents','consequents','confidence'}])
# Out:
#        A      B      C      D      E
# 0   True  False   True   True  False
# 1  False   True   True  False   True
# 2   True   True   True  False   True
# 3  False   True  False  False   True
# Support values for candidate itemsets:
#     support   itemsets
# 0     0.50        (A)
# 1     0.75        (B)
# 2     0.75        (C)
# 3     0.75        (E)
# 4     0.50     (A, C)
# 5     0.50     (B, C)
# 6     0.75     (B, E)
# 7     0.50     (C, E)
# 8     0.50  (B, C, E)
#
# [[frozenset({'A'}) frozenset({'C'}) 1.0]
#  [frozenset({'B'}) frozenset({'E'}) 1.0]
#  [frozenset({'E'}) frozenset({'B'}) 1.0]
#  [frozenset({'B', 'C'}) frozenset({'E'}) 1.0]
#  [frozenset({'C', 'E'}) frozenset({'B'}) 1.0]]

# %% [markdown]
# ### Load the  supermarket transaction datasets

# %%
import csv 
import pprint
file_name = 'Groceries.csv'
data_list = []
with open(file_name, 'r') as f:  #opens PW file
    reader = csv.reader(f)
    # Print every value of every row. 
    for row in reader:
        row_list = []
        for value in row: 
            if len(value.strip()) > 0 and value.strip() != '':
                row_list.append(value.strip())
        data_list.append(row_list)
pprint.pprint(data_list)
# Out:
# [['pork',
#   'sandwich bags',
#   'lunch meat',
#   'all- purpose',
#   'flour',
#   'soda',
#   'butter',
#   'vegetables',
#   'beef',
#   'aluminum foil',
#   'all- purpose',
#   'dinner rolls',
#   'shampoo',
#   'all- purpose'],
#  ['shampoo',
#   'hand soap',
#   'waffles',
#   'vegetables',
#   'cheeses',
#   'mixes',
#   'milk',
#   'sandwich bags',
#   'laundry detergent',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'individual meals',
#   'hand soap',
#   'vegetables'],
#  ['pork',
#   'soap',
#   'ice cream',
#   'toilet paper',
#   'dinner rolls',
#   'hand soap',
#   'spaghetti sauce',
#   'milk',
#   'ketchup',
#   'sandwich loaves',
#   'poultry',
#   'toilet paper',
#   'ice cream',
#   'ketchup'],
#  ['juice', 'lunch meat', 'soda', 'toilet paper', 'all- purpose'],
#  ['pasta',
#   'tortillas',
#   'mixes',
#   'hand soap',
#   'toilet paper',
#   'vegetables',
#   'vegetables',
#   'paper towels',
#   'vegetables',
#   'flour',
#   'vegetables',
#   'pork',
#   'poultry',
#   'eggs'],
#  ['toilet paper',
#   'eggs',
#   'toilet paper',
#   'vegetables',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'cereals',
#   'paper towels',
#   'laundry detergent',
#   'butter',
#   'cereals',
#   'bagels',
#   'paper towels',
#   'shampoo'],
#  ['paper towels',
#   'tortillas',
#   'vegetables',
#   'milk',
#   'ice cream',
#   'juice',
#   'dishwashing liquid/detergent',
#   'soap',
#   'sandwich bags',
#   'pasta',
#   'ketchup',
#   'all- purpose',
#   'yogurt',
#   'mixes'],
#  ['juice',
#   'paper towels',
#   'waffles',
#   'soda',
#   'cheeses',
#   'poultry',
#   'toilet paper',
#   'vegetables'],
#  ['poultry', 'coffee/tea', 'coffee/tea', 'dishwashing liquid/detergent'],
#  ['coffee/tea',
#   'toilet paper',
#   'pork',
#   'flour',
#   'milk',
#   'soda',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'tortillas',
#   'tortillas',
#   'vegetables',
#   'fruits',
#   'sugar',
#   'soap'],
#  ['ice cream',
#   'soda',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'sugar',
#   'waffles',
#   'individual meals',
#   'toilet paper',
#   'pasta',
#   'sandwich loaves',
#   'cheeses',
#   'vegetables',
#   'hand soap'],
#  ['tortillas',
#   'pork',
#   'shampoo',
#   'lunch meat',
#   'pasta',
#   'juice',
#   'bagels',
#   'vegetables',
#   'bagels',
#   'vegetables',
#   'laundry detergent',
#   'yogurt',
#   'sugar',
#   'waffles'],
#  ['fruits',
#   'all- purpose',
#   'aluminum foil',
#   'laundry detergent',
#   'individual meals',
#   'flour',
#   'pork',
#   'shampoo',
#   'sugar',
#   'aluminum foil',
#   'shampoo',
#   'soap',
#   'bagels',
#   'toilet paper'],
#  ['dinner rolls',
#   'individual meals',
#   'shampoo',
#   'ketchup',
#   'cereals',
#   'sandwich bags',
#   'laundry detergent',
#   'vegetables',
#   'sandwich loaves',
#   'cheeses',
#   'vegetables'],
#  ['ice cream',
#   'cereals',
#   'paper towels',
#   'bagels',
#   'mixes',
#   'lunch meat',
#   'juice',
#   'toilet paper',
#   'cheeses',
#   'paper towels',
#   'paper towels',
#   'juice',
#   'aluminum foil',
#   'fruits'],
#  ['sandwich bags',
#   'flour',
#   'juice',
#   'milk',
#   'paper towels',
#   'cereals',
#   'sandwich bags',
#   'pasta',
#   'soda',
#   'dishwashing liquid/detergent',
#   'ice cream',
#   'soap',
#   'cheeses',
#   'beef'],
#  ['hand soap',
#   'pasta',
#   'individual meals',
#   'spaghetti sauce',
#   'cereals',
#   'sandwich loaves',
#   'hand soap',
#   'individual meals'],
#  ['toilet paper', 'bagels', 'shampoo', 'coffee/tea'],
#  ['laundry detergent',
#   'coffee/tea',
#   'eggs',
#   'aluminum foil',
#   'beef',
#   'juice',
#   'flour',
#   'sugar',
#   'individual meals',
#   'waffles',
#   'bagels',
#   'vegetables',
#   'coffee/tea',
#   'spaghetti sauce'],
#  ['dishwashing liquid/detergent',
#   'yogurt',
#   'juice',
#   'sugar',
#   'soap',
#   'sandwich loaves',
#   'butter',
#   'sandwich loaves',
#   'coffee/tea',
#   'ketchup',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'laundry detergent'],
#  ['fruits', 'all- purpose', 'pork', 'juice', 'bagels', 'mixes'],
#  ['vegetables', 'cereals', 'sugar', 'bagels', 'soda'],
#  ['vegetables',
#   'aluminum foil',
#   'bagels',
#   'vegetables',
#   'shampoo',
#   'shampoo',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'cereals',
#   'cheeses',
#   'flour',
#   'lunch meat',
#   'pasta',
#   'soda'],
#  ['all- purpose',
#   'pasta',
#   'cheeses',
#   'juice',
#   'sandwich bags',
#   'vegetables',
#   'sandwich loaves',
#   'coffee/tea',
#   'juice',
#   'lunch meat',
#   'spaghetti sauce',
#   'paper towels',
#   'hand soap',
#   'soap'],
#  ['sugar',
#   'pork',
#   'sandwich loaves',
#   'tortillas',
#   'ice cream',
#   'all- purpose',
#   'yogurt',
#   'fruits',
#   'pasta',
#   'lunch meat',
#   'dishwashing liquid/detergent',
#   'juice',
#   'vegetables',
#   'vegetables'],
#  ['sandwich loaves',
#   'vegetables',
#   'coffee/tea',
#   'aluminum foil',
#   'vegetables',
#   'shampoo',
#   'cereals',
#   'dinner rolls',
#   'coffee/tea',
#   'poultry',
#   'butter',
#   'juice',
#   'paper towels',
#   'vegetables'],
#  ['pork',
#   'pasta',
#   'cheeses',
#   'fruits',
#   'sugar',
#   'lunch meat',
#   'laundry detergent',
#   'paper towels',
#   'butter',
#   'sandwich loaves',
#   'ice cream',
#   'waffles',
#   'all- purpose',
#   'sandwich bags'],
#  ['bagels',
#   'poultry',
#   'pasta',
#   'butter',
#   'all- purpose',
#   'pasta',
#   'shampoo',
#   'sugar',
#   'ketchup',
#   'eggs',
#   'soda',
#   'tortillas',
#   'soap',
#   'individual meals'],
#  ['butter',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'juice',
#   'dinner rolls',
#   'all- purpose',
#   'pork',
#   'yogurt',
#   'vegetables',
#   'spaghetti sauce',
#   'vegetables'],
#  ['bagels', 'cheeses', 'sandwich loaves', 'toilet paper'],
#  ['eggs',
#   'ice cream',
#   'pasta',
#   'juice',
#   'waffles',
#   'shampoo',
#   'dinner rolls',
#   'soda',
#   'vegetables',
#   'laundry detergent',
#   'hand soap',
#   'waffles',
#   'cereals',
#   'vegetables'],
#  ['paper towels',
#   'individual meals',
#   'dinner rolls',
#   'vegetables',
#   'lunch meat',
#   'sugar',
#   'soap',
#   'eggs',
#   'beef',
#   'yogurt',
#   'soda',
#   'sandwich loaves',
#   'aluminum foil',
#   'dinner rolls'],
#  ['pork',
#   'sandwich bags',
#   'ketchup',
#   'coffee/tea',
#   'vegetables',
#   'soda',
#   'poultry',
#   'pasta',
#   'all- purpose',
#   'coffee/tea',
#   'paper towels',
#   'individual meals',
#   'vegetables',
#   'poultry'],
#  ['mixes',
#   'vegetables',
#   'soap',
#   'hand soap',
#   'tortillas',
#   'coffee/tea',
#   'cheeses',
#   'tortillas',
#   'cheeses',
#   'ice cream',
#   'tortillas',
#   'beef',
#   'yogurt',
#   'spaghetti sauce'],
#  ['cheeses',
#   'cereals',
#   'mixes',
#   'laundry detergent',
#   'juice',
#   'pork',
#   'bagels',
#   'sandwich loaves',
#   'yogurt',
#   'milk',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'cereals',
#   'individual meals'],
#  ['vegetables',
#   'lunch meat',
#   'flour',
#   'juice',
#   'yogurt',
#   'shampoo',
#   'spaghetti sauce',
#   'ketchup',
#   'laundry detergent',
#   'dinner rolls',
#   'ketchup',
#   'vegetables',
#   'shampoo',
#   'sugar'],
#  ['lunch meat',
#   'dinner rolls',
#   'shampoo',
#   'vegetables',
#   'hand soap',
#   'mixes',
#   'vegetables',
#   'pasta',
#   'sugar',
#   'vegetables'],
#  ['hand soap',
#   'dinner rolls',
#   'hand soap',
#   'lunch meat',
#   'laundry detergent',
#   'pasta',
#   'aluminum foil',
#   'toilet paper',
#   'cereals',
#   'coffee/tea',
#   'toilet paper',
#   'vegetables',
#   'juice',
#   'lunch meat'],
#  ['milk',
#   'dinner rolls',
#   'beef',
#   'coffee/tea',
#   'waffles',
#   'beef',
#   'eggs',
#   'sandwich bags',
#   'tortillas',
#   'vegetables',
#   'tortillas',
#   'all- purpose',
#   'vegetables',
#   'yogurt'],
#  ['sandwich bags',
#   'poultry',
#   'beef',
#   'coffee/tea',
#   'mixes',
#   'poultry',
#   'sandwich loaves',
#   'shampoo',
#   'ice cream',
#   'poultry',
#   'shampoo'],
#  ['hand soap',
#   'fruits',
#   'poultry',
#   'coffee/tea',
#   'sugar',
#   'tortillas',
#   'soda',
#   'individual meals',
#   'tortillas',
#   'milk',
#   'toilet paper',
#   'soda',
#   'poultry',
#   'coffee/tea'],
#  ['shampoo',
#   'waffles',
#   'bagels',
#   'mixes',
#   'shampoo',
#   'mixes',
#   'beef',
#   'dinner rolls',
#   'beef',
#   'shampoo',
#   'aluminum foil',
#   'individual meals',
#   'sugar',
#   'spaghetti sauce'],
#  ['butter',
#   'ketchup',
#   'shampoo',
#   'juice',
#   'mixes',
#   'milk',
#   'shampoo',
#   'tortillas',
#   'laundry detergent',
#   'flour',
#   'cereals',
#   'soap',
#   'toilet paper',
#   'butter'],
#  ['hand soap',
#   'waffles',
#   'laundry detergent',
#   'shampoo',
#   'lunch meat',
#   'cheeses',
#   'vegetables',
#   'hand soap',
#   'cereals',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'soda',
#   'spaghetti sauce',
#   'aluminum foil'],
#  ['cereals',
#   'toilet paper',
#   'waffles',
#   'soda',
#   'pork',
#   'yogurt',
#   'pork',
#   'all- purpose',
#   'toilet paper',
#   'vegetables',
#   'spaghetti sauce',
#   'toilet paper',
#   'vegetables',
#   'laundry detergent'],
#  ['spaghetti sauce',
#   'sandwich bags',
#   'ice cream',
#   'fruits',
#   'soap',
#   'cheeses',
#   'waffles',
#   'tortillas',
#   'sugar',
#   'toilet paper',
#   'ketchup',
#   'beef',
#   'beef',
#   'poultry'],
#  ['waffles',
#   'vegetables',
#   'beef',
#   'fruits',
#   'sandwich loaves',
#   'ketchup',
#   'cheeses',
#   'sugar',
#   'shampoo',
#   'butter',
#   'laundry detergent',
#   'poultry',
#   'waffles',
#   'soap'],
#  ['mixes',
#   'individual meals',
#   'laundry detergent',
#   'coffee/tea',
#   'hand soap',
#   'pasta',
#   'individual meals',
#   'cereals',
#   'spaghetti sauce',
#   'pasta',
#   'cereals',
#   'fruits',
#   'flour',
#   'vegetables'],
#  ['aluminum foil',
#   'sandwich bags',
#   'all- purpose',
#   'shampoo',
#   'beef',
#   'sandwich loaves',
#   'aluminum foil',
#   'ice cream',
#   'fruits',
#   'lunch meat',
#   'all- purpose',
#   'bagels',
#   'vegetables',
#   'sandwich loaves'],
#  ['cereals',
#   'beef',
#   'flour',
#   'sugar',
#   'beef',
#   'eggs',
#   'aluminum foil',
#   'vegetables',
#   'pork',
#   'soda',
#   'mixes',
#   'vegetables',
#   'ketchup',
#   'vegetables'],
#  ['sugar',
#   'pasta',
#   'sandwich loaves',
#   'mixes',
#   'butter',
#   'pasta',
#   'aluminum foil',
#   'tortillas',
#   'paper towels',
#   'yogurt',
#   'coffee/tea',
#   'sandwich bags',
#   'soda',
#   'poultry'],
#  ['cereals',
#   'mixes',
#   'cereals',
#   'pork',
#   'cheeses',
#   'poultry',
#   'all- purpose',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'beef',
#   'ketchup',
#   'mixes',
#   'ice cream'],
#  ['flour',
#   'butter',
#   'vegetables',
#   'lunch meat',
#   'toilet paper',
#   'tortillas',
#   'laundry detergent',
#   'milk',
#   'poultry',
#   'laundry detergent',
#   'milk',
#   'soda',
#   'butter',
#   'spaghetti sauce'],
#  ['butter',
#   'waffles',
#   'aluminum foil',
#   'coffee/tea',
#   'vegetables',
#   'vegetables',
#   'mixes',
#   'paper towels',
#   'juice',
#   'tortillas',
#   'dinner rolls',
#   'eggs',
#   'shampoo',
#   'waffles'],
#  ['tortillas',
#   'soda',
#   'beef',
#   'flour',
#   'eggs',
#   'vegetables',
#   'cheeses',
#   'lunch meat',
#   'coffee/tea',
#   'yogurt',
#   'dinner rolls',
#   'ice cream',
#   'pasta',
#   'fruits'],
#  ['poultry',
#   'eggs',
#   'eggs',
#   'ketchup',
#   'beef',
#   'toilet paper',
#   'soda',
#   'pork',
#   'ice cream',
#   'hand soap',
#   'shampoo',
#   'yogurt',
#   'fruits',
#   'waffles'],
#  ['spaghetti sauce',
#   'shampoo',
#   'ice cream',
#   'waffles',
#   'soda',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'soap',
#   'juice',
#   'all- purpose',
#   'vegetables',
#   'ketchup',
#   'individual meals',
#   'fruits'],
#  ['all- purpose',
#   'dishwashing liquid/detergent',
#   'soap',
#   'vegetables',
#   'milk',
#   'shampoo',
#   'coffee/tea',
#   'spaghetti sauce',
#   'aluminum foil',
#   'ice cream',
#   'pasta',
#   'all- purpose',
#   'eggs',
#   'tortillas'],
#  ['sandwich loaves',
#   'laundry detergent',
#   'ice cream',
#   'spaghetti sauce',
#   'milk',
#   'vegetables',
#   'all- purpose',
#   'cereals',
#   'hand soap',
#   'waffles',
#   'cereals',
#   'lunch meat',
#   'poultry',
#   'milk'],
#  ['flour',
#   'laundry detergent',
#   'poultry',
#   'milk',
#   'cheeses',
#   'pork',
#   'cereals',
#   'aluminum foil'],
#  ['fruits', 'all- purpose', 'juice', 'toilet paper'],
#  ['laundry detergent',
#   'laundry detergent',
#   'spaghetti sauce',
#   'beef',
#   'cheeses',
#   'shampoo',
#   'vegetables',
#   'waffles',
#   'cereals',
#   'sandwich bags',
#   'pasta',
#   'fruits',
#   'soap',
#   'vegetables'],
#  ['yogurt',
#   'ice cream',
#   'ice cream',
#   'toilet paper',
#   'ice cream',
#   'coffee/tea',
#   'sandwich bags',
#   'soda',
#   'ketchup',
#   'aluminum foil',
#   'all- purpose',
#   'pork',
#   'eggs',
#   'waffles'],
#  ['butter',
#   'flour',
#   'vegetables',
#   'bagels',
#   'sandwich bags',
#   'ice cream',
#   'sandwich loaves',
#   'flour',
#   'individual meals',
#   'ice cream',
#   'cheeses',
#   'milk',
#   'sandwich bags',
#   'poultry'],
#  ['hand soap',
#   'shampoo',
#   'beef',
#   'paper towels',
#   'mixes',
#   'lunch meat',
#   'pasta',
#   'shampoo',
#   'hand soap',
#   'pasta',
#   'milk',
#   'toilet paper',
#   'butter',
#   'eggs'],
#  ['hand soap',
#   'fruits',
#   'sandwich loaves',
#   'lunch meat',
#   'vegetables',
#   'individual meals',
#   'individual meals',
#   'sugar',
#   'fruits',
#   'cereals',
#   'ketchup',
#   'laundry detergent',
#   'cheeses',
#   'cheeses'],
#  ['cereals',
#   'yogurt',
#   'mixes',
#   'yogurt',
#   'sandwich loaves',
#   'hand soap',
#   'sugar',
#   'mixes',
#   'shampoo',
#   'all- purpose',
#   'pasta',
#   'cheeses',
#   'flour',
#   'poultry'],
#  ['lunch meat',
#   'sandwich bags',
#   'yogurt',
#   'ice cream',
#   'ice cream',
#   'individual meals',
#   'sugar',
#   'dishwashing liquid/detergent',
#   'flour',
#   'vegetables',
#   'paper towels',
#   'fruits',
#   'cheeses',
#   'vegetables'],
#  ['milk',
#   'yogurt',
#   'sugar',
#   'laundry detergent',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'cereals'],
#  ['soda', 'ketchup', 'poultry', 'vegetables'],
#  ['toilet paper',
#   'all- purpose',
#   'vegetables',
#   'juice',
#   'bagels',
#   'cheeses',
#   'fruits',
#   'vegetables',
#   'toilet paper',
#   'shampoo',
#   'eggs',
#   'butter',
#   'shampoo',
#   'butter'],
#  ['pasta',
#   'sugar',
#   'ketchup',
#   'waffles',
#   'all- purpose',
#   'vegetables',
#   'fruits',
#   'sandwich bags',
#   'sandwich bags',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'butter'],
#  ['ketchup',
#   'milk',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'butter',
#   'ice cream',
#   'laundry detergent',
#   'butter',
#   'aluminum foil',
#   'cereals',
#   'vegetables',
#   'spaghetti sauce',
#   'hand soap',
#   'mixes'],
#  ['vegetables',
#   'vegetables',
#   'ketchup',
#   'yogurt',
#   'cheeses',
#   'juice',
#   'all- purpose',
#   'mixes',
#   'ketchup',
#   'mixes',
#   'shampoo',
#   'milk',
#   'fruits',
#   'vegetables'],
#  ['individual meals',
#   'coffee/tea',
#   'lunch meat',
#   'butter',
#   'paper towels',
#   'pasta'],
#  ['laundry detergent',
#   'yogurt',
#   'toilet paper',
#   'tortillas',
#   'dinner rolls',
#   'tortillas',
#   'tortillas',
#   'soap',
#   'fruits',
#   'sandwich bags',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'milk',
#   'ketchup'],
#  ['dishwashing liquid/detergent',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'sugar',
#   'mixes',
#   'all- purpose',
#   'fruits',
#   'cereals',
#   'ice cream',
#   'lunch meat',
#   'sugar'],
#  ['dishwashing liquid/detergent',
#   'fruits',
#   'mixes',
#   'bagels',
#   'beef',
#   'ice cream',
#   'individual meals',
#   'bagels',
#   'butter'],
#  ['toilet paper',
#   'butter',
#   'lunch meat',
#   'individual meals',
#   'toilet paper',
#   'butter',
#   'poultry',
#   'cheeses',
#   'laundry detergent',
#   'spaghetti sauce',
#   'waffles',
#   'sandwich loaves'],
#  ['all- purpose',
#   'paper towels',
#   'ketchup',
#   'beef',
#   'soap',
#   'pork',
#   'waffles',
#   'lunch meat',
#   'cheeses',
#   'shampoo',
#   'spaghetti sauce',
#   'pork',
#   'poultry',
#   'all- purpose'],
#  ['vegetables',
#   'ketchup',
#   'soda',
#   'fruits',
#   'aluminum foil',
#   'yogurt',
#   'bagels',
#   'yogurt',
#   'milk',
#   'eggs',
#   'dishwashing liquid/detergent'],
#  ['soda',
#   'bagels',
#   'milk',
#   'fruits',
#   'pasta',
#   'spaghetti sauce',
#   'soap',
#   'cheeses',
#   'spaghetti sauce',
#   'juice',
#   'fruits',
#   'beef',
#   'toilet paper',
#   'dishwashing liquid/detergent'],
#  ['all- purpose',
#   'vegetables',
#   'individual meals',
#   'vegetables',
#   'toilet paper',
#   'pork',
#   'sandwich bags',
#   'paper towels',
#   'toilet paper',
#   'shampoo',
#   'coffee/tea',
#   'shampoo',
#   'juice',
#   'waffles'],
#  ['soap',
#   'cheeses',
#   'sandwich loaves',
#   'aluminum foil',
#   'bagels',
#   'tortillas',
#   'individual meals',
#   'hand soap',
#   'butter'],
#  ['aluminum foil',
#   'pork',
#   'fruits',
#   'sandwich bags',
#   'poultry',
#   'coffee/tea',
#   'bagels',
#   'hand soap',
#   'vegetables',
#   'mixes',
#   'ketchup',
#   'waffles',
#   'paper towels',
#   'tortillas'],
#  ['ketchup',
#   'all- purpose',
#   'beef',
#   'shampoo',
#   'sandwich loaves',
#   'coffee/tea',
#   'ketchup',
#   'vegetables',
#   'milk',
#   'butter',
#   'vegetables',
#   'pork',
#   'yogurt',
#   'vegetables'],
#  ['individual meals',
#   'shampoo',
#   'beef',
#   'sandwich bags',
#   'eggs',
#   'vegetables',
#   'shampoo',
#   'sandwich loaves',
#   'ketchup',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'beef',
#   'lunch meat',
#   'cereals'],
#  ['individual meals',
#   'sugar',
#   'spaghetti sauce',
#   'pasta',
#   'vegetables',
#   'cheeses',
#   'cheeses',
#   'fruits',
#   'fruits',
#   'lunch meat',
#   'vegetables',
#   'fruits',
#   'spaghetti sauce',
#   'individual meals'],
#  ['beef',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'juice',
#   'laundry detergent',
#   'beef',
#   'soda',
#   'laundry detergent',
#   'aluminum foil',
#   'soap'],
#  ['paper towels',
#   'individual meals',
#   'individual meals',
#   'aluminum foil',
#   'beef'],
#  ['cereals',
#   'sugar',
#   'tortillas',
#   'coffee/tea',
#   'sandwich loaves',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'dinner rolls',
#   'vegetables',
#   'mixes',
#   'all- purpose',
#   'ice cream'],
#  ['bagels',
#   'shampoo',
#   'sandwich bags',
#   'soap',
#   'ice cream',
#   'juice',
#   'shampoo',
#   'spaghetti sauce',
#   'vegetables',
#   'yogurt',
#   'ketchup'],
#  ['bagels',
#   'soda',
#   'vegetables',
#   'shampoo',
#   'vegetables',
#   'poultry',
#   'eggs',
#   'waffles',
#   'lunch meat',
#   'dinner rolls',
#   'beef',
#   'butter'],
#  ['tortillas',
#   'waffles',
#   'vegetables',
#   'pork',
#   'beef',
#   'mixes',
#   'vegetables',
#   'poultry',
#   'soap',
#   'toilet paper',
#   'waffles',
#   'vegetables',
#   'ketchup',
#   'poultry'],
#  ['ketchup',
#   'laundry detergent',
#   'pork',
#   'cheeses',
#   'shampoo',
#   'juice',
#   'yogurt',
#   'juice',
#   'eggs',
#   'coffee/tea',
#   'sandwich bags',
#   'flour',
#   'vegetables',
#   'beef'],
#  ['soap', 'pork', 'tortillas', 'soap'],
#  ['fruits',
#   'paper towels',
#   'sugar',
#   'individual meals',
#   'hand soap',
#   'milk',
#   'soda'],
#  ['coffee/tea',
#   'pork',
#   'aluminum foil',
#   'cheeses',
#   'soda',
#   'soda',
#   'bagels',
#   'vegetables'],
#  ['laundry detergent',
#   'juice',
#   'ketchup',
#   'cheeses',
#   'aluminum foil',
#   'waffles',
#   'pasta',
#   'vegetables',
#   'yogurt',
#   'eggs',
#   'aluminum foil',
#   'tortillas',
#   'toilet paper',
#   'paper towels'],
#  ['eggs',
#   'tortillas',
#   'vegetables',
#   'soda',
#   'vegetables',
#   'cereals',
#   'vegetables',
#   'mixes',
#   'toilet paper',
#   'bagels',
#   'dinner rolls'],
#  ['butter',
#   'cereals',
#   'cereals',
#   'vegetables',
#   'lunch meat',
#   'milk',
#   'milk',
#   'ice cream',
#   'butter',
#   'butter',
#   'poultry',
#   'paper towels',
#   'cheeses',
#   'lunch meat'],
#  ['cereals',
#   'lunch meat',
#   'sandwich loaves',
#   'vegetables',
#   'vegetables',
#   'pork',
#   'butter',
#   'poultry',
#   'soap',
#   'toilet paper'],
#  ['sandwich bags',
#   'flour',
#   'all- purpose',
#   'shampoo',
#   'coffee/tea',
#   'bagels',
#   'shampoo'],
#  ['dishwashing liquid/detergent',
#   'toilet paper',
#   'spaghetti sauce',
#   'mixes',
#   'all- purpose',
#   'cheeses',
#   'toilet paper',
#   'toilet paper',
#   'vegetables',
#   'coffee/tea',
#   'lunch meat',
#   'spaghetti sauce',
#   'flour',
#   'individual meals'],
#  ['cereals',
#   'ketchup',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'bagels',
#   'beef',
#   'eggs',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'individual meals',
#   'waffles',
#   'soap',
#   'milk',
#   'pork'],
#  ['cheeses',
#   'cereals',
#   'sugar',
#   'soap',
#   'hand soap',
#   'sugar',
#   'spaghetti sauce',
#   'milk',
#   'coffee/tea',
#   'aluminum foil',
#   'soda',
#   'cereals',
#   'ice cream',
#   'vegetables'],
#  ['ketchup',
#   'lunch meat',
#   'juice',
#   'waffles',
#   'sandwich loaves',
#   'vegetables',
#   'vegetables',
#   'cheeses',
#   'vegetables',
#   'pork',
#   'lunch meat',
#   'beef',
#   'tortillas',
#   'bagels'],
#  ['pasta',
#   'all- purpose',
#   'bagels',
#   'lunch meat',
#   'poultry',
#   'paper towels',
#   'coffee/tea',
#   'sugar',
#   'cereals',
#   'vegetables',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'bagels'],
#  ['poultry',
#   'vegetables',
#   'pork',
#   'vegetables',
#   'vegetables',
#   'vegetables',
#   'individual meals',
#   'hand soap',
#   'vegetables',
#   'hand soap',
#   'pasta',
#   'all- purpose',
#   'toilet paper',
#   'mixes'],
#  ['laundry detergent',
#   'cereals',
#   'toilet paper',
#   'sandwich bags',
#   'poultry',
#   'vegetables',
#   'ketchup',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'pork',
#   'flour',
#   'lunch meat',
#   'eggs'],
#  ['fruits',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'vegetables',
#   'waffles',
#   'poultry',
#   'soda',
#   'pork',
#   'sugar',
#   'poultry',
#   'flour',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'bagels'],
#  ['pork',
#   'aluminum foil',
#   'fruits',
#   'aluminum foil',
#   'cereals',
#   'lunch meat',
#   'coffee/tea',
#   'yogurt',
#   'bagels',
#   'sugar',
#   'sugar',
#   'eggs',
#   'sugar',
#   'fruits'],
#  ['sandwich loaves',
#   'vegetables',
#   'paper towels',
#   'vegetables',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'ketchup',
#   'soda',
#   'soda',
#   'sandwich bags',
#   'dinner rolls',
#   'all- purpose',
#   'ketchup',
#   'waffles'],
#  ['waffles',
#   'beef',
#   'individual meals',
#   'beef',
#   'shampoo',
#   'ice cream',
#   'cheeses',
#   'poultry',
#   'vegetables',
#   'dinner rolls',
#   'pasta',
#   'lunch meat',
#   'fruits',
#   'bagels'],
#  ['bagels',
#   'coffee/tea',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'cheeses',
#   'laundry detergent',
#   'hand soap'],
#  ['ice cream',
#   'shampoo',
#   'vegetables',
#   'milk',
#   'toilet paper',
#   'cereals',
#   'laundry detergent',
#   'dinner rolls',
#   'sugar',
#   'pork',
#   'flour',
#   'sugar'],
#  ['pasta',
#   'ketchup',
#   'sandwich bags',
#   'waffles',
#   'sugar',
#   'beef',
#   'pork',
#   'milk',
#   'ice cream',
#   'soda',
#   'fruits',
#   'cereals',
#   'vegetables',
#   'fruits'],
#  ['bagels',
#   'cheeses',
#   'soda',
#   'poultry',
#   'cheeses',
#   'vegetables',
#   'flour',
#   'dinner rolls',
#   'hand soap',
#   'laundry detergent',
#   'flour',
#   'vegetables',
#   'milk',
#   'dinner rolls'],
#  ['cheeses',
#   'yogurt',
#   'coffee/tea',
#   'coffee/tea',
#   'beef',
#   'toilet paper',
#   'shampoo',
#   'sandwich loaves',
#   'ketchup',
#   'sandwich loaves',
#   'paper towels',
#   'vegetables',
#   'vegetables',
#   'pork'],
#  ['paper towels',
#   'sugar',
#   'vegetables',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'shampoo'],
#  ['beef',
#   'beef',
#   'sugar',
#   'toilet paper',
#   'aluminum foil',
#   'aluminum foil',
#   'hand soap',
#   'all- purpose',
#   'yogurt',
#   'eggs',
#   'flour',
#   'fruits',
#   'waffles',
#   'waffles'],
#  ['juice',
#   'waffles',
#   'vegetables',
#   'waffles',
#   'lunch meat',
#   'spaghetti sauce',
#   'juice',
#   'all- purpose',
#   'flour',
#   'soap',
#   'waffles',
#   'juice',
#   'spaghetti sauce',
#   'vegetables'],
#  ['vegetables',
#   'soap',
#   'soda',
#   'cheeses',
#   'toilet paper',
#   'shampoo',
#   'eggs',
#   'paper towels',
#   'mixes',
#   'individual meals',
#   'coffee/tea',
#   'all- purpose',
#   'sugar',
#   'waffles'],
#  ['coffee/tea',
#   'sugar',
#   'cheeses',
#   'tortillas',
#   'all- purpose',
#   'milk',
#   'pasta',
#   'poultry',
#   'paper towels',
#   'yogurt',
#   'eggs',
#   'toilet paper',
#   'bagels',
#   'pork'],
#  ['cheeses',
#   'tortillas',
#   'spaghetti sauce',
#   'yogurt',
#   'beef',
#   'sandwich bags',
#   'laundry detergent',
#   'vegetables',
#   'soap',
#   'eggs',
#   'yogurt',
#   'juice',
#   'shampoo',
#   'vegetables'],
#  ['fruits',
#   'dinner rolls',
#   'vegetables',
#   'sandwich loaves',
#   'flour',
#   'eggs',
#   'pork',
#   'pork',
#   'spaghetti sauce',
#   'spaghetti sauce'],
#  ['butter',
#   'butter',
#   'poultry',
#   'beef',
#   'soap',
#   'fruits',
#   'vegetables',
#   'toilet paper',
#   'bagels',
#   'sugar',
#   'tortillas',
#   'poultry',
#   'toilet paper',
#   'fruits'],
#  ['soap',
#   'sandwich bags',
#   'ice cream',
#   'individual meals',
#   'ice cream',
#   'mixes',
#   'aluminum foil',
#   'bagels',
#   'sandwich bags',
#   'cereals',
#   'butter',
#   'beef',
#   'dishwashing liquid/detergent',
#   'laundry detergent'],
#  ['paper towels',
#   'spaghetti sauce',
#   'cereals',
#   'dinner rolls',
#   'tortillas',
#   'toilet paper',
#   'sugar'],
#  ['cereals',
#   'spaghetti sauce',
#   'lunch meat',
#   'fruits',
#   'spaghetti sauce',
#   'beef',
#   'shampoo',
#   'individual meals',
#   'paper towels',
#   'cheeses',
#   'aluminum foil',
#   'cheeses',
#   'coffee/tea',
#   'poultry'],
#  ['cheeses',
#   'aluminum foil',
#   'lunch meat',
#   'dinner rolls',
#   'sandwich bags',
#   'dinner rolls',
#   'flour',
#   'fruits',
#   'soda',
#   'aluminum foil',
#   'vegetables',
#   'eggs',
#   'mixes',
#   'sandwich bags'],
#  ['laundry detergent',
#   'laundry detergent',
#   'individual meals',
#   'poultry',
#   'juice',
#   'juice',
#   'lunch meat',
#   'sandwich bags',
#   'beef',
#   'dinner rolls',
#   'milk',
#   'toilet paper',
#   'pasta',
#   'ice cream'],
#  ['pork',
#   'mixes',
#   'flour',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'toilet paper',
#   'coffee/tea',
#   'soap',
#   'bagels',
#   'waffles',
#   'coffee/tea',
#   'pork',
#   'individual meals'],
#  ['pasta',
#   'eggs',
#   'cheeses',
#   'vegetables',
#   'all- purpose',
#   'ice cream',
#   'hand soap',
#   'shampoo',
#   'ice cream',
#   'vegetables',
#   'bagels',
#   'sandwich loaves',
#   'waffles',
#   'coffee/tea'],
#  ['juice',
#   'sugar',
#   'bagels',
#   'spaghetti sauce',
#   'ketchup',
#   'shampoo',
#   'tortillas',
#   'sandwich loaves',
#   'vegetables',
#   'flour',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'milk'],
#  ['eggs',
#   'ketchup',
#   'waffles',
#   'butter',
#   'sandwich loaves',
#   'sugar',
#   'sandwich bags',
#   'vegetables',
#   'shampoo',
#   'laundry detergent',
#   'sandwich bags',
#   'vegetables',
#   'cheeses',
#   'cereals'],
#  ['fruits',
#   'cheeses',
#   'waffles',
#   'vegetables',
#   'sandwich bags',
#   'aluminum foil',
#   'pasta',
#   'lunch meat',
#   'flour',
#   'butter',
#   'aluminum foil',
#   'poultry'],
#  ['tortillas',
#   'fruits',
#   'toilet paper',
#   'milk',
#   'butter',
#   'cereals',
#   'cereals',
#   'pasta',
#   'bagels',
#   'sandwich loaves',
#   'beef',
#   'cereals',
#   'aluminum foil',
#   'coffee/tea'],
#  ['laundry detergent',
#   'vegetables',
#   'ice cream',
#   'milk',
#   'sugar',
#   'mixes',
#   'vegetables',
#   'tortillas',
#   'toilet paper',
#   'milk',
#   'sandwich bags',
#   'poultry',
#   'soda',
#   'sandwich loaves'],
#  ['butter',
#   'cereals',
#   'soda',
#   'dishwashing liquid/detergent',
#   'cheeses',
#   'cheeses',
#   'sandwich loaves',
#   'flour',
#   'hand soap',
#   'cereals',
#   'individual meals'],
#  ['bagels', 'aluminum foil', 'beef', 'flour', 'spaghetti sauce', 'vegetables'],
#  ['pasta',
#   'butter',
#   'vegetables',
#   'dinner rolls',
#   'all- purpose',
#   'ketchup',
#   'cereals',
#   'ice cream',
#   'toilet paper',
#   'spaghetti sauce'],
#  ['pasta',
#   'yogurt',
#   'waffles',
#   'vegetables',
#   'waffles',
#   'mixes',
#   'cereals',
#   'eggs',
#   'soda',
#   'spaghetti sauce',
#   'mixes',
#   'dinner rolls',
#   'pasta'],
#  ['bagels',
#   'aluminum foil',
#   'flour',
#   'individual meals',
#   'dinner rolls',
#   'ketchup',
#   'tortillas',
#   'butter',
#   'aluminum foil',
#   'paper towels',
#   'toilet paper',
#   'laundry detergent',
#   'dinner rolls',
#   'vegetables'],
#  ['pasta',
#   'fruits',
#   'aluminum foil',
#   'hand soap',
#   'vegetables',
#   'all- purpose',
#   'flour'],
#  ['pork',
#   'hand soap',
#   'vegetables',
#   'ketchup',
#   'yogurt',
#   'butter',
#   'ice cream',
#   'lunch meat',
#   'laundry detergent',
#   'lunch meat',
#   'butter',
#   'yogurt',
#   'all- purpose',
#   'waffles'],
#  ['vegetables',
#   'juice',
#   'cereals',
#   'pork',
#   'poultry',
#   'sugar',
#   'vegetables',
#   'shampoo',
#   'yogurt',
#   'soap'],
#  ['individual meals',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'cereals',
#   'milk',
#   'paper towels',
#   'lunch meat',
#   'vegetables',
#   'sugar',
#   'beef',
#   'toilet paper',
#   'spaghetti sauce'],
#  ['ketchup',
#   'milk',
#   'all- purpose',
#   'mixes',
#   'cheeses',
#   'individual meals',
#   'yogurt',
#   'yogurt',
#   'paper towels',
#   'vegetables',
#   'pork',
#   'shampoo',
#   'pork',
#   'sugar'],
#  ['ice cream',
#   'butter',
#   'ketchup',
#   'ketchup',
#   'vegetables',
#   'pasta',
#   'sugar',
#   'eggs',
#   'sandwich loaves',
#   'individual meals',
#   'spaghetti sauce',
#   'dinner rolls',
#   'aluminum foil',
#   'eggs'],
#  ['ketchup',
#   'cheeses',
#   'individual meals',
#   'spaghetti sauce',
#   'dishwashing liquid/detergent',
#   'soap',
#   'all- purpose',
#   'fruits',
#   'eggs',
#   'bagels',
#   'beef',
#   'waffles',
#   'sandwich loaves',
#   'vegetables'],
#  ['spaghetti sauce',
#   'paper towels',
#   'soap',
#   'eggs',
#   'mixes',
#   'coffee/tea',
#   'tortillas',
#   'eggs',
#   'waffles',
#   'laundry detergent'],
#  ['soda',
#   'spaghetti sauce',
#   'fruits',
#   'beef',
#   'lunch meat',
#   'sugar',
#   'yogurt',
#   'aluminum foil',
#   'vegetables',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'eggs',
#   'dishwashing liquid/detergent'],
#  ['pasta',
#   'vegetables',
#   'sugar',
#   'pasta',
#   'sugar',
#   'bagels',
#   'milk',
#   'coffee/tea',
#   'flour',
#   'dinner rolls',
#   'aluminum foil',
#   'vegetables',
#   'ketchup',
#   'aluminum foil'],
#  ['cereals', 'sandwich bags', 'juice', 'tortillas', 'spaghetti sauce'],
#  ['juice',
#   'poultry',
#   'sandwich bags',
#   'individual meals',
#   'shampoo',
#   'yogurt',
#   'fruits',
#   'coffee/tea',
#   'vegetables',
#   'ice cream',
#   'poultry',
#   'pork',
#   'coffee/tea',
#   'vegetables'],
#  ['all- purpose',
#   'coffee/tea',
#   'vegetables',
#   'eggs',
#   'beef',
#   'juice',
#   'bagels',
#   'vegetables',
#   'fruits',
#   'juice',
#   'vegetables',
#   'hand soap',
#   'flour',
#   'sugar'],
#  ['eggs',
#   'sandwich bags',
#   'cereals',
#   'hand soap',
#   'pasta',
#   'laundry detergent',
#   'poultry',
#   'eggs',
#   'pork',
#   'pasta',
#   'laundry detergent'],
#  ['bagels',
#   'vegetables',
#   'toilet paper',
#   'cereals',
#   'sugar',
#   'laundry detergent',
#   'fruits',
#   'butter',
#   'dinner rolls',
#   'ice cream',
#   'bagels',
#   'ketchup'],
#  ['yogurt',
#   'toilet paper',
#   'coffee/tea',
#   'mixes',
#   'milk',
#   'soda',
#   'milk',
#   'cereals'],
#  ['pork',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'fruits',
#   'cheeses',
#   'toilet paper',
#   'coffee/tea',
#   'vegetables',
#   'yogurt',
#   'dinner rolls',
#   'milk',
#   'poultry',
#   'cheeses'],
#  ['sandwich bags',
#   'coffee/tea',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'soap',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'ketchup',
#   'beef',
#   'spaghetti sauce',
#   'fruits',
#   'sandwich bags',
#   'sandwich bags',
#   'cheeses'],
#  ['coffee/tea', 'ice cream', 'bagels', 'pork'],
#  ['all- purpose',
#   'ketchup',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'sugar',
#   'eggs',
#   'waffles',
#   'juice',
#   'dishwashing liquid/detergent',
#   'flour',
#   'eggs',
#   'all- purpose',
#   'flour',
#   'sandwich bags'],
#  ['tortillas',
#   'vegetables',
#   'milk',
#   'hand soap',
#   'fruits',
#   'coffee/tea',
#   'sugar',
#   'pork'],
#  ['fruits',
#   'aluminum foil',
#   'bagels',
#   'eggs',
#   'flour',
#   'cheeses',
#   'paper towels',
#   'shampoo',
#   'aluminum foil',
#   'vegetables',
#   'coffee/tea',
#   'spaghetti sauce',
#   'juice',
#   'bagels'],
#  ['dinner rolls',
#   'soda',
#   'dinner rolls',
#   'dinner rolls',
#   'hand soap',
#   'dinner rolls',
#   'all- purpose',
#   'tortillas',
#   'sugar',
#   'individual meals',
#   'bagels',
#   'soap',
#   'ketchup',
#   'individual meals'],
#  ['yogurt', 'all- purpose', 'mixes', 'bagels'],
#  ['hand soap',
#   'laundry detergent',
#   'yogurt',
#   'aluminum foil',
#   'bagels',
#   'fruits',
#   'mixes',
#   'mixes',
#   'soda',
#   'sandwich bags',
#   'vegetables'],
#  ['butter', 'ice cream', 'individual meals', 'all- purpose'],
#  ['pasta',
#   'poultry',
#   'cereals',
#   'soap',
#   'laundry detergent',
#   'pasta',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'paper towels',
#   'toilet paper',
#   'lunch meat',
#   'fruits',
#   'pork'],
#  ['eggs',
#   'dinner rolls',
#   'soap',
#   'individual meals',
#   'all- purpose',
#   'fruits',
#   'dinner rolls',
#   'laundry detergent',
#   'juice',
#   'dishwashing liquid/detergent',
#   'vegetables'],
#  ['vegetables',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'eggs',
#   'vegetables',
#   'soda',
#   'juice',
#   'sugar',
#   'ice cream',
#   'soap',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'individual meals',
#   'coffee/tea'],
#  ['beef',
#   'beef',
#   'mixes',
#   'vegetables',
#   'bagels',
#   'shampoo',
#   'milk',
#   'shampoo',
#   'flour',
#   'lunch meat',
#   'pork',
#   'yogurt',
#   'poultry',
#   'beef'],
#  ['mixes',
#   'pork',
#   'ice cream',
#   'juice',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'vegetables',
#   'butter',
#   'toilet paper',
#   'mixes',
#   'juice',
#   'paper towels',
#   'sandwich loaves',
#   'dishwashing liquid/detergent'],
#  ['cheeses',
#   'ketchup',
#   'flour',
#   'mixes',
#   'tortillas',
#   'shampoo',
#   'sandwich loaves',
#   'fruits',
#   'spaghetti sauce',
#   'lunch meat',
#   'lunch meat',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'yogurt'],
#  ['waffles',
#   'mixes',
#   'shampoo',
#   'laundry detergent',
#   'ketchup',
#   'paper towels',
#   'dinner rolls',
#   'ketchup',
#   'aluminum foil'],
#  ['fruits', 'pork', 'flour', 'cheeses', 'yogurt', 'juice', 'lunch meat'],
#  ['ketchup',
#   'vegetables',
#   'toilet paper',
#   'tortillas',
#   'juice',
#   'ketchup',
#   'spaghetti sauce',
#   'all- purpose',
#   'lunch meat',
#   'mixes',
#   'spaghetti sauce',
#   'ice cream',
#   'cheeses',
#   'paper towels'],
#  ['vegetables',
#   'paper towels',
#   'shampoo',
#   'fruits',
#   'yogurt',
#   'dinner rolls',
#   'lunch meat',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'toilet paper',
#   'mixes',
#   'soda',
#   'laundry detergent'],
#  ['vegetables', 'hand soap', 'milk', 'hand soap', 'beef'],
#  ['aluminum foil',
#   'sandwich bags',
#   'mixes',
#   'dinner rolls',
#   'milk',
#   'tortillas',
#   'milk',
#   'fruits',
#   'pasta',
#   'pasta',
#   'lunch meat',
#   'yogurt',
#   'cheeses',
#   'vegetables'],
#  ['toilet paper',
#   'juice',
#   'aluminum foil',
#   'all- purpose',
#   'beef',
#   'juice',
#   'paper towels',
#   'coffee/tea',
#   'individual meals'],
#  ['individual meals',
#   'eggs',
#   'ice cream',
#   'bagels',
#   'vegetables',
#   'poultry',
#   'dinner rolls',
#   'vegetables',
#   'butter',
#   'mixes',
#   'tortillas',
#   'spaghetti sauce',
#   'cereals',
#   'tortillas'],
#  ['waffles',
#   'flour',
#   'lunch meat',
#   'milk',
#   'tortillas',
#   'sandwich loaves',
#   'yogurt',
#   'flour',
#   'beef',
#   'shampoo',
#   'cereals',
#   'vegetables',
#   'waffles',
#   'aluminum foil'],
#  ['beef',
#   'pork',
#   'aluminum foil',
#   'sandwich bags',
#   'soda',
#   'beef',
#   'toilet paper',
#   'poultry',
#   'soap',
#   'pasta',
#   'ketchup'],
#  ['flour',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'ketchup',
#   'ketchup',
#   'bagels',
#   'all- purpose',
#   'hand soap',
#   'shampoo',
#   'yogurt',
#   'hand soap',
#   'poultry',
#   'vegetables',
#   'aluminum foil'],
#  ['cheeses',
#   'sandwich bags',
#   'cereals',
#   'laundry detergent',
#   'aluminum foil',
#   'yogurt',
#   'all- purpose',
#   'bagels',
#   'shampoo',
#   'soap',
#   'pasta',
#   'yogurt',
#   'lunch meat',
#   'vegetables'],
#  ['beef',
#   'dinner rolls',
#   'ketchup',
#   'pasta',
#   'milk',
#   'soap',
#   'hand soap',
#   'coffee/tea',
#   'hand soap',
#   'vegetables',
#   'ice cream',
#   'eggs',
#   'bagels',
#   'flour'],
#  ['beef',
#   'cheeses',
#   'ice cream',
#   'hand soap',
#   'laundry detergent',
#   'ketchup',
#   'juice',
#   'lunch meat',
#   'butter',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables'],
#  ['waffles',
#   'milk',
#   'laundry detergent',
#   'vegetables',
#   'dinner rolls',
#   'vegetables',
#   'milk',
#   'spaghetti sauce',
#   'toilet paper',
#   'pork',
#   'sugar',
#   'lunch meat',
#   'toilet paper',
#   'sandwich loaves'],
#  ['flour',
#   'individual meals',
#   'flour',
#   'poultry',
#   'butter',
#   'hand soap',
#   'eggs',
#   'butter',
#   'flour',
#   'butter',
#   'ketchup',
#   'laundry detergent',
#   'spaghetti sauce',
#   'shampoo'],
#  ['soap',
#   'dinner rolls',
#   'ice cream',
#   'sandwich loaves',
#   'toilet paper',
#   'sandwich bags',
#   'juice',
#   'ketchup',
#   'beef',
#   'cheeses',
#   'soap',
#   'paper towels'],
#  ['pork',
#   'sugar',
#   'sandwich bags',
#   'pasta',
#   'ketchup',
#   'sandwich bags',
#   'pork',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'milk',
#   'bagels'],
#  ['ketchup',
#   'pasta',
#   'tortillas',
#   'sandwich loaves',
#   'laundry detergent',
#   'soap'],
#  ['milk',
#   'flour',
#   'beef',
#   'soda',
#   'sandwich loaves',
#   'ice cream',
#   'fruits',
#   'ice cream',
#   'fruits',
#   'soda',
#   'all- purpose'],
#  ['ice cream',
#   'bagels',
#   'pork',
#   'all- purpose',
#   'ice cream',
#   'ice cream',
#   'vegetables',
#   'pasta',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'ice cream',
#   'hand soap',
#   'soap',
#   'butter'],
#  ['individual meals',
#   'paper towels',
#   'mixes',
#   'ketchup',
#   'aluminum foil',
#   'juice',
#   'spaghetti sauce',
#   'fruits'],
#  ['pasta',
#   'dinner rolls',
#   'aluminum foil',
#   'sandwich loaves',
#   'ice cream',
#   'vegetables',
#   'butter',
#   'cereals',
#   'butter',
#   'beef',
#   'soda',
#   'toilet paper',
#   'cheeses',
#   'waffles'],
#  ['coffee/tea',
#   'pasta',
#   'aluminum foil',
#   'lunch meat',
#   'sandwich loaves',
#   'sandwich bags',
#   'sugar',
#   'aluminum foil',
#   'tortillas',
#   'individual meals',
#   'juice',
#   'vegetables'],
#  ['all- purpose',
#   'vegetables',
#   'paper towels',
#   'fruits',
#   'poultry',
#   'poultry',
#   'mixes',
#   'vegetables',
#   'soda',
#   'milk',
#   'individual meals',
#   'sugar',
#   'yogurt'],
#  ['dinner rolls',
#   'milk',
#   'tortillas',
#   'ice cream',
#   'vegetables',
#   'dinner rolls',
#   'poultry',
#   'vegetables',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'cereals',
#   'butter',
#   'hand soap'],
#  ['spaghetti sauce',
#   'sandwich loaves',
#   'flour',
#   'soap',
#   'vegetables',
#   'eggs',
#   'vegetables',
#   'poultry',
#   'cereals',
#   'cheeses',
#   'fruits',
#   'vegetables',
#   'paper towels',
#   'flour'],
#  ['milk',
#   'vegetables',
#   'dinner rolls',
#   'butter',
#   'all- purpose',
#   'sandwich loaves',
#   'waffles',
#   'yogurt',
#   'vegetables',
#   'coffee/tea',
#   'flour',
#   'bagels',
#   'vegetables',
#   'lunch meat'],
#  ['beef',
#   'lunch meat',
#   'beef',
#   'mixes',
#   'individual meals',
#   'milk',
#   'shampoo',
#   'all- purpose',
#   'yogurt',
#   'individual meals',
#   'spaghetti sauce',
#   'paper towels',
#   'cereals',
#   'aluminum foil'],
#  ['vegetables',
#   'dinner rolls',
#   'sugar',
#   'bagels',
#   'spaghetti sauce',
#   'dishwashing liquid/detergent'],
#  ['coffee/tea',
#   'eggs',
#   'toilet paper',
#   'dinner rolls',
#   'pasta',
#   'paper towels',
#   'tortillas',
#   'spaghetti sauce',
#   'waffles',
#   'all- purpose',
#   'bagels',
#   'aluminum foil',
#   'bagels',
#   'soda'],
#  ['hand soap', 'sandwich bags', 'milk', 'milk'],
#  ['shampoo',
#   'eggs',
#   'beef',
#   'ice cream',
#   'paper towels',
#   'shampoo',
#   'individual meals',
#   'shampoo',
#   'pasta',
#   'milk',
#   'coffee/tea',
#   'pasta',
#   'waffles',
#   'pasta'],
#  ['poultry',
#   'waffles',
#   'aluminum foil',
#   'coffee/tea',
#   'toilet paper',
#   'hand soap',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'aluminum foil',
#   'pork',
#   'spaghetti sauce',
#   'beef',
#   'dinner rolls'],
#  ['hand soap',
#   'eggs',
#   'soda',
#   'aluminum foil',
#   'poultry',
#   'tortillas',
#   'bagels',
#   'vegetables',
#   'sandwich bags',
#   'cheeses',
#   'sandwich bags',
#   'cereals',
#   'mixes',
#   'dinner rolls'],
#  ['spaghetti sauce',
#   'tortillas',
#   'spaghetti sauce',
#   'vegetables',
#   'soda',
#   'spaghetti sauce',
#   'pasta',
#   'sandwich bags',
#   'spaghetti sauce',
#   'yogurt',
#   'bagels',
#   'toilet paper',
#   'shampoo',
#   'vegetables'],
#  ['bagels', 'sandwich loaves', 'butter', 'vegetables'],
#  ['dinner rolls',
#   'pasta',
#   'soap',
#   'ketchup',
#   'paper towels',
#   'vegetables',
#   'juice',
#   'sugar',
#   'ice cream',
#   'sandwich bags',
#   'spaghetti sauce'],
#  ['spaghetti sauce',
#   'paper towels',
#   'individual meals',
#   'poultry',
#   'soap',
#   'ice cream',
#   'paper towels',
#   'ice cream',
#   'coffee/tea',
#   'soap',
#   'milk',
#   'soap',
#   'eggs',
#   'cereals'],
#  ['waffles',
#   'shampoo',
#   'mixes',
#   'vegetables',
#   'shampoo',
#   'flour',
#   'waffles',
#   'soda',
#   'sandwich loaves',
#   'vegetables',
#   'sandwich loaves',
#   'soap',
#   'laundry detergent',
#   'vegetables'],
#  ['sugar',
#   'coffee/tea',
#   'all- purpose',
#   'juice',
#   'mixes',
#   'soda',
#   'yogurt',
#   'vegetables',
#   'all- purpose',
#   'cereals',
#   'soap',
#   'soda',
#   'hand soap',
#   'vegetables'],
#  ['individual meals',
#   'juice',
#   'individual meals',
#   'vegetables',
#   'vegetables',
#   'sugar'],
#  ['bagels',
#   'spaghetti sauce',
#   'beef',
#   'sandwich loaves',
#   'fruits',
#   'laundry detergent',
#   'ice cream',
#   'cereals',
#   'lunch meat',
#   'poultry',
#   'bagels',
#   'all- purpose',
#   'paper towels',
#   'pasta'],
#  ['juice',
#   'dishwashing liquid/detergent',
#   'milk',
#   'individual meals',
#   'spaghetti sauce',
#   'toilet paper',
#   'flour',
#   'yogurt',
#   'waffles',
#   'tortillas',
#   'fruits',
#   'paper towels',
#   'cereals',
#   'pasta'],
#  ['pasta',
#   'eggs',
#   'shampoo',
#   'sugar',
#   'paper towels',
#   'ketchup',
#   'poultry',
#   'sugar',
#   'soda',
#   'butter',
#   'paper towels',
#   'pasta',
#   'waffles',
#   'lunch meat'],
#  ['cheeses',
#   'butter',
#   'aluminum foil',
#   'vegetables',
#   'vegetables',
#   'poultry',
#   'hand soap',
#   'toilet paper',
#   'ice cream',
#   'sugar',
#   'mixes',
#   'vegetables',
#   'vegetables',
#   'milk'],
#  ['butter',
#   'spaghetti sauce',
#   'hand soap',
#   'soap',
#   'sandwich bags',
#   'ketchup',
#   'ice cream',
#   'waffles',
#   'flour',
#   'pasta',
#   'soap',
#   'pasta',
#   'all- purpose',
#   'dishwashing liquid/detergent'],
#  ['bagels', 'fruits', 'mixes', 'vegetables', 'tortillas', 'cereals'],
#  ['milk',
#   'bagels',
#   'pork',
#   'yogurt',
#   'ice cream',
#   'eggs',
#   'individual meals',
#   'soda',
#   'vegetables',
#   'pasta',
#   'pork',
#   'waffles',
#   'waffles',
#   'pork'],
#  ['fruits',
#   'spaghetti sauce',
#   'pasta',
#   'mixes',
#   'pasta',
#   'fruits',
#   'dishwashing liquid/detergent',
#   'juice',
#   'aluminum foil',
#   'flour',
#   'individual meals',
#   'yogurt',
#   'ketchup',
#   'fruits'],
#  ['eggs',
#   'cheeses',
#   'cereals',
#   'juice',
#   'hand soap',
#   'soap',
#   'soap',
#   'yogurt',
#   'pork',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'beef',
#   'bagels'],
#  ['butter',
#   'all- purpose',
#   'dinner rolls',
#   'vegetables',
#   'beef',
#   'vegetables',
#   'milk',
#   'laundry detergent'],
#  ['soda',
#   'bagels',
#   'poultry',
#   'vegetables',
#   'tortillas',
#   'milk',
#   'soap',
#   'yogurt',
#   'lunch meat',
#   'lunch meat',
#   'lunch meat'],
#  ['individual meals',
#   'poultry',
#   'individual meals',
#   'soda',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'pork',
#   'coffee/tea',
#   'hand soap',
#   'beef',
#   'ice cream',
#   'dinner rolls',
#   'lunch meat',
#   'individual meals'],
#  ['pasta',
#   'cereals',
#   'individual meals',
#   'vegetables',
#   'toilet paper',
#   'coffee/tea',
#   'toilet paper',
#   'mixes',
#   'fruits',
#   'vegetables',
#   'shampoo',
#   'soap',
#   'toilet paper',
#   'soap'],
#  ['sandwich loaves',
#   'eggs',
#   'soap',
#   'pasta',
#   'vegetables',
#   'dinner rolls',
#   'paper towels',
#   'soda',
#   'coffee/tea',
#   'poultry',
#   'cheeses',
#   'vegetables',
#   'spaghetti sauce',
#   'butter'],
#  ['juice', 'cereals', 'lunch meat', 'waffles', 'ketchup', 'pasta', 'juice'],
#  ['beef',
#   'sandwich bags',
#   'shampoo',
#   'fruits',
#   'cheeses',
#   'flour',
#   'laundry detergent',
#   'waffles',
#   'vegetables',
#   'soap',
#   'waffles',
#   'eggs',
#   'individual meals',
#   'eggs'],
#  ['spaghetti sauce',
#   'flour',
#   'milk',
#   'beef',
#   'laundry detergent',
#   'tortillas',
#   'cereals',
#   'coffee/tea',
#   'sandwich loaves',
#   'beef',
#   'toilet paper',
#   'milk',
#   'yogurt',
#   'soda'],
#  ['individual meals',
#   'lunch meat',
#   'soda',
#   'vegetables',
#   'sugar',
#   'mixes',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'bagels',
#   'coffee/tea',
#   'hand soap',
#   'sugar',
#   'spaghetti sauce'],
#  ['sugar',
#   'yogurt',
#   'butter',
#   'milk',
#   'poultry',
#   'hand soap',
#   'mixes',
#   'bagels',
#   'tortillas',
#   'vegetables',
#   'spaghetti sauce',
#   'flour',
#   'eggs',
#   'poultry'],
#  ['lunch meat',
#   'pasta',
#   'laundry detergent',
#   'sandwich loaves',
#   'vegetables',
#   'poultry',
#   'yogurt',
#   'laundry detergent',
#   'sandwich bags',
#   'aluminum foil',
#   'vegetables',
#   'tortillas',
#   'milk',
#   'soap'],
#  ['sandwich loaves',
#   'toilet paper',
#   'yogurt',
#   'fruits',
#   'butter',
#   'cereals',
#   'vegetables',
#   'waffles',
#   'beef',
#   'lunch meat',
#   'paper towels',
#   'mixes',
#   'paper towels',
#   'dinner rolls'],
#  ['waffles',
#   'juice',
#   'lunch meat',
#   'vegetables',
#   'shampoo',
#   'dinner rolls',
#   'all- purpose',
#   'sandwich loaves',
#   'hand soap',
#   'waffles',
#   'spaghetti sauce',
#   'shampoo',
#   'fruits',
#   'eggs'],
#  ['flour',
#   'waffles',
#   'soap',
#   'vegetables',
#   'tortillas',
#   'fruits',
#   'sugar',
#   'paper towels',
#   'lunch meat',
#   'lunch meat',
#   'spaghetti sauce',
#   'poultry'],
#  ['vegetables',
#   'flour',
#   'milk',
#   'soda',
#   'laundry detergent',
#   'yogurt',
#   'cheeses',
#   'yogurt'],
#  ['butter', 'poultry', 'aluminum foil', 'vegetables'],
#  ['yogurt',
#   'cereals',
#   'sandwich bags',
#   'laundry detergent',
#   'fruits',
#   'flour',
#   'soda',
#   'sandwich loaves',
#   'fruits',
#   'aluminum foil',
#   'individual meals',
#   'coffee/tea',
#   'spaghetti sauce',
#   'mixes'],
#  ['dinner rolls',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'eggs',
#   'pasta',
#   'ice cream',
#   'ketchup',
#   'sugar',
#   'flour',
#   'pasta',
#   'all- purpose',
#   'yogurt',
#   'pork',
#   'cereals'],
#  ['bagels',
#   'juice',
#   'cereals',
#   'mixes',
#   'fruits',
#   'individual meals',
#   'aluminum foil',
#   'sandwich loaves',
#   'laundry detergent',
#   'paper towels',
#   'all- purpose',
#   'ice cream',
#   'cereals',
#   'soap'],
#  ['pork',
#   'beef',
#   'vegetables',
#   'coffee/tea',
#   'cheeses',
#   'butter',
#   'bagels',
#   'waffles'],
#  ['soda', 'beef', 'juice', 'sugar'],
#  ['fruits',
#   'individual meals',
#   'vegetables',
#   'spaghetti sauce',
#   'hand soap',
#   'sandwich loaves',
#   'vegetables',
#   'sugar',
#   'pork',
#   'laundry detergent',
#   'sandwich loaves',
#   'dishwashing liquid/detergent',
#   'yogurt',
#   'bagels'],
#  ['sandwich loaves',
#   'bagels',
#   'pasta',
#   'toilet paper',
#   'ketchup',
#   'shampoo',
#   'beef',
#   'poultry',
#   'milk',
#   'beef',
#   'laundry detergent',
#   'juice',
#   'sugar',
#   'all- purpose'],
#  ['soap',
#   'yogurt',
#   'sandwich loaves',
#   'waffles',
#   'hand soap',
#   'poultry',
#   'toilet paper',
#   'toilet paper'],
#  ['spaghetti sauce',
#   'sandwich bags',
#   'ice cream',
#   'yogurt',
#   'bagels',
#   'tortillas',
#   'all- purpose',
#   'sandwich bags',
#   'ice cream',
#   'eggs',
#   'individual meals',
#   'butter',
#   'mixes',
#   'all- purpose'],
#  ['hand soap',
#   'ice cream',
#   'vegetables',
#   'bagels',
#   'milk',
#   'aluminum foil',
#   'dinner rolls',
#   'toilet paper',
#   'yogurt',
#   'ketchup',
#   'bagels',
#   'pasta',
#   'soap',
#   'beef'],
#  ['sugar',
#   'mixes',
#   'vegetables',
#   'poultry',
#   'waffles',
#   'pork',
#   'sandwich bags',
#   'toilet paper',
#   'all- purpose',
#   'tortillas',
#   'dinner rolls',
#   'hand soap'],
#  ['eggs',
#   'mixes',
#   'lunch meat',
#   'fruits',
#   'coffee/tea',
#   'yogurt',
#   'aluminum foil',
#   'flour'],
#  ['poultry',
#   'soap',
#   'butter',
#   'sandwich bags',
#   'beef',
#   'milk',
#   'all- purpose',
#   'pasta',
#   'dinner rolls'],
#  ['bagels',
#   'tortillas',
#   'dinner rolls',
#   'flour',
#   'vegetables',
#   'ketchup',
#   'juice',
#   'toilet paper',
#   'milk',
#   'all- purpose',
#   'spaghetti sauce',
#   'shampoo',
#   'spaghetti sauce',
#   'hand soap'],
#  ['waffles',
#   'laundry detergent',
#   'pasta',
#   'toilet paper',
#   'juice',
#   'sugar',
#   'milk',
#   'cereals',
#   'flour',
#   'soda'],
#  ['paper towels',
#   'pork',
#   'cereals',
#   'fruits',
#   'aluminum foil',
#   'bagels',
#   'butter',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'eggs',
#   'lunch meat',
#   'flour',
#   'laundry detergent',
#   'vegetables'],
#  ['butter',
#   'individual meals',
#   'cereals',
#   'toilet paper',
#   'individual meals',
#   'soda',
#   'waffles',
#   'juice',
#   'butter',
#   'sandwich loaves',
#   'individual meals',
#   'yogurt',
#   'soda'],
#  ['ketchup',
#   'flour',
#   'pasta',
#   'soda',
#   'pork',
#   'hand soap',
#   'eggs',
#   'sandwich bags',
#   'soap',
#   'juice',
#   'cheeses',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'lunch meat'],
#  ['cereals',
#   'dinner rolls',
#   'juice',
#   'aluminum foil',
#   'fruits',
#   'spaghetti sauce',
#   'milk',
#   'ice cream',
#   'hand soap',
#   'cheeses',
#   'ketchup',
#   'milk',
#   'lunch meat',
#   'cereals'],
#  ['shampoo',
#   'beef',
#   'sugar',
#   'mixes',
#   'pasta',
#   'toilet paper',
#   'eggs',
#   'dinner rolls',
#   'poultry',
#   'soap',
#   'laundry detergent',
#   'spaghetti sauce',
#   'laundry detergent',
#   'cereals'],
#  ['vegetables',
#   'ice cream',
#   'fruits',
#   'ketchup',
#   'ketchup',
#   'laundry detergent'],
#  ['vegetables',
#   'waffles',
#   'mixes',
#   'vegetables',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'all- purpose',
#   'vegetables',
#   'waffles',
#   'dinner rolls',
#   'sugar',
#   'aluminum foil',
#   'waffles'],
#  ['vegetables',
#   'all- purpose',
#   'coffee/tea',
#   'ketchup',
#   'ketchup',
#   'hand soap',
#   'shampoo',
#   'fruits',
#   'individual meals',
#   'eggs',
#   'sandwich bags',
#   'cheeses',
#   'cereals',
#   'yogurt'],
#  ['toilet paper',
#   'tortillas',
# ...
#   'toilet paper',
#   'yogurt',
#   'individual meals',
#   'beef'],
#  ['aluminum foil',
#   'dinner rolls',
#   'sandwich loaves',
#   'butter',
#   'tortillas',
#   'vegetables',
#   'hand soap',
#   'dinner rolls',
#   'vegetables'],
#  ['paper towels',
#   'eggs',
#   'lunch meat',
#   'sandwich loaves',
#   'butter',
#   'dishwashing liquid/detergent',
#   'juice',
#   'laundry detergent',
#   'fruits',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'butter',
#   'poultry',
#   'bagels'],
#  ['tortillas',
#   'vegetables',
#   'pasta',
#   'soap',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'tortillas',
#   'fruits',
#   'milk',
#   'soda',
#   'dinner rolls',
#   'vegetables',
#   'dinner rolls',
#   'cereals'],
#  ['dishwashing liquid/detergent',
#   'coffee/tea',
#   'vegetables',
#   'bagels',
#   'sandwich bags',
#   'milk',
#   'tortillas',
#   'yogurt',
#   'beef',
#   'hand soap'],
#  ['dinner rolls', 'poultry', 'aluminum foil', 'juice'],
#  ['flour',
#   'soda',
#   'ice cream',
#   'lunch meat',
#   'juice',
#   'ketchup',
#   'flour',
#   'beef',
#   'all- purpose',
#   'butter',
#   'laundry detergent',
#   'vegetables',
#   'butter',
#   'individual meals'],
#  ['eggs',
#   'juice',
#   'dinner rolls',
#   'vegetables',
#   'yogurt',
#   'spaghetti sauce',
#   'beef',
#   'vegetables',
#   'paper towels',
#   'shampoo',
#   'dinner rolls',
#   'beef',
#   'aluminum foil',
#   'soda'],
#  ['shampoo',
#   'soda',
#   'eggs',
#   'paper towels',
#   'flour',
#   'paper towels',
#   'shampoo',
#   'pasta',
#   'soda',
#   'eggs',
#   'ketchup',
#   'toilet paper',
#   'individual meals',
#   'yogurt'],
#  ['eggs',
#   'beef',
#   'ketchup',
#   'pork',
#   'dinner rolls',
#   'bagels',
#   'coffee/tea',
#   'tortillas',
#   'spaghetti sauce',
#   'pasta',
#   'waffles',
#   'all- purpose',
#   'milk',
#   'coffee/tea'],
#  ['sandwich bags',
#   'soda',
#   'tortillas',
#   'soda',
#   'tortillas',
#   'eggs',
#   'pasta',
#   'soda',
#   'yogurt',
#   'shampoo',
#   'lunch meat',
#   'milk',
#   'laundry detergent',
#   'cheeses'],
#  ['sugar',
#   'poultry',
#   'sandwich loaves',
#   'cereals',
#   'poultry',
#   'tortillas',
#   'vegetables',
#   'tortillas',
#   'vegetables',
#   'vegetables',
#   'ice cream',
#   'lunch meat',
#   'eggs',
#   'butter'],
#  ['poultry',
#   'sandwich loaves',
#   'dinner rolls',
#   'pork',
#   'coffee/tea',
#   'hand soap',
#   'cheeses',
#   'dinner rolls',
#   'all- purpose',
#   'butter',
#   'ketchup',
#   'laundry detergent',
#   'spaghetti sauce',
#   'cheeses'],
#  ['individual meals',
#   'pork',
#   'individual meals',
#   'individual meals',
#   'soap',
#   'paper towels',
#   'sandwich loaves',
#   'eggs',
#   'cereals',
#   'aluminum foil',
#   'dinner rolls',
#   'ice cream',
#   'soap',
#   'shampoo'],
#  ['sandwich bags',
#   'pasta',
#   'milk',
#   'milk',
#   'dishwashing liquid/detergent',
#   'all- purpose',
#   'individual meals',
#   'shampoo',
#   'pork',
#   'juice',
#   'pasta',
#   'paper towels'],
#  ['soap',
#   'hand soap',
#   'all- purpose',
#   'sugar',
#   'vegetables',
#   'yogurt',
#   'poultry',
#   'hand soap',
#   'flour',
#   'waffles',
#   'pork',
#   'spaghetti sauce',
#   'butter',
#   'shampoo'],
#  ['soap',
#   'flour',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'milk',
#   'poultry'],
#  ['all- purpose',
#   'tortillas',
#   'yogurt',
#   'all- purpose',
#   'ketchup',
#   'vegetables',
#   'butter',
#   'dinner rolls',
#   'flour',
#   'butter',
#   'ketchup',
#   'mixes',
#   'laundry detergent',
#   'milk'],
#  ['poultry', 'coffee/tea', 'sandwich loaves', 'individual meals'],
#  ['aluminum foil',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'paper towels',
#   'soda',
#   'ketchup',
#   'dinner rolls',
#   'soap',
#   'ketchup',
#   'milk',
#   'milk',
#   'ice cream',
#   'flour',
#   'juice'],
#  ['vegetables',
#   'sandwich bags',
#   'vegetables',
#   'soda',
#   'coffee/tea',
#   'sandwich loaves',
#   'hand soap'],
#  ['lunch meat',
#   'eggs',
#   'eggs',
#   'individual meals',
#   'all- purpose',
#   'beef',
#   'spaghetti sauce',
#   'vegetables',
#   'paper towels',
#   'eggs',
#   'cereals',
#   'individual meals',
#   'fruits',
#   'dishwashing liquid/detergent'],
#  ['tortillas',
#   'bagels',
#   'all- purpose',
#   'spaghetti sauce',
#   'juice',
#   'sugar',
#   'paper towels',
#   'fruits',
#   'fruits',
#   'individual meals',
#   'eggs',
#   'spaghetti sauce',
#   'pork',
#   'pork'],
#  ['individual meals',
#   'beef',
#   'milk',
#   'laundry detergent',
#   'hand soap',
#   'bagels',
#   'milk',
#   'vegetables',
#   'aluminum foil',
#   'vegetables',
#   'toilet paper',
#   'aluminum foil',
#   'soda',
#   'vegetables'],
#  ['fruits',
#   'yogurt',
#   'sugar',
#   'cheeses',
#   'pasta',
#   'soda',
#   'butter',
#   'vegetables',
#   'butter',
#   'dishwashing liquid/detergent',
#   'cheeses',
#   'ice cream',
#   'pork',
#   'ice cream'],
#  ['dishwashing liquid/detergent',
#   'flour',
#   'paper towels',
#   'yogurt',
#   'flour',
#   'spaghetti sauce',
#   'fruits',
#   'ice cream',
#   'vegetables',
#   'cheeses',
#   'all- purpose',
#   'pork',
#   'cheeses',
#   'yogurt'],
#  ['all- purpose',
#   'ice cream',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'butter'],
#  ['vegetables',
#   'milk',
#   'ketchup',
#   'juice',
#   'toilet paper',
#   'hand soap',
#   'shampoo',
#   'bagels',
#   'sandwich bags',
#   'coffee/tea',
#   'fruits',
#   'eggs',
#   'mixes',
#   'cereals'],
#  ['dinner rolls',
#   'shampoo',
#   'vegetables',
#   'eggs',
#   'coffee/tea',
#   'ice cream',
#   'sandwich bags',
#   'pasta',
#   'milk',
#   'tortillas'],
#  ['pork',
#   'individual meals',
#   'lunch meat',
#   'mixes',
#   'beef',
#   'vegetables',
#   'coffee/tea',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'coffee/tea',
#   'soda'],
#  ['lunch meat',
#   'flour',
#   'pasta',
#   'dinner rolls',
#   'soda',
#   'toilet paper',
#   'vegetables',
#   'aluminum foil',
#   'yogurt',
#   'toilet paper',
#   'paper towels',
#   'coffee/tea',
#   'ice cream',
#   'individual meals'],
#  ['dinner rolls',
#   'spaghetti sauce',
#   'soda',
#   'butter',
#   'paper towels',
#   'poultry',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'fruits',
#   'poultry',
#   'vegetables',
#   'butter',
#   'mixes',
#   'flour'],
#  ['juice',
#   'milk',
#   'paper towels',
#   'bagels',
#   'dinner rolls',
#   'soda',
#   'vegetables',
#   'pork',
#   'toilet paper',
#   'pasta',
#   'ketchup',
#   'soda',
#   'fruits',
#   'cereals'],
#  ['coffee/tea',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'ketchup',
#   'vegetables',
#   'flour',
#   'dinner rolls',
#   'shampoo',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'paper towels'],
#  ['mixes',
#   'fruits',
#   'pork',
#   'dinner rolls',
#   'butter',
#   'all- purpose',
#   'pasta',
#   'soda',
#   'pasta',
#   'sandwich loaves',
#   'eggs',
#   'mixes',
#   'vegetables',
#   'eggs'],
#  ['ice cream', 'dinner rolls', 'coffee/tea', 'coffee/tea', 'bagels', 'pork'],
#  ['individual meals',
#   'fruits',
#   'toilet paper',
#   'cereals',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'ketchup',
#   'poultry',
#   'aluminum foil',
#   'butter',
#   'dishwashing liquid/detergent'],
#  ['individual meals',
#   'sandwich bags',
#   'cereals',
#   'yogurt',
#   'soda',
#   'laundry detergent',
#   'bagels',
#   'laundry detergent',
#   'vegetables',
#   'vegetables',
#   'flour',
#   'cereals',
#   'spaghetti sauce',
#   'cheeses'],
#  ['dinner rolls',
#   'soda',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'individual meals',
#   'fruits',
#   'laundry detergent',
#   'ice cream',
#   'juice',
#   'beef',
#   'ketchup',
#   'bagels',
#   'paper towels',
#   'toilet paper'],
#  ['vegetables',
#   'ice cream',
#   'individual meals',
#   'pork',
#   'mixes',
#   'soap',
#   'ice cream',
#   'ketchup',
#   'mixes',
#   'individual meals',
#   'poultry',
#   'paper towels',
#   'vegetables',
#   'cheeses'],
#  ['poultry', 'vegetables', 'waffles', 'all- purpose', 'yogurt'],
#  ['eggs',
#   'laundry detergent',
#   'sugar',
#   'flour',
#   'sandwich loaves',
#   'yogurt',
#   'lunch meat',
#   'vegetables',
#   'spaghetti sauce',
#   'beef',
#   'cereals',
#   'flour',
#   'cereals',
#   'poultry'],
#  ['cheeses', 'vegetables', 'flour', 'soap', 'ice cream'],
#  ['mixes',
#   'toilet paper',
#   'sandwich loaves',
#   'coffee/tea',
#   'vegetables',
#   'flour',
#   'soap',
#   'vegetables',
#   'beef',
#   'sugar',
#   'ice cream',
#   'cereals',
#   'tortillas',
#   'juice'],
#  ['dishwashing liquid/detergent',
#   'toilet paper',
#   'toilet paper',
#   'mixes',
#   'yogurt',
#   'individual meals',
#   'dinner rolls',
#   'paper towels',
#   'sugar',
#   'tortillas',
#   'laundry detergent',
#   'vegetables',
#   'all- purpose',
#   'soda'],
#  ['cereals',
#   'sandwich loaves',
#   'soda',
#   'toilet paper',
#   'shampoo',
#   'pasta',
#   'beef',
#   'pasta',
#   'sandwich loaves',
#   'ice cream',
#   'cereals',
#   'dinner rolls',
#   'beef',
#   'cereals'],
#  ['ketchup',
#   'vegetables',
#   'juice',
#   'ketchup',
#   'soap',
#   'cheeses',
#   'shampoo',
#   'tortillas',
#   'lunch meat',
#   'waffles',
#   'flour',
#   'tortillas',
#   'ice cream',
#   'individual meals'],
#  ['soap',
#   'all- purpose',
#   'lunch meat',
#   'vegetables',
#   'beef',
#   'dinner rolls',
#   'mixes',
#   'sandwich loaves',
#   'poultry',
#   'fruits',
#   'pork',
#   'lunch meat',
#   'paper towels',
#   'soda'],
#  ['aluminum foil',
#   'all- purpose',
#   'sandwich bags',
#   'pork',
#   'bagels',
#   'sugar',
#   'pork',
#   'coffee/tea',
#   'vegetables',
#   'lunch meat',
#   'ketchup'],
#  ['shampoo',
#   'pasta',
#   'flour',
#   'cereals',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'tortillas',
#   'yogurt',
#   'flour',
#   'individual meals',
#   'laundry detergent',
#   'all- purpose'],
#  ['ketchup',
#   'paper towels',
#   'sandwich bags',
#   'pasta',
#   'laundry detergent',
#   'paper towels',
#   'butter',
#   'beef',
#   'waffles',
#   'tortillas',
#   'coffee/tea',
#   'waffles',
#   'poultry',
#   'juice'],
#  ['dinner rolls',
#   'bagels',
#   'waffles',
#   'sandwich loaves',
#   'pasta',
#   'individual meals',
#   'milk',
#   'soap',
#   'laundry detergent',
#   'spaghetti sauce',
#   'shampoo',
#   'dinner rolls',
#   'cheeses',
#   'laundry detergent'],
#  ['sandwich bags',
#   'flour',
#   'waffles',
#   'vegetables',
#   'ice cream',
#   'yogurt',
#   'tortillas',
#   'hand soap',
#   'paper towels'],
#  ['dinner rolls',
#   'ice cream',
#   'butter',
#   'sandwich loaves',
#   'shampoo',
#   'beef',
#   'eggs',
#   'butter',
#   'beef',
#   'waffles',
#   'aluminum foil',
#   'ketchup',
#   'eggs',
#   'sandwich loaves'],
#  ['dishwashing liquid/detergent',
#   'bagels',
#   'aluminum foil',
#   'hand soap',
#   'aluminum foil',
#   'laundry detergent'],
#  ['vegetables',
#   'fruits',
#   'cereals',
#   'milk',
#   'vegetables',
#   'yogurt',
#   'vegetables',
#   'eggs',
#   'hand soap',
#   'all- purpose',
#   'bagels'],
#  ['milk',
#   'toilet paper',
#   'individual meals',
#   'shampoo',
#   'vegetables',
#   'cheeses',
#   'hand soap'],
#  ['soap',
#   'ice cream',
#   'butter',
#   'vegetables',
#   'dinner rolls',
#   'mixes',
#   'lunch meat',
#   'waffles',
#   'hand soap'],
#  ['poultry',
#   'soap',
#   'mixes',
#   'fruits',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'eggs',
#   'ice cream',
#   'tortillas',
#   'sugar',
#   'lunch meat',
#   'tortillas',
#   'mixes',
#   'lunch meat'],
#  ['tortillas',
#   'mixes',
#   'cheeses',
#   'toilet paper',
#   'juice',
#   'mixes',
#   'toilet paper',
#   'beef',
#   'aluminum foil',
#   'yogurt',
#   'sandwich bags',
#   'sugar',
#   'cheeses',
#   'lunch meat'],
#  ['all- purpose',
#   'sandwich loaves',
#   'pork',
#   'bagels',
#   'sugar',
#   'juice',
#   'flour',
#   'waffles',
#   'sandwich loaves',
#   'sandwich loaves',
#   'sandwich bags',
#   'juice',
#   'flour',
#   'fruits'],
#  ['mixes',
#   'sandwich bags',
#   'all- purpose',
#   'dinner rolls',
#   'soda',
#   'vegetables',
#   'pork',
#   'butter',
#   'lunch meat',
#   'toilet paper',
#   'ice cream',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'dinner rolls'],
#  ['ketchup', 'spaghetti sauce', 'cheeses', 'vegetables'],
#  ['aluminum foil',
#   'butter',
#   'laundry detergent',
#   'spaghetti sauce',
#   'pasta',
#   'sandwich loaves',
#   'all- purpose',
#   'lunch meat',
#   'ketchup',
#   'bagels',
#   'ketchup',
#   'pork',
#   'toilet paper',
#   'sandwich loaves'],
#  ['flour',
#   'paper towels',
#   'cereals',
#   'pork',
#   'pork',
#   'vegetables',
#   'fruits',
#   'coffee/tea',
#   'toilet paper',
#   'cheeses',
#   'sandwich bags',
#   'soap',
#   'cheeses',
#   'beef'],
#  ['butter',
#   'butter',
#   'flour',
#   'fruits',
#   'vegetables',
#   'all- purpose',
#   'mixes',
#   'pork',
#   'mixes',
#   'sandwich loaves',
#   'flour',
#   'vegetables',
#   'mixes',
#   'beef'],
#  ['sandwich loaves',
#   'flour',
#   'yogurt',
#   'all- purpose',
#   'sandwich loaves',
#   'cereals',
#   'soap',
#   'toilet paper',
#   'sandwich bags',
#   'all- purpose',
#   'poultry',
#   'juice',
#   'dinner rolls',
#   'all- purpose'],
#  ['cheeses',
#   'paper towels',
#   'vegetables',
#   'pasta',
#   'milk',
#   'cereals',
#   'poultry',
#   'cheeses',
#   'yogurt',
#   'coffee/tea',
#   'dinner rolls',
#   'soda',
#   'flour',
#   'all- purpose'],
#  ['beef',
#   'lunch meat',
#   'vegetables',
#   'vegetables',
#   'yogurt',
#   'ice cream',
#   'aluminum foil',
#   'poultry',
#   'individual meals',
#   'dinner rolls',
#   'pork',
#   'dinner rolls',
#   'vegetables',
#   'poultry'],
#  ['soap',
#   'cheeses',
#   'vegetables',
#   'beef',
#   'vegetables',
#   'toilet paper',
#   'shampoo',
#   'cereals',
#   'soda'],
#  ['individual meals',
#   'paper towels',
#   'aluminum foil',
#   'waffles',
#   'cheeses',
#   'vegetables',
#   'dinner rolls',
#   'laundry detergent',
#   'dinner rolls',
#   'vegetables',
#   'toilet paper',
#   'juice',
#   'cereals',
#   'shampoo'],
#  ['vegetables',
#   'vegetables',
#   'vegetables',
#   'vegetables',
#   'poultry',
#   'mixes',
#   'sandwich bags',
#   'vegetables',
#   'spaghetti sauce',
#   'juice',
#   'vegetables',
#   'yogurt',
#   'toilet paper',
#   'laundry detergent'],
#  ['toilet paper',
#   'lunch meat',
#   'laundry detergent',
#   'ketchup',
#   'individual meals',
#   'mixes',
#   'poultry',
#   'fruits',
#   'soda',
#   'soap',
#   'sugar',
#   'dishwashing liquid/detergent',
#   'beef',
#   'beef'],
#  ['soda', 'pasta', 'dinner rolls', 'cheeses'],
#  ['fruits',
#   'spaghetti sauce',
#   'mixes',
#   'vegetables',
#   'beef',
#   'lunch meat',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'poultry',
#   'laundry detergent',
#   'poultry',
#   'laundry detergent',
#   'lunch meat'],
#  ['spaghetti sauce',
#   'yogurt',
#   'sandwich loaves',
#   'poultry',
#   'mixes',
#   'ice cream',
#   'paper towels',
#   'sandwich loaves',
#   'cereals',
#   'yogurt',
#   'all- purpose',
#   'vegetables',
#   'cereals',
#   'pork'],
#  ['waffles',
#   'mixes',
#   'vegetables',
#   'individual meals',
#   'ice cream',
#   'tortillas',
#   'ice cream',
#   'mixes',
#   'poultry',
#   'yogurt',
#   'eggs',
#   'bagels',
#   'tortillas',
#   'coffee/tea'],
#  ['waffles',
#   'mixes',
#   'dinner rolls',
#   'vegetables',
#   'sandwich bags',
#   'ketchup',
#   'coffee/tea',
#   'cheeses',
#   'juice',
#   'yogurt',
#   'pasta',
#   'bagels',
#   'butter',
#   'sugar'],
#  ['sandwich bags',
#   'dishwashing liquid/detergent',
#   'toilet paper',
#   'juice',
#   'sandwich loaves',
#   'butter',
#   'sugar',
#   'vegetables',
#   'milk',
#   'butter',
#   'yogurt',
#   'laundry detergent',
#   'eggs',
#   'juice'],
#  ['laundry detergent',
#   'ice cream',
#   'eggs',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'juice',
#   'pork',
#   'cheeses',
#   'pasta',
#   'soda',
#   'cheeses',
#   'milk'],
#  ['cheeses',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'toilet paper',
#   'eggs',
#   'soap',
#   'vegetables',
#   'sandwich loaves',
#   'toilet paper',
#   'ketchup',
#   'toilet paper',
#   'laundry detergent',
#   'lunch meat'],
#  ['butter',
#   'hand soap',
#   'bagels',
#   'soap',
#   'laundry detergent',
#   'toilet paper',
#   'hand soap',
#   'fruits',
#   'ketchup',
#   'poultry',
#   'ice cream',
#   'juice',
#   'tortillas',
#   'ice cream'],
#  ['pasta', 'toilet paper', 'pork', 'cheeses', 'coffee/tea'],
#  ['beef',
#   'sandwich bags',
#   'hand soap',
#   'paper towels',
#   'paper towels',
#   'all- purpose',
#   'beef',
#   'fruits',
#   'coffee/tea',
#   'beef',
#   'shampoo',
#   'mixes',
#   'cheeses',
#   'juice'],
#  ['dinner rolls',
#   'lunch meat',
#   'spaghetti sauce',
#   'pasta',
#   'vegetables',
#   'cereals',
#   'dinner rolls',
#   'soap',
#   'milk',
#   'eggs',
#   'poultry',
#   'cheeses',
#   'cereals',
#   'mixes'],
#  ['lunch meat',
#   'eggs',
#   'poultry',
#   'vegetables',
#   'tortillas',
#   'beef',
#   'beef',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'sugar'],
#  ['ketchup',
#   'milk',
#   'poultry',
#   'cheeses',
#   'soap',
#   'toilet paper',
#   'yogurt',
#   'beef',
#   'waffles',
#   'sugar',
#   'spaghetti sauce',
#   'all- purpose',
#   'sandwich bags',
#   'toilet paper'],
#  ['laundry detergent', 'vegetables', 'shampoo', 'vegetables']]

# %% [markdown]
# ## TODO Mining association rules on Groceries datasets
# * Apply apriori and association_rules functions from mlxtend library
# * What would be a reasonable value of min-support for these supermarket transaction data

# %%
oht = TransactionEncoder()
oht_ary = oht. fit(data_list).transform(data_list)
df = pd.DataFrame(oht_ary, columns=oht.columns_)
 
MIN_SUPPORT = 0.05
frequent_itemsets = apriori(df, min_support=MIN_SUPPORT, use_colnames=True)
print (frequent_itemsets)
 
rules= association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
print (rules.as_matrix(columns=['antecedents','consequents','confidence']))
#print (rules[{'antecedents','consequents','confidence'}])
# Out:
#       support                                           itemsets
# 0    0.263509                                     (all- purpose)
# 1    0.264176                                    (aluminum foil)
# 2    0.278185                                           (bagels)
# 3    0.262842                                             (beef)
# 4    0.261508                                           (butter)
# 5    0.273516                                          (cereals)
# 6    0.260173                                          (cheeses)
# 7    0.262842                                       (coffee/tea)
# 8    0.258839                                     (dinner rolls)
# 9    0.268179                     (dishwashing liquid/detergent)
# 10   0.268846                                             (eggs)
# 11   0.257505                                            (flour)
# 12   0.263509                                           (fruits)
# 13   0.237492                                        (hand soap)
# 14   0.274850                                        (ice cream)
# 15   0.271514                                 (individual meals)
# 16   0.257505                                            (juice)
# 17   0.250167                                          (ketchup)
# 18   0.264176                                (laundry detergent)
# 19   0.276184                                       (lunch meat)
# 20   0.270847                                             (milk)
# 21   0.273516                                            (mixes)
# 22   0.254837                                     (paper towels)
# 23   0.271514                                            (pasta)
# 24   0.250167                                             (pork)
# 25   0.287525                                          (poultry)
# 26   0.250167                                    (sandwich bags)
# 27   0.248833                                  (sandwich loaves)
# 28   0.248165                                          (shampoo)
# 29   0.265510                                             (soap)
# ..        ...                                                ...
# 741  0.050033                 (all- purpose, yogurt, vegetables)
# 742  0.050033             (ice cream, aluminum foil, vegetables)
# 743  0.053369                  (aluminum foil, soda, vegetables)
# 744  0.052035  (bagels, dishwashing liquid/detergent, vegetab...
# 745  0.052035                         (bagels, eggs, vegetables)
# 746  0.050033              (butter, sandwich loaves, vegetables)
# 747  0.054703           (cereals, laundry detergent, vegetables)
# 748  0.052702                     (poultry, cereals, vegetables)
# 749  0.050033                       (sugar, cereals, vegetables)
# 750  0.050033           (cheeses, laundry detergent, vegetables)
# 751  0.050700                      (cheeses, yogurt, vegetables)
# 752  0.051368                 (vegetables, yogurt, dinner rolls)
# 753  0.054036  (fruits, dishwashing liquid/detergent, vegetab...
# 754  0.050700  (individual meals, dishwashing liquid/detergen...
# 755  0.050700  (dishwashing liquid/detergent, laundry deterge...
# 756  0.054703  (poultry, dishwashing liquid/detergent, vegeta...
# 757  0.050700              (eggs, laundry detergent, vegetables)
# 758  0.050033             (flour, laundry detergent, vegetables)
# 759  0.050033         (ice cream, laundry detergent, vegetables)
# 760  0.050033            (poultry, individual meals, vegetables)
# 761  0.051368                        (yogurt, juice, vegetables)
# 762  0.050033              (laundry detergent, milk, vegetables)
# 763  0.052702                  (poultry, lunch meat, vegetables)
# 764  0.055370                    (sugar, lunch meat, vegetables)
# 765  0.050700                  (lunch meat, waffles, vegetables)
# 766  0.054036                         (yogurt, milk, vegetables)
# 767  0.056704                       (poultry, mixes, vegetables)
# 768  0.055370                         (soda, yogurt, vegetables)
# 769  0.050033                        (sugar, yogurt, vegetables)
# 770  0.052035                      (yogurt, waffles, vegetables)
#
# [771 rows x 2 columns]
# [[frozenset({'cereals', 'laundry detergent'}) frozenset({'vegetables'})
#   0.7387387387387387]
#  [frozenset({'cheeses', 'laundry detergent'}) frozenset({'vegetables'})
#   0.7142857142857142]
#  [frozenset({'cheeses', 'yogurt'}) frozenset({'vegetables'})
#   0.7169811320754716]
#  [frozenset({'flour', 'laundry detergent'}) frozenset({'vegetables'})
#   0.7009345794392522]
#  [frozenset({'ice cream', 'laundry detergent'}) frozenset({'vegetables'})
#   0.7211538461538461]
#  [frozenset({'sugar', 'lunch meat'}) frozenset({'vegetables'})
#   0.7155172413793103]]

# %% [markdown]
# ## *STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.*

# %% [markdown]
# # EXERCISE: FP-Growth

# %% [markdown]
# ## Rules  generation

# %%
#Install the library if it is not available
#!pip install pyfpgrowth
import pyfpgrowth
MIN_SUPPORT = 2 
MIN_CONFIDENCE = 0.7
DATASET = [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]

frequent_itemsets = pyfpgrowth.find_frequent_patterns(DATASET, MIN_SUPPORT)
print('Support values for candidate itemsets:\n', frequent_itemsets, '\n')
rules = pyfpgrowth.generate_association_rules(frequent_itemsets, MIN_CONFIDENCE)
print('Resultant assoication rules:\n')
pprint.pprint(rules)
# Out:
# Support values for candidate itemsets:
#  {('A',): 2, ('A', 'C'): 2, ('C',): 3, ('B', 'C'): 2, ('B',): 3, ('E',): 3, ('C', 'E'): 2, ('B', 'E'): 3, ('B', 'C', 'E'): 2}
#
# Resultant assoication rules:
#
# {('A',): (('C',), 1.0),
#  ('B',): (('E',), 1.0),
#  ('B', 'C'): (('E',), 1.0),
#  ('C', 'E'): (('B',), 1.0),
#  ('E',): (('B',), 1.0)}

# %% [markdown]
# ### TODO Mining association rules using FP-growth  on Groceries datasets
# * Try different confidence thresholds
# * What’s a reasonable value for real data?

# %%
MIN_SUPPORT = 0.05 * len(data_list)
frequent_itemsets = pyfpgrowth.find_frequent_patterns(data_list, MIN_SUPPORT)
print('Support values for candidate itemsets:\n')
pprint.pprint(frequent_itemsets) 
rules = pyfpgrowth.generate_association_rules(frequent_itemsets, MIN_CONFIDENCE)
print('Resultant assoication rules:\n')
pprint.pprint(rules)
# Out:
# Support values for candidate itemsets:
#
# {('all- purpose', 'aluminum foil'): 120,
#  ('all- purpose', 'aluminum foil', 'vegetables'): 100,
#  ('all- purpose', 'bagels'): 149,
#  ('all- purpose', 'bagels', 'vegetables'): 114,
#  ('all- purpose', 'beef'): 135,
#  ('all- purpose', 'beef', 'vegetables'): 110,
#  ('all- purpose', 'butter'): 127,
#  ('all- purpose', 'butter', 'vegetables'): 101,
#  ('all- purpose', 'cereals'): 119,
#  ('all- purpose', 'cereals', 'vegetables'): 114,
#  ('all- purpose', 'cheeses'): 122,
#  ('all- purpose', 'cheeses', 'vegetables'): 109,
#  ('all- purpose', 'coffee/tea'): 131,
#  ('all- purpose', 'coffee/tea', 'vegetables'): 118,
#  ('all- purpose', 'dinner rolls'): 130,
#  ('all- purpose', 'dinner rolls', 'vegetables'): 113,
#  ('all- purpose', 'dishwashing liquid/detergent'): 140,
#  ('all- purpose', 'dishwashing liquid/detergent', 'vegetables'): 115,
#  ('all- purpose', 'eggs'): 144,
#  ('all- purpose', 'eggs', 'vegetables'): 107,
#  ('all- purpose', 'flour'): 149,
#  ('all- purpose', 'flour', 'vegetables'): 122,
#  ('all- purpose', 'fruits'): 155,
#  ('all- purpose', 'fruits', 'vegetables'): 130,
#  ('all- purpose', 'hand soap'): 127,
#  ('all- purpose', 'hand soap', 'vegetables'): 107,
#  ('all- purpose', 'ice cream'): 133,
#  ('all- purpose', 'ice cream', 'vegetables'): 107,
#  ('all- purpose', 'individual meals'): 133,
#  ('all- purpose', 'individual meals', 'vegetables'): 106,
#  ('all- purpose', 'juice'): 134,
#  ('all- purpose', 'juice', 'vegetables'): 113,
#  ('all- purpose', 'ketchup'): 132,
#  ('all- purpose', 'ketchup', 'vegetables'): 105,
#  ('all- purpose', 'laundry detergent'): 137,
#  ('all- purpose', 'laundry detergent', 'vegetables'): 120,
#  ('all- purpose', 'lunch meat'): 135,
#  ('all- purpose', 'lunch meat', 'vegetables'): 99,
#  ('all- purpose', 'milk'): 142,
#  ('all- purpose', 'milk', 'vegetables'): 122,
#  ('all- purpose', 'mixes'): 140,
#  ('all- purpose', 'mixes', 'vegetables'): 105,
#  ('all- purpose', 'paper towels'): 128,
#  ('all- purpose', 'paper towels', 'vegetables'): 108,
#  ('all- purpose', 'pasta'): 133,
#  ('all- purpose', 'pasta', 'vegetables'): 96,
#  ('all- purpose', 'pork'): 131,
#  ('all- purpose', 'pork', 'vegetables'): 105,
#  ('all- purpose', 'poultry'): 146,
#  ('all- purpose', 'poultry', 'vegetables'): 122,
#  ('all- purpose', 'sandwich bags'): 126,
#  ('all- purpose', 'sandwich bags', 'vegetables'): 96,
#  ('all- purpose', 'sandwich loaves'): 133,
#  ('all- purpose', 'sandwich loaves', 'vegetables'): 99,
#  ('all- purpose', 'shampoo'): 132,
#  ('all- purpose', 'shampoo', 'vegetables'): 104,
#  ('all- purpose', 'soap'): 139,
#  ('all- purpose', 'soap', 'vegetables'): 99,
#  ('all- purpose', 'soda'): 128,
#  ('all- purpose', 'soda', 'vegetables'): 128,
#  ('all- purpose', 'spaghetti sauce'): 131,
#  ('all- purpose', 'spaghetti sauce', 'vegetables'): 102,
#  ('all- purpose', 'sugar'): 143,
#  ('all- purpose', 'sugar', 'vegetables'): 112,
#  ('all- purpose', 'toilet paper'): 144,
#  ('all- purpose', 'toilet paper', 'vegetables'): 119,
#  ('all- purpose', 'tortillas'): 128,
#  ('all- purpose', 'tortillas', 'vegetables'): 89,
#  ('all- purpose', 'vegetables'): 382,
#  ('all- purpose', 'vegetables', 'vegetables'): 151,
#  ('all- purpose', 'vegetables', 'waffles'): 133,
#  ('all- purpose', 'vegetables', 'yogurt'): 141,
#  ('all- purpose', 'waffles'): 148,
#  ('all- purpose', 'yogurt'): 142,
#  ('aluminum foil', 'bagels'): 149,
#  ('aluminum foil', 'bagels', 'vegetables'): 152,
#  ('aluminum foil', 'beef'): 140,
#  ('aluminum foil', 'beef', 'vegetables'): 118,
#  ('aluminum foil', 'butter'): 148,
#  ('aluminum foil', 'butter', 'vegetables'): 127,
#  ('aluminum foil', 'cereals'): 145,
#  ('aluminum foil', 'cereals', 'vegetables'): 122,
#  ('aluminum foil', 'cheeses'): 145,
#  ('aluminum foil', 'cheeses', 'vegetables'): 144,
#  ('aluminum foil', 'coffee/tea'): 135,
#  ('aluminum foil', 'coffee/tea', 'vegetables'): 117,
#  ('aluminum foil', 'dinner rolls'): 148,
#  ('aluminum foil', 'dinner rolls', 'vegetables'): 144,
#  ('aluminum foil', 'dishwashing liquid/detergent'): 133,
#  ('aluminum foil', 'dishwashing liquid/detergent', 'vegetables'): 118,
#  ('aluminum foil', 'eggs'): 126,
#  ('aluminum foil', 'eggs', 'vegetables'): 108,
#  ('aluminum foil', 'flour'): 131,
#  ('aluminum foil', 'flour', 'vegetables'): 119,
#  ('aluminum foil', 'fruits'): 145,
#  ('aluminum foil', 'fruits', 'vegetables'): 124,
#  ('aluminum foil', 'hand soap'): 111,
#  ('aluminum foil', 'hand soap', 'vegetables'): 101,
#  ('aluminum foil', 'ice cream'): 156,
#  ('aluminum foil', 'ice cream', 'vegetables'): 144,
#  ('aluminum foil', 'individual meals'): 162,
#  ('aluminum foil', 'individual meals', 'vegetables'): 128,
#  ('aluminum foil', 'juice'): 146,
#  ('aluminum foil', 'juice', 'vegetables'): 132,
#  ('aluminum foil', 'ketchup'): 127,
#  ('aluminum foil', 'ketchup', 'vegetables'): 108,
#  ('aluminum foil', 'laundry detergent'): 140,
#  ('aluminum foil', 'laundry detergent', 'vegetables'): 129,
#  ('aluminum foil', 'lunch meat'): 133,
#  ('aluminum foil', 'lunch meat', 'vegetables'): 130,
#  ('aluminum foil', 'milk'): 142,
#  ('aluminum foil', 'milk', 'vegetables'): 120,
#  ('aluminum foil', 'mixes'): 138,
#  ('aluminum foil', 'mixes', 'vegetables'): 125,
#  ('aluminum foil', 'paper towels'): 135,
#  ('aluminum foil', 'paper towels', 'vegetables'): 131,
#  ('aluminum foil', 'pasta'): 144,
#  ('aluminum foil', 'pasta', 'vegetables'): 111,
#  ('aluminum foil', 'pork'): 137,
#  ('aluminum foil', 'pork', 'vegetables'): 108,
#  ('aluminum foil', 'poultry'): 153,
#  ('aluminum foil', 'poultry', 'vegetables'): 135,
#  ('aluminum foil', 'sandwich bags'): 126,
#  ('aluminum foil', 'sandwich bags', 'vegetables'): 95,
#  ('aluminum foil', 'sandwich loaves'): 132,
#  ('aluminum foil', 'sandwich loaves', 'vegetables'): 110,
#  ('aluminum foil', 'shampoo'): 132,
#  ('aluminum foil', 'shampoo', 'vegetables'): 117,
#  ('aluminum foil', 'soda'): 160,
#  ('aluminum foil', 'soda', 'vegetables'): 167,
#  ('aluminum foil', 'spaghetti sauce'): 123,
#  ('aluminum foil', 'spaghetti sauce', 'vegetables'): 120,
#  ('aluminum foil', 'sugar'): 133,
#  ('aluminum foil', 'sugar', 'vegetables'): 124,
#  ('aluminum foil', 'toilet paper'): 142,
#  ('aluminum foil', 'toilet paper', 'vegetables'): 134,
#  ('aluminum foil', 'tortillas'): 114,
#  ('aluminum foil', 'tortillas', 'vegetables'): 103,
#  ('aluminum foil', 'vegetables'): 432,
#  ('aluminum foil', 'vegetables', 'vegetables'): 209,
#  ('aluminum foil', 'vegetables', 'waffles'): 147,
#  ('aluminum foil', 'vegetables', 'yogurt'): 139,
#  ('aluminum foil', 'waffles'): 143,
#  ('aluminum foil', 'yogurt'): 140,
#  ('bagels', 'bagels'): 78,
#  ('bagels', 'beef'): 144,
#  ('bagels', 'beef', 'vegetables'): 114,
#  ('bagels', 'butter'): 156,
#  ('bagels', 'butter', 'vegetables'): 133,
#  ('bagels', 'cereals'): 136,
#  ('bagels', 'cereals', 'vegetables'): 115,
#  ('bagels', 'cheeses'): 145,
#  ('bagels', 'cheeses', 'vegetables'): 106,
#  ('bagels', 'coffee/tea'): 163,
#  ('bagels', 'coffee/tea', 'vegetables'): 136,
#  ('bagels', 'dinner rolls'): 130,
#  ('bagels', 'dinner rolls', 'vegetables'): 106,
#  ('bagels', 'dishwashing liquid/detergent'): 154,
#  ('bagels', 'dishwashing liquid/detergent', 'vegetables'): 142,
#  ('bagels', 'eggs'): 154,
#  ('bagels', 'eggs', 'vegetables'): 138,
#  ('bagels', 'flour'): 114,
#  ('bagels', 'flour', 'vegetables'): 93,
#  ('bagels', 'fruits'): 155,
#  ('bagels', 'fruits', 'vegetables'): 123,
#  ('bagels', 'hand soap'): 129,
#  ('bagels', 'hand soap', 'vegetables'): 101,
#  ('bagels', 'ice cream'): 159,
#  ('bagels', 'ice cream', 'vegetables'): 124,
#  ('bagels', 'individual meals'): 143,
#  ('bagels', 'individual meals', 'vegetables'): 110,
#  ('bagels', 'juice'): 126,
#  ('bagels', 'juice', 'vegetables'): 117,
#  ('bagels', 'ketchup'): 111,
#  ('bagels', 'ketchup', 'vegetables'): 93,
#  ('bagels', 'laundry detergent'): 155,
#  ('bagels', 'laundry detergent', 'vegetables'): 132,
#  ('bagels', 'lunch meat'): 145,
#  ('bagels', 'lunch meat', 'vegetables'): 134,
#  ('bagels', 'milk'): 146,
#  ('bagels', 'milk', 'vegetables'): 110,
#  ('bagels', 'mixes'): 177,
#  ('bagels', 'mixes', 'vegetables'): 150,
#  ('bagels', 'paper towels'): 141,
#  ('bagels', 'paper towels', 'vegetables'): 114,
#  ('bagels', 'pasta'): 146,
#  ('bagels', 'pasta', 'vegetables'): 126,
#  ('bagels', 'pork'): 135,
#  ('bagels', 'pork', 'vegetables'): 133,
#  ('bagels', 'poultry'): 158,
#  ('bagels', 'poultry', 'vegetables'): 137,
#  ('bagels', 'sandwich bags'): 157,
#  ('bagels', 'sandwich bags', 'vegetables'): 108,
#  ('bagels', 'sandwich loaves'): 138,
#  ('bagels', 'sandwich loaves', 'vegetables'): 94,
#  ('bagels', 'shampoo'): 145,
#  ('bagels', 'shampoo', 'vegetables'): 115,
#  ('bagels', 'soap'): 151,
#  ('bagels', 'soap', 'vegetables'): 118,
#  ('bagels', 'soda'): 150,
#  ('bagels', 'soda', 'vegetables'): 133,
#  ('bagels', 'spaghetti sauce'): 151,
#  ('bagels', 'spaghetti sauce', 'vegetables'): 130,
#  ('bagels', 'sugar'): 132,
#  ('bagels', 'sugar', 'vegetables'): 109,
#  ('bagels', 'toilet paper'): 152,
#  ('bagels', 'toilet paper', 'vegetables'): 124,
#  ('bagels', 'tortillas'): 156,
#  ('bagels', 'tortillas', 'vegetables'): 139,
#  ('bagels', 'vegetables'): 426,
#  ('bagels', 'vegetables', 'vegetables'): 180,
#  ('bagels', 'vegetables', 'waffles'): 153,
#  ('bagels', 'vegetables', 'yogurt'): 123,
#  ('bagels', 'waffles'): 148,
#  ('bagels', 'yogurt'): 131,
#  ('beef', 'butter'): 114,
#  ('beef', 'butter', 'vegetables'): 92,
#  ('beef', 'cereals'): 146,
#  ('beef', 'cereals', 'vegetables'): 116,
#  ('beef', 'cheeses'): 125,
#  ('beef', 'cheeses', 'vegetables'): 102,
#  ('beef', 'coffee/tea'): 131,
#  ('beef', 'coffee/tea', 'vegetables'): 111,
#  ('beef', 'dinner rolls'): 133,
#  ('beef', 'dinner rolls', 'vegetables'): 115,
#  ('beef', 'dishwashing liquid/detergent'): 137,
#  ('beef', 'dishwashing liquid/detergent', 'vegetables'): 116,
#  ('beef', 'eggs'): 135,
#  ('beef', 'eggs', 'vegetables'): 114,
#  ('beef', 'flour'): 126,
#  ('beef', 'flour', 'vegetables'): 106,
#  ('beef', 'fruits'): 154,
#  ('beef', 'fruits', 'vegetables'): 119,
#  ('beef', 'hand soap'): 98,
#  ('beef', 'hand soap', 'vegetables'): 81,
#  ('beef', 'ice cream'): 147,
#  ('beef', 'ice cream', 'vegetables'): 120,
#  ('beef', 'individual meals'): 144,
#  ('beef', 'individual meals', 'vegetables'): 129,
#  ('beef', 'juice'): 118,
#  ('beef', 'juice', 'vegetables'): 102,
#  ('beef', 'ketchup'): 126,
#  ('beef', 'ketchup', 'vegetables'): 116,
#  ('beef', 'laundry detergent'): 141,
#  ('beef', 'laundry detergent', 'vegetables'): 119,
#  ('beef', 'lunch meat'): 149,
#  ('beef', 'lunch meat', 'vegetables'): 132,
#  ('beef', 'milk'): 135,
#  ('beef', 'milk', 'vegetables'): 105,
#  ('beef', 'mixes'): 149,
#  ('beef', 'mixes', 'vegetables'): 98,
#  ('beef', 'paper towels'): 132,
#  ('beef', 'paper towels', 'vegetables'): 94,
#  ('beef', 'pasta'): 119,
#  ('beef', 'pasta', 'vegetables'): 78,
#  ('beef', 'pork'): 147,
#  ('beef', 'pork', 'vegetables'): 118,
#  ('beef', 'poultry'): 167,
#  ('beef', 'poultry', 'vegetables'): 127,
#  ('beef', 'sandwich bags'): 146,
#  ('beef', 'sandwich bags', 'vegetables'): 92,
#  ('beef', 'sandwich loaves'): 127,
#  ('beef', 'sandwich loaves', 'vegetables'): 102,
#  ('beef', 'shampoo'): 148,
#  ('beef', 'shampoo', 'vegetables'): 110,
#  ('beef', 'soap'): 122,
#  ('beef', 'soap', 'vegetables'): 83,
#  ('beef', 'soda'): 144,
#  ('beef', 'soda', 'vegetables'): 103,
#  ('beef', 'spaghetti sauce'): 130,
#  ('beef', 'spaghetti sauce', 'vegetables'): 100,
#  ('beef', 'sugar'): 139,
#  ('beef', 'sugar', 'vegetables'): 113,
#  ('beef', 'toilet paper'): 141,
#  ('beef', 'toilet paper', 'vegetables'): 98,
#  ('beef', 'tortillas'): 114,
#  ('beef', 'tortillas', 'vegetables'): 96,
#  ('beef', 'vegetables'): 384,
#  ('beef', 'vegetables', 'vegetables'): 167,
#  ('beef', 'vegetables', 'waffles'): 130,
#  ('beef', 'vegetables', 'yogurt'): 130,
#  ('beef', 'waffles'): 155,
#  ('beef', 'yogurt'): 141,
#  ('butter', 'butter'): 84,
#  ('butter', 'cereals'): 122,
#  ('butter', 'cereals', 'vegetables'): 107,
#  ('butter', 'cheeses'): 129,
#  ('butter', 'cheeses', 'vegetables'): 112,
#  ('butter', 'coffee/tea'): 128,
#  ('butter', 'coffee/tea', 'vegetables'): 122,
#  ('butter', 'dinner rolls'): 147,
#  ('butter', 'dinner rolls', 'vegetables'): 140,
#  ('butter', 'dishwashing liquid/detergent'): 136,
#  ('butter', 'dishwashing liquid/detergent', 'vegetables'): 110,
#  ('butter', 'eggs'): 133,
#  ('butter', 'eggs', 'vegetables'): 124,
#  ('butter', 'flour'): 130,
#  ('butter', 'flour', 'vegetables'): 136,
#  ('butter', 'fruits'): 131,
#  ('butter', 'fruits', 'vegetables'): 102,
#  ('butter', 'hand soap'): 126,
#  ('butter', 'hand soap', 'vegetables'): 111,
#  ('butter', 'ice cream'): 137,
#  ('butter', 'ice cream', 'vegetables'): 122,
#  ('butter', 'individual meals'): 143,
#  ('butter', 'individual meals', 'vegetables'): 115,
#  ('butter', 'juice'): 144,
#  ('butter', 'juice', 'vegetables'): 136,
#  ('butter', 'ketchup'): 130,
#  ('butter', 'ketchup', 'vegetables'): 107,
#  ('butter', 'laundry detergent'): 141,
#  ('butter', 'laundry detergent', 'vegetables'): 124,
#  ('butter', 'lunch meat'): 151,
#  ('butter', 'lunch meat', 'vegetables'): 125,
#  ('butter', 'milk'): 142,
#  ('butter', 'milk', 'vegetables'): 126,
#  ('butter', 'mixes'): 155,
#  ('butter', 'mixes', 'vegetables'): 146,
#  ('butter', 'paper towels'): 146,
#  ('butter', 'paper towels', 'vegetables'): 130,
#  ('butter', 'pork'): 120,
#  ('butter', 'pork', 'vegetables'): 104,
#  ('butter', 'poultry'): 155,
#  ('butter', 'poultry', 'vegetables'): 163,
#  ('butter', 'sandwich bags'): 130,
#  ('butter', 'sandwich bags', 'vegetables'): 95,
#  ('butter', 'sandwich loaves'): 156,
#  ('butter', 'sandwich loaves', 'vegetables'): 141,
#  ('butter', 'shampoo'): 133,
#  ('butter', 'shampoo', 'vegetables'): 100,
#  ('butter', 'soap'): 142,
#  ('butter', 'soap', 'vegetables'): 106,
#  ('butter', 'soda'): 156,
#  ('butter', 'soda', 'vegetables'): 109,
#  ('butter', 'spaghetti sauce'): 137,
#  ('butter', 'spaghetti sauce', 'vegetables'): 145,
#  ('butter', 'sugar'): 132,
#  ('butter', 'sugar', 'vegetables'): 104,
#  ('butter', 'toilet paper'): 157,
#  ('butter', 'toilet paper', 'vegetables'): 123,
#  ('butter', 'tortillas'): 127,
#  ('butter', 'tortillas', 'vegetables'): 121,
#  ('butter', 'vegetables'): 421,
#  ('butter', 'vegetables', 'vegetables'): 186,
#  ('butter', 'vegetables', 'waffles'): 129,
#  ('butter', 'vegetables', 'yogurt'): 98,
#  ('butter', 'waffles'): 129,
#  ('butter', 'yogurt'): 125,
#  ('cereals', 'cereals'): 82,
#  ('cereals', 'cheeses'): 136,
#  ('cereals', 'cheeses', 'vegetables'): 117,
#  ('cereals', 'coffee/tea'): 135,
#  ('cereals', 'coffee/tea', 'vegetables'): 124,
#  ('cereals', 'dinner rolls'): 139,
#  ('cereals', 'dinner rolls', 'vegetables'): 119,
#  ('cereals', 'dishwashing liquid/detergent'): 139,
#  ('cereals', 'dishwashing liquid/detergent', 'vegetables'): 117,
#  ('cereals', 'eggs'): 147,
#  ('cereals', 'eggs', 'vegetables'): 139,
#  ('cereals', 'flour'): 135,
#  ('cereals', 'flour', 'vegetables'): 129,
#  ('cereals', 'fruits'): 153,
#  ('cereals', 'fruits', 'vegetables'): 111,
#  ('cereals', 'hand soap'): 133,
#  ('cereals', 'hand soap', 'vegetables'): 119,
#  ('cereals', 'ice cream'): 154,
#  ('cereals', 'ice cream', 'vegetables'): 127,
#  ('cereals', 'individual meals'): 164,
#  ('cereals', 'individual meals', 'vegetables'): 127,
#  ('cereals', 'juice'): 136,
#  ('cereals', 'juice', 'vegetables'): 106,
#  ('cereals', 'ketchup'): 115,
#  ('cereals', 'ketchup', 'vegetables'): 102,
#  ('cereals', 'laundry detergent'): 145,
#  ('cereals', 'laundry detergent', 'vegetables'): 150,
#  ('cereals', 'lunch meat'): 146,
#  ('cereals', 'lunch meat', 'vegetables'): 136,
#  ('cereals', 'milk'): 161,
#  ('cereals', 'milk', 'vegetables'): 120,
#  ('cereals', 'mixes'): 156,
#  ('cereals', 'mixes', 'vegetables'): 120,
#  ('cereals', 'paper towels'): 168,
#  ('cereals', 'paper towels', 'vegetables'): 144,
#  ('cereals', 'pasta'): 142,
#  ('cereals', 'pasta', 'vegetables'): 120,
#  ('cereals', 'pork'): 123,
#  ('cereals', 'pork', 'vegetables'): 95,
#  ('cereals', 'poultry'): 170,
#  ('cereals', 'poultry', 'vegetables'): 137,
#  ('cereals', 'sandwich bags'): 152,
#  ('cereals', 'sandwich bags', 'vegetables'): 114,
#  ('cereals', 'sandwich loaves'): 135,
#  ('cereals', 'sandwich loaves', 'vegetables'): 89,
#  ('cereals', 'shampoo'): 138,
#  ('cereals', 'shampoo', 'vegetables'): 119,
#  ('cereals', 'soap'): 148,
#  ('cereals', 'soap', 'vegetables'): 119,
#  ('cereals', 'soda'): 155,
#  ('cereals', 'soda', 'vegetables'): 138,
#  ('cereals', 'spaghetti sauce'): 163,
#  ('cereals', 'spaghetti sauce', 'vegetables'): 137,
#  ('cereals', 'sugar'): 151,
#  ('cereals', 'sugar', 'vegetables'): 137,
#  ('cereals', 'toilet paper'): 141,
#  ('cereals', 'toilet paper', 'vegetables'): 136,
#  ('cereals', 'tortillas'): 127,
#  ('cereals', 'tortillas', 'vegetables'): 110,
#  ('cereals', 'vegetables'): 425,
#  ('cereals', 'vegetables', 'vegetables'): 154,
#  ('cereals', 'vegetables', 'waffles'): 114,
#  ('cereals', 'vegetables', 'yogurt'): 131,
#  ('cereals', 'waffles'): 130,
#  ('cereals', 'yogurt'): 145,
#  ('cheeses', 'dinner rolls'): 143,
#  ('cheeses', 'dinner rolls', 'vegetables'): 131,
#  ('cheeses', 'dishwashing liquid/detergent'): 131,
#  ('cheeses', 'dishwashing liquid/detergent', 'vegetables'): 121,
#  ('cheeses', 'eggs'): 139,
#  ('cheeses', 'eggs', 'vegetables'): 132,
#  ('cheeses', 'flour'): 161,
#  ('cheeses', 'flour', 'vegetables'): 154,
#  ('cheeses', 'fruits'): 150,
#  ('cheeses', 'fruits', 'vegetables'): 151,
#  ('cheeses', 'hand soap'): 128,
#  ('cheeses', 'hand soap', 'vegetables'): 122,
#  ('cheeses', 'ice cream'): 131,
#  ('cheeses', 'ice cream', 'vegetables'): 123,
#  ('cheeses', 'individual meals'): 151,
#  ('cheeses', 'individual meals', 'vegetables'): 130,
#  ('cheeses', 'juice'): 98,
#  ('cheeses', 'juice', 'vegetables'): 90,
#  ('cheeses', 'ketchup'): 108,
#  ('cheeses', 'ketchup', 'vegetables'): 106,
#  ('cheeses', 'lunch meat'): 139,
#  ('cheeses', 'lunch meat', 'vegetables'): 118,
#  ('cheeses', 'milk'): 110,
#  ('cheeses', 'milk', 'vegetables'): 108,
#  ('cheeses', 'mixes'): 138,
#  ('cheeses', 'mixes', 'vegetables'): 127,
#  ('cheeses', 'paper towels'): 125,
#  ('cheeses', 'paper towels', 'vegetables'): 80,
#  ('cheeses', 'pasta'): 135,
#  ('cheeses', 'pasta', 'vegetables'): 103,
#  ('cheeses', 'pork'): 147,
#  ('cheeses', 'pork', 'vegetables'): 109,
#  ('cheeses', 'poultry'): 163,
#  ('cheeses', 'poultry', 'vegetables'): 149,
#  ('cheeses', 'sandwich bags'): 163,
#  ('cheeses', 'sandwich bags', 'vegetables'): 124,
#  ('cheeses', 'sandwich loaves'): 121,
#  ('cheeses', 'sandwich loaves', 'vegetables'): 88,
#  ('cheeses', 'shampoo'): 104,
#  ('cheeses', 'shampoo', 'vegetables'): 86,
#  ('cheeses', 'soap'): 151,
#  ('cheeses', 'soap', 'vegetables'): 107,
#  ('cheeses', 'soda'): 132,
#  ('cheeses', 'soda', 'vegetables'): 114,
#  ('cheeses', 'spaghetti sauce'): 158,
#  ('cheeses', 'spaghetti sauce', 'vegetables'): 142,
#  ('cheeses', 'sugar'): 131,
#  ('cheeses', 'sugar', 'vegetables'): 111,
#  ('cheeses', 'toilet paper'): 152,
#  ('cheeses', 'toilet paper', 'vegetables'): 135,
#  ('cheeses', 'tortillas'): 119,
#  ('cheeses', 'tortillas', 'vegetables'): 105,
#  ('cheeses', 'vegetables'): 427,
#  ('cheeses', 'vegetables', 'vegetables'): 206,
#  ('cheeses', 'vegetables', 'waffles'): 135,
#  ('cheeses', 'vegetables', 'yogurt'): 148,
#  ('cheeses', 'waffles'): 152,
#  ('cheeses', 'yogurt'): 144,
#  ('coffee/tea', 'dinner rolls'): 143,
#  ('coffee/tea', 'dinner rolls', 'vegetables'): 139,
#  ('coffee/tea', 'dishwashing liquid/detergent'): 124,
#  ('coffee/tea', 'dishwashing liquid/detergent', 'vegetables'): 113,
#  ('coffee/tea', 'eggs'): 124,
#  ('coffee/tea', 'eggs', 'vegetables'): 125,
#  ('coffee/tea', 'flour'): 116,
#  ('coffee/tea', 'flour', 'vegetables'): 129,
#  ('coffee/tea', 'fruits'): 113,
#  ('coffee/tea', 'fruits', 'vegetables'): 93,
#  ('coffee/tea', 'hand soap'): 126,
#  ('coffee/tea', 'hand soap', 'vegetables'): 113,
#  ('coffee/tea', 'ice cream'): 144,
#  ('coffee/tea', 'ice cream', 'vegetables'): 122,
#  ('coffee/tea', 'individual meals'): 149,
#  ('coffee/tea', 'individual meals', 'vegetables'): 141,
#  ('coffee/tea', 'juice'): 142,
#  ('coffee/tea', 'juice', 'vegetables'): 156,
#  ('coffee/tea', 'ketchup'): 138,
#  ('coffee/tea', 'ketchup', 'vegetables'): 139,
#  ('coffee/tea', 'lunch meat'): 124,
#  ('coffee/tea', 'lunch meat', 'vegetables'): 102,
#  ('coffee/tea', 'milk'): 142,
#  ('coffee/tea', 'milk', 'vegetables'): 134,
#  ('coffee/tea', 'mixes'): 145,
#  ('coffee/tea', 'mixes', 'vegetables'): 135,
#  ('coffee/tea', 'paper towels'): 129,
#  ('coffee/tea', 'paper towels', 'vegetables'): 116,
#  ('coffee/tea', 'pasta'): 136,
#  ('coffee/tea', 'pasta', 'vegetables'): 130,
#  ('coffee/tea', 'pork'): 143,
#  ('coffee/tea', 'pork', 'vegetables'): 133,
#  ('coffee/tea', 'poultry'): 155,
#  ('coffee/tea', 'poultry', 'vegetables'): 139,
#  ('coffee/tea', 'sandwich bags'): 117,
#  ('coffee/tea', 'sandwich bags', 'vegetables'): 94,
#  ('coffee/tea', 'sandwich loaves'): 134,
#  ('coffee/tea', 'sandwich loaves', 'vegetables'): 117,
#  ('coffee/tea', 'shampoo'): 123,
#  ('coffee/tea', 'shampoo', 'vegetables'): 101,
#  ('coffee/tea', 'soap'): 118,
#  ('coffee/tea', 'soap', 'vegetables'): 87,
#  ('coffee/tea', 'soda'): 130,
#  ('coffee/tea', 'soda', 'vegetables'): 106,
#  ('coffee/tea', 'spaghetti sauce'): 110,
#  ('coffee/tea', 'spaghetti sauce', 'vegetables'): 106,
#  ('coffee/tea', 'sugar'): 124,
#  ('coffee/tea', 'sugar', 'vegetables'): 117,
#  ('coffee/tea', 'toilet paper'): 139,
#  ('coffee/tea', 'toilet paper', 'vegetables'): 117,
#  ('coffee/tea', 'tortillas'): 139,
#  ('coffee/tea', 'tortillas', 'vegetables'): 137,
#  ('coffee/tea', 'vegetables'): 425,
#  ('coffee/tea', 'vegetables', 'vegetables'): 196,
#  ('coffee/tea', 'vegetables', 'waffles'): 110,
#  ('coffee/tea', 'vegetables', 'yogurt'): 129,
#  ('coffee/tea', 'waffles'): 135,
#  ('coffee/tea', 'yogurt'): 121,
#  ('dinner rolls', 'dishwashing liquid/detergent'): 123,
#  ('dinner rolls', 'dishwashing liquid/detergent', 'vegetables'): 113,
#  ('dinner rolls', 'eggs'): 145,
#  ('dinner rolls', 'eggs', 'vegetables'): 132,
#  ('dinner rolls', 'flour'): 118,
#  ('dinner rolls', 'flour', 'vegetables'): 109,
#  ('dinner rolls', 'fruits'): 128,
#  ('dinner rolls', 'fruits', 'vegetables'): 126,
#  ('dinner rolls', 'hand soap'): 105,
#  ('dinner rolls', 'hand soap', 'vegetables'): 89,
#  ('dinner rolls', 'ice cream'): 124,
#  ('dinner rolls', 'ice cream', 'vegetables'): 124,
#  ('dinner rolls', 'individual meals'): 124,
#  ('dinner rolls', 'individual meals', 'vegetables'): 98,
#  ('dinner rolls', 'juice'): 117,
#  ('dinner rolls', 'juice', 'vegetables'): 114,
#  ('dinner rolls', 'ketchup'): 119,
#  ('dinner rolls', 'ketchup', 'vegetables'): 91,
#  ('dinner rolls', 'laundry detergent'): 132,
#  ('dinner rolls', 'laundry detergent', 'vegetables'): 126,
#  ('dinner rolls', 'lunch meat'): 140,
#  ('dinner rolls', 'lunch meat', 'vegetables'): 128,
#  ('dinner rolls', 'milk'): 119,
#  ('dinner rolls', 'milk', 'vegetables'): 119,
#  ('dinner rolls', 'mixes'): 142,
#  ('dinner rolls', 'mixes', 'vegetables'): 121,
#  ('dinner rolls', 'paper towels'): 134,
#  ('dinner rolls', 'paper towels', 'vegetables'): 130,
#  ('dinner rolls', 'pasta'): 142,
#  ('dinner rolls', 'pasta', 'vegetables'): 111,
#  ('dinner rolls', 'pork'): 116,
#  ('dinner rolls', 'pork', 'vegetables'): 90,
#  ('dinner rolls', 'poultry'): 144,
#  ('dinner rolls', 'poultry', 'vegetables'): 134,
#  ('dinner rolls', 'sandwich bags'): 107,
#  ('dinner rolls', 'sandwich bags', 'vegetables'): 80,
#  ('dinner rolls', 'sandwich loaves'): 126,
#  ('dinner rolls', 'sandwich loaves', 'vegetables'): 98,
#  ('dinner rolls', 'shampoo'): 133,
#  ('dinner rolls', 'shampoo', 'vegetables'): 108,
#  ('dinner rolls', 'soap'): 130,
#  ('dinner rolls', 'soap', 'vegetables'): 86,
#  ('dinner rolls', 'soda'): 145,
#  ('dinner rolls', 'soda', 'vegetables'): 129,
#  ('dinner rolls', 'spaghetti sauce'): 131,
#  ('dinner rolls', 'spaghetti sauce', 'vegetables'): 101,
#  ('dinner rolls', 'sugar'): 133,
#  ('dinner rolls', 'sugar', 'vegetables'): 118,
#  ('dinner rolls', 'toilet paper'): 132,
#  ('dinner rolls', 'toilet paper', 'vegetables'): 125,
#  ('dinner rolls', 'tortillas'): 135,
#  ('dinner rolls', 'tortillas', 'vegetables'): 134,
#  ('dinner rolls', 'vegetables'): 406,
#  ('dinner rolls', 'vegetables', 'vegetables'): 182,
#  ('dinner rolls', 'vegetables', 'waffles'): 132,
#  ('dinner rolls', 'vegetables', 'yogurt'): 139,
#  ('dinner rolls', 'waffles'): 133,
#  ('dinner rolls', 'yogurt'): 137,
#  ('dishwashing liquid/detergent', 'eggs'): 137,
#  ('dishwashing liquid/detergent', 'eggs', 'vegetables'): 123,
#  ('dishwashing liquid/detergent', 'flour'): 133,
#  ('dishwashing liquid/detergent', 'flour', 'vegetables'): 103,
#  ('dishwashing liquid/detergent', 'fruits'): 161,
#  ('dishwashing liquid/detergent', 'fruits', 'vegetables'): 141,
#  ('dishwashing liquid/detergent', 'hand soap'): 120,
#  ('dishwashing liquid/detergent', 'hand soap', 'vegetables'): 97,
#  ('dishwashing liquid/detergent', 'ice cream'): 148,
#  ('dishwashing liquid/detergent', 'ice cream', 'vegetables'): 133,
#  ('dishwashing liquid/detergent', 'individual meals'): 163,
#  ('dishwashing liquid/detergent', 'individual meals', 'vegetables'): 141,
#  ('dishwashing liquid/detergent', 'juice'): 109,
#  ('dishwashing liquid/detergent', 'juice', 'vegetables'): 90,
#  ('dishwashing liquid/detergent', 'ketchup'): 133,
#  ('dishwashing liquid/detergent', 'ketchup', 'vegetables'): 105,
#  ('dishwashing liquid/detergent', 'laundry detergent'): 138,
#  ('dishwashing liquid/detergent', 'laundry detergent', 'vegetables'): 124,
#  ('dishwashing liquid/detergent', 'lunch meat'): 163,
#  ('dishwashing liquid/detergent', 'lunch meat', 'vegetables'): 130,
#  ('dishwashing liquid/detergent', 'milk'): 134,
#  ('dishwashing liquid/detergent', 'milk', 'vegetables'): 111,
#  ('dishwashing liquid/detergent', 'mixes'): 163,
#  ('dishwashing liquid/detergent', 'mixes', 'vegetables'): 112,
#  ('dishwashing liquid/detergent', 'paper towels'): 121,
#  ('dishwashing liquid/detergent', 'paper towels', 'vegetables'): 95,
#  ('dishwashing liquid/detergent', 'pasta'): 141,
#  ('dishwashing liquid/detergent', 'pasta', 'vegetables'): 105,
#  ('dishwashing liquid/detergent', 'pork'): 111,
#  ('dishwashing liquid/detergent', 'pork', 'vegetables'): 77,
#  ('dishwashing liquid/detergent', 'poultry'): 171,
#  ('dishwashing liquid/detergent', 'poultry', 'vegetables'): 160,
#  ('dishwashing liquid/detergent', 'sandwich bags'): 123,
#  ('dishwashing liquid/detergent', 'sandwich bags', 'vegetables'): 99,
#  ('dishwashing liquid/detergent', 'sandwich loaves'): 100,
#  ('dishwashing liquid/detergent', 'sandwich loaves', 'vegetables'): 97,
#  ('dishwashing liquid/detergent', 'shampoo'): 104,
#  ('dishwashing liquid/detergent', 'shampoo', 'vegetables'): 80,
#  ('dishwashing liquid/detergent', 'soap'): 140,
#  ('dishwashing liquid/detergent', 'soap', 'vegetables'): 120,
#  ('dishwashing liquid/detergent', 'soda'): 129,
#  ('dishwashing liquid/detergent', 'soda', 'vegetables'): 122,
#  ('dishwashing liquid/detergent', 'spaghetti sauce'): 119,
#  ('dishwashing liquid/detergent', 'spaghetti sauce', 'vegetables'): 100,
#  ('dishwashing liquid/detergent', 'sugar'): 147,
#  ('dishwashing liquid/detergent', 'sugar', 'vegetables'): 140,
#  ('dishwashing liquid/detergent', 'toilet paper'): 144,
#  ('dishwashing liquid/detergent', 'toilet paper', 'vegetables'): 124,
#  ('dishwashing liquid/detergent', 'tortillas'): 115,
#  ('dishwashing liquid/detergent', 'tortillas', 'vegetables'): 112,
#  ('dishwashing liquid/detergent', 'vegetables'): 395,
#  ('dishwashing liquid/detergent', 'vegetables', 'vegetables'): 136,
#  ('dishwashing liquid/detergent', 'vegetables', 'waffles'): 130,
#  ('dishwashing liquid/detergent', 'vegetables', 'yogurt'): 124,
#  ('dishwashing liquid/detergent', 'waffles'): 144,
#  ('dishwashing liquid/detergent', 'yogurt'): 130,
#  ('eggs', 'flour'): 130,
#  ('eggs', 'flour', 'vegetables'): 120,
#  ('eggs', 'fruits'): 75,
#  ('eggs', 'hand soap'): 119,
#  ('eggs', 'hand soap', 'vegetables'): 114,
#  ('eggs', 'ice cream'): 132,
#  ('eggs', 'ice cream', 'vegetables'): 89,
#  ('eggs', 'individual meals'): 121,
#  ('eggs', 'individual meals', 'vegetables'): 110,
#  ('eggs', 'juice'): 131,
#  ('eggs', 'juice', 'vegetables'): 133,
#  ('eggs', 'ketchup'): 124,
#  ('eggs', 'ketchup', 'vegetables'): 109,
#  ('eggs', 'laundry detergent'): 145,
#  ('eggs', 'laundry detergent', 'vegetables'): 129,
#  ('eggs', 'lunch meat'): 122,
#  ('eggs', 'lunch meat', 'vegetables'): 102,
#  ('eggs', 'milk'): 128,
#  ('eggs', 'milk', 'vegetables'): 128,
#  ('eggs', 'mixes'): 139,
#  ('eggs', 'mixes', 'vegetables'): 128,
#  ('eggs', 'paper towels'): 142,
#  ('eggs', 'paper towels', 'vegetables'): 134,
#  ('eggs', 'pasta'): 157,
#  ('eggs', 'pasta', 'vegetables'): 118,
#  ('eggs', 'pork'): 123,
#  ('eggs', 'pork', 'vegetables'): 89,
#  ('eggs', 'poultry'): 150,
#  ('eggs', 'poultry', 'vegetables'): 140,
#  ('eggs', 'sandwich bags'): 146,
#  ('eggs', 'sandwich bags', 'vegetables'): 118,
#  ('eggs', 'sandwich loaves'): 114,
#  ('eggs', 'sandwich loaves', 'vegetables'): 101,
#  ('eggs', 'shampoo'): 124,
#  ('eggs', 'shampoo', 'vegetables'): 87,
#  ('eggs', 'soap'): 137,
#  ('eggs', 'soap', 'vegetables'): 113,
#  ('eggs', 'soda'): 174,
#  ('eggs', 'soda', 'vegetables'): 146,
#  ('eggs', 'spaghetti sauce'): 130,
#  ('eggs', 'spaghetti sauce', 'vegetables'): 125,
#  ('eggs', 'sugar'): 134,
#  ('eggs', 'sugar', 'vegetables'): 117,
#  ('eggs', 'toilet paper'): 154,
#  ('eggs', 'toilet paper', 'vegetables'): 131,
#  ('eggs', 'tortillas'): 140,
#  ('eggs', 'tortillas', 'vegetables'): 137,
#  ('eggs', 'vegetables'): 417,
#  ('eggs', 'vegetables', 'vegetables'): 177,
#  ('eggs', 'vegetables', 'waffles'): 141,
#  ('eggs', 'vegetables', 'yogurt'): 110,
#  ('eggs', 'waffles'): 157,
#  ('eggs', 'yogurt'): 122,
#  ('flour', 'fruits'): 135,
#  ('flour', 'fruits', 'vegetables'): 123,
#  ('flour', 'hand soap'): 140,
#  ('flour', 'hand soap', 'vegetables'): 112,
#  ('flour', 'ice cream'): 124,
#  ('flour', 'ice cream', 'vegetables'): 105,
#  ('flour', 'individual meals'): 144,
#  ('flour', 'individual meals', 'vegetables'): 111,
#  ('flour', 'juice'): 119,
#  ('flour', 'juice', 'vegetables'): 115,
#  ('flour', 'ketchup'): 136,
#  ('flour', 'ketchup', 'vegetables'): 115,
#  ('flour', 'laundry detergent'): 142,
#  ('flour', 'laundry detergent', 'vegetables'): 144,
#  ('flour', 'lunch meat'): 137,
#  ('flour', 'lunch meat', 'vegetables'): 108,
#  ('flour', 'milk'): 144,
#  ('flour', 'milk', 'vegetables'): 108,
#  ('flour', 'mixes'): 152,
#  ('flour', 'mixes', 'vegetables'): 127,
#  ('flour', 'paper towels'): 122,
#  ('flour', 'paper towels', 'vegetables'): 112,
#  ('flour', 'pasta'): 148,
#  ('flour', 'pasta', 'vegetables'): 114,
#  ('flour', 'pork'): 132,
#  ('flour', 'pork', 'vegetables'): 95,
#  ('flour', 'poultry'): 137,
#  ('flour', 'poultry', 'vegetables'): 123,
#  ('flour', 'sandwich bags'): 130,
#  ('flour', 'sandwich bags', 'vegetables'): 107,
#  ('flour', 'sandwich loaves'): 124,
#  ('flour', 'sandwich loaves', 'vegetables'): 114,
#  ('flour', 'shampoo'): 134,
#  ('flour', 'shampoo', 'vegetables'): 111,
#  ('flour', 'soap'): 160,
#  ('flour', 'soap', 'vegetables'): 129,
#  ('flour', 'soda'): 146,
#  ('flour', 'soda', 'vegetables'): 135,
#  ('flour', 'spaghetti sauce'): 138,
#  ('flour', 'spaghetti sauce', 'vegetables'): 126,
#  ('flour', 'sugar'): 138,
#  ('flour', 'sugar', 'vegetables'): 135,
#  ('flour', 'toilet paper'): 123,
#  ('flour', 'toilet paper', 'vegetables'): 86,
#  ('flour', 'tortillas'): 123,
#  ('flour', 'tortillas', 'vegetables'): 109,
#  ('flour', 'vegetables'): 411,
#  ('flour', 'vegetables', 'vegetables'): 178,
#  ('flour', 'vegetables', 'waffles'): 128,
#  ('flour', 'vegetables', 'yogurt'): 121,
#  ('flour', 'waffles'): 144,
#  ('flour', 'yogurt'): 146,
#  ('fruits', 'hand soap'): 112,
#  ('fruits', 'hand soap', 'vegetables'): 82,
#  ('fruits', 'ice cream'): 141,
#  ('fruits', 'ice cream', 'vegetables'): 119,
#  ('fruits', 'individual meals'): 136,
#  ('fruits', 'individual meals', 'vegetables'): 118,
#  ('fruits', 'juice'): 109,
#  ('fruits', 'juice', 'vegetables'): 87,
#  ('fruits', 'ketchup'): 130,
#  ('fruits', 'ketchup', 'vegetables'): 124,
#  ('fruits', 'laundry detergent'): 127,
#  ('fruits', 'laundry detergent', 'vegetables'): 117,
#  ('fruits', 'lunch meat'): 141,
#  ('fruits', 'lunch meat', 'vegetables'): 128,
#  ('fruits', 'milk'): 108,
#  ('fruits', 'milk', 'vegetables'): 85,
#  ('fruits', 'mixes'): 157,
#  ('fruits', 'mixes', 'vegetables'): 120,
#  ('fruits', 'paper towels'): 127,
#  ('fruits', 'paper towels', 'vegetables'): 96,
#  ('fruits', 'pasta'): 142,
#  ('fruits', 'pasta', 'vegetables'): 105,
#  ('fruits', 'pork'): 120,
#  ('fruits', 'pork', 'vegetables'): 95,
#  ('fruits', 'poultry'): 149,
#  ('fruits', 'poultry', 'vegetables'): 116,
#  ('fruits', 'sandwich bags'): 140,
#  ('fruits', 'sandwich bags', 'vegetables'): 102,
#  ('fruits', 'sandwich loaves'): 108,
#  ('fruits', 'sandwich loaves', 'vegetables'): 86,
#  ('fruits', 'shampoo'): 113,
#  ('fruits', 'shampoo', 'vegetables'): 107,
#  ('fruits', 'soap'): 129,
#  ('fruits', 'soap', 'vegetables'): 100,
#  ('fruits', 'soda'): 153,
#  ('fruits', 'soda', 'vegetables'): 127,
#  ('fruits', 'spaghetti sauce'): 155,
#  ('fruits', 'spaghetti sauce', 'vegetables'): 128,
#  ('fruits', 'sugar'): 147,
#  ('fruits', 'sugar', 'vegetables'): 122,
#  ('fruits', 'toilet paper'): 134,
#  ('fruits', 'toilet paper', 'vegetables'): 102,
#  ('fruits', 'tortillas'): 126,
#  ('fruits', 'tortillas', 'vegetables'): 90,
#  ('fruits', 'vegetables'): 394,
#  ('fruits', 'vegetables', 'vegetables'): 160,
#  ('fruits', 'vegetables', 'waffles'): 120,
#  ('fruits', 'vegetables', 'yogurt'): 106,
#  ('fruits', 'waffles'): 133,
#  ('fruits', 'yogurt'): 126,
#  ('hand soap', 'ice cream'): 123,
#  ('hand soap', 'ice cream', 'vegetables'): 95,
#  ('hand soap', 'individual meals'): 118,
#  ('hand soap', 'individual meals', 'vegetables'): 112,
#  ('hand soap', 'juice'): 109,
#  ('hand soap', 'juice', 'vegetables'): 98,
#  ('hand soap', 'ketchup'): 97,
#  ('hand soap', 'laundry detergent'): 100,
#  ('hand soap', 'laundry detergent', 'vegetables'): 89,
#  ('hand soap', 'lunch meat'): 128,
#  ('hand soap', 'lunch meat', 'vegetables'): 109,
#  ('hand soap', 'milk'): 139,
#  ('hand soap', 'milk', 'vegetables'): 108,
#  ('hand soap', 'mixes'): 152,
#  ('hand soap', 'mixes', 'vegetables'): 136,
#  ('hand soap', 'paper towels'): 102,
#  ('hand soap', 'paper towels', 'vegetables'): 85,
#  ('hand soap', 'pasta'): 121,
#  ('hand soap', 'pasta', 'vegetables'): 106,
#  ('hand soap', 'pork'): 105,
#  ('hand soap', 'poultry'): 124,
#  ('hand soap', 'poultry', 'vegetables'): 115,
#  ('hand soap', 'sandwich bags'): 116,
#  ('hand soap', 'sandwich bags', 'vegetables'): 84,
#  ('hand soap', 'sandwich loaves'): 116,
#  ('hand soap', 'sandwich loaves', 'vegetables'): 104,
#  ('hand soap', 'shampoo'): 110,
#  ('hand soap', 'shampoo', 'vegetables'): 94,
#  ('hand soap', 'soap'): 106,
#  ('hand soap', 'soda'): 122,
#  ('hand soap', 'soda', 'vegetables'): 114,
#  ('hand soap', 'spaghetti sauce'): 107,
#  ('hand soap', 'sugar'): 135,
#  ('hand soap', 'sugar', 'vegetables'): 131,
#  ('hand soap', 'toilet paper'): 103,
#  ('hand soap', 'toilet paper', 'vegetables'): 90,
#  ('hand soap', 'tortillas'): 118,
#  ('hand soap', 'tortillas', 'vegetables'): 95,
#  ('hand soap', 'vegetables'): 362,
#  ('hand soap', 'vegetables', 'vegetables'): 181,
#  ('hand soap', 'vegetables', 'waffles'): 106,
#  ('hand soap', 'vegetables', 'yogurt'): 106,
#  ('hand soap', 'waffles'): 144,
#  ('hand soap', 'yogurt'): 106,
#  ('ice cream', 'ice cream'): 79,
#  ('ice cream', 'individual meals'): 152,
#  ('ice cream', 'individual meals', 'vegetables'): 128,
#  ('ice cream', 'juice'): 132,
#  ('ice cream', 'juice', 'vegetables'): 123,
#  ('ice cream', 'ketchup'): 149,
#  ('ice cream', 'ketchup', 'vegetables'): 124,
#  ('ice cream', 'laundry detergent'): 132,
#  ('ice cream', 'laundry detergent', 'vegetables'): 128,
#  ('ice cream', 'lunch meat'): 140,
#  ('ice cream', 'lunch meat', 'vegetables'): 117,
#  ('ice cream', 'milk'): 159,
#  ('ice cream', 'milk', 'vegetables'): 117,
#  ('ice cream', 'mixes'): 130,
#  ('ice cream', 'mixes', 'vegetables'): 110,
#  ('ice cream', 'paper towels'): 148,
#  ('ice cream', 'paper towels', 'vegetables'): 123,
#  ('ice cream', 'pasta'): 166,
#  ('ice cream', 'pasta', 'vegetables'): 117,
#  ('ice cream', 'pork'): 127,
#  ('ice cream', 'pork', 'vegetables'): 87,
#  ('ice cream', 'poultry'): 167,
#  ('ice cream', 'poultry', 'vegetables'): 139,
#  ('ice cream', 'sandwich bags'): 137,
#  ('ice cream', 'sandwich bags', 'vegetables'): 99,
#  ('ice cream', 'sandwich loaves'): 129,
#  ('ice cream', 'sandwich loaves', 'vegetables'): 113,
#  ('ice cream', 'shampoo'): 115,
#  ('ice cream', 'shampoo', 'vegetables'): 102,
#  ('ice cream', 'soap'): 149,
#  ('ice cream', 'soap', 'vegetables'): 107,
#  ('ice cream', 'soda'): 160,
#  ('ice cream', 'soda', 'vegetables'): 151,
#  ('ice cream', 'spaghetti sauce'): 133,
#  ('ice cream', 'spaghetti sauce', 'vegetables'): 123,
#  ('ice cream', 'sugar'): 139,
#  ('ice cream', 'sugar', 'vegetables'): 144,
#  ('ice cream', 'toilet paper'): 155,
#  ('ice cream', 'toilet paper', 'vegetables'): 139,
#  ('ice cream', 'tortillas'): 136,
#  ('ice cream', 'tortillas', 'vegetables'): 128,
#  ('ice cream', 'vegetables'): 424,
#  ('ice cream', 'vegetables', 'vegetables'): 167,
#  ('ice cream', 'vegetables', 'yogurt'): 144,
#  ('ice cream', 'waffles'): 86,
#  ('ice cream', 'yogurt'): 140,
#  ('individual meals', 'juice'): 126,
#  ('individual meals', 'juice', 'vegetables'): 108,
#  ('individual meals', 'ketchup'): 126,
#  ('individual meals', 'ketchup', 'vegetables'): 114,
#  ('individual meals', 'laundry detergent'): 130,
#  ('individual meals', 'laundry detergent', 'vegetables'): 122,
#  ('individual meals', 'lunch meat'): 141,
#  ('individual meals', 'lunch meat', 'vegetables'): 118,
#  ('individual meals', 'milk'): 121,
#  ('individual meals', 'milk', 'vegetables'): 85,
#  ('individual meals', 'mixes'): 120,
#  ('individual meals', 'mixes', 'vegetables'): 105,
#  ('individual meals', 'paper towels'): 146,
#  ('individual meals', 'paper towels', 'vegetables'): 96,
#  ('individual meals', 'pasta'): 138,
#  ('individual meals', 'pasta', 'vegetables'): 93,
#  ('individual meals', 'pork'): 140,
#  ('individual meals', 'pork', 'vegetables'): 116,
#  ('individual meals', 'poultry'): 163,
#  ('individual meals', 'poultry', 'vegetables'): 157,
#  ('individual meals', 'sandwich bags'): 115,
#  ('individual meals', 'sandwich bags', 'vegetables'): 87,
#  ('individual meals', 'sandwich loaves'): 138,
#  ('individual meals', 'sandwich loaves', 'vegetables'): 107,
#  ('individual meals', 'shampoo'): 137,
#  ('individual meals', 'shampoo', 'vegetables'): 107,
#  ('individual meals', 'soap'): 149,
#  ('individual meals', 'soap', 'vegetables'): 101,
#  ('individual meals', 'soda'): 144,
#  ('individual meals', 'soda', 'vegetables'): 124,
#  ('individual meals', 'spaghetti sauce'): 144,
#  ('individual meals', 'spaghetti sauce', 'vegetables'): 99,
#  ('individual meals', 'sugar'): 136,
#  ('individual meals', 'sugar', 'vegetables'): 132,
#  ('individual meals', 'toilet paper'): 147,
#  ('individual meals', 'toilet paper', 'vegetables'): 131,
#  ('individual meals', 'tortillas'): 118,
#  ('individual meals', 'tortillas', 'vegetables'): 90,
#  ('individual meals', 'vegetables'): 405,
#  ('individual meals', 'vegetables', 'vegetables'): 186,
#  ('individual meals', 'vegetables', 'waffles'): 114,
#  ('individual meals', 'vegetables', 'yogurt'): 132,
#  ('individual meals', 'waffles'): 131,
#  ('individual meals', 'yogurt'): 131,
#  ('juice', 'ketchup'): 122,
#  ('juice', 'ketchup', 'vegetables'): 118,
#  ('juice', 'laundry detergent'): 133,
#  ('juice', 'laundry detergent', 'vegetables'): 131,
#  ('juice', 'lunch meat'): 121,
#  ('juice', 'lunch meat', 'vegetables'): 113,
#  ('juice', 'milk'): 121,
#  ('juice', 'milk', 'vegetables'): 89,
#  ('juice', 'mixes'): 142,
#  ('juice', 'mixes', 'vegetables'): 131,
#  ('juice', 'paper towels'): 135,
#  ('juice', 'paper towels', 'vegetables'): 111,
#  ('juice', 'pasta'): 130,
#  ('juice', 'pasta', 'vegetables'): 98,
#  ('juice', 'pork'): 128,
#  ('juice', 'pork', 'vegetables'): 112,
#  ('juice', 'poultry'): 138,
#  ('juice', 'poultry', 'vegetables'): 138,
#  ('juice', 'sandwich bags'): 116,
#  ('juice', 'sandwich bags', 'vegetables'): 95,
#  ('juice', 'sandwich loaves'): 142,
#  ('juice', 'sandwich loaves', 'vegetables'): 107,
#  ('juice', 'shampoo'): 142,
#  ('juice', 'shampoo', 'vegetables'): 139,
#  ('juice', 'soap'): 136,
#  ('juice', 'soap', 'vegetables'): 111,
#  ('juice', 'soda'): 137,
#  ('juice', 'soda', 'vegetables'): 125,
#  ('juice', 'spaghetti sauce'): 137,
#  ('juice', 'spaghetti sauce', 'vegetables'): 132,
#  ('juice', 'sugar'): 135,
#  ('juice', 'sugar', 'vegetables'): 123,
#  ('juice', 'toilet paper'): 157,
#  ('juice', 'toilet paper', 'vegetables'): 129,
#  ('juice', 'tortillas'): 109,
#  ('juice', 'tortillas', 'vegetables'): 100,
#  ('juice', 'vegetables'): 406,
#  ('juice', 'vegetables', 'vegetables'): 188,
#  ('juice', 'vegetables', 'waffles'): 129,
#  ('juice', 'vegetables', 'yogurt'): 161,
#  ('juice', 'waffles'): 131,
#  ('juice', 'yogurt'): 150,
#  ('ketchup', 'laundry detergent'): 132,
#  ('ketchup', 'laundry detergent', 'vegetables'): 113,
#  ('ketchup', 'lunch meat'): 121,
#  ('ketchup', 'lunch meat', 'vegetables'): 127,
#  ('ketchup', 'milk'): 131,
#  ('ketchup', 'milk', 'vegetables'): 112,
#  ('ketchup', 'mixes'): 155,
#  ('ketchup', 'mixes', 'vegetables'): 136,
#  ('ketchup', 'paper towels'): 105,
#  ('ketchup', 'paper towels', 'vegetables'): 94,
#  ('ketchup', 'pasta'): 146,
#  ('ketchup', 'pasta', 'vegetables'): 115,
#  ('ketchup', 'pork'): 136,
#  ('ketchup', 'pork', 'vegetables'): 130,
#  ('ketchup', 'poultry'): 119,
#  ('ketchup', 'poultry', 'vegetables'): 94,
#  ('ketchup', 'sandwich bags'): 128,
#  ('ketchup', 'sandwich bags', 'vegetables'): 108,
#  ('ketchup', 'sandwich loaves'): 125,
#  ('ketchup', 'sandwich loaves', 'vegetables'): 116,
#  ('ketchup', 'shampoo'): 140,
#  ('ketchup', 'shampoo', 'vegetables'): 117,
#  ('ketchup', 'soap'): 153,
#  ('ketchup', 'soap', 'vegetables'): 128,
#  ('ketchup', 'soda'): 120,
#  ('ketchup', 'soda', 'vegetables'): 114,
#  ('ketchup', 'spaghetti sauce'): 134,
#  ('ketchup', 'spaghetti sauce', 'vegetables'): 111,
#  ('ketchup', 'sugar'): 125,
#  ('ketchup', 'sugar', 'vegetables'): 118,
#  ('ketchup', 'toilet paper'): 126,
#  ('ketchup', 'toilet paper', 'vegetables'): 94,
#  ('ketchup', 'tortillas'): 123,
#  ('ketchup', 'tortillas', 'vegetables'): 108,
#  ('ketchup', 'vegetables'): 388,
#  ('ketchup', 'vegetables', 'vegetables'): 162,
#  ('ketchup', 'vegetables', 'waffles'): 112,
#  ('ketchup', 'vegetables', 'yogurt'): 126,
#  ('ketchup', 'waffles'): 134,
#  ('ketchup', 'yogurt'): 118,
#  ('laundry detergent', 'lunch meat'): 140,
#  ('laundry detergent', 'lunch meat', 'vegetables'): 136,
#  ('laundry detergent', 'milk'): 159,
#  ('laundry detergent', 'milk', 'vegetables'): 150,
#  ('laundry detergent', 'mixes'): 137,
#  ('laundry detergent', 'mixes', 'vegetables'): 129,
#  ('laundry detergent', 'paper towels'): 116,
#  ('laundry detergent', 'paper towels', 'vegetables'): 109,
#  ('laundry detergent', 'pasta'): 159,
#  ('laundry detergent', 'pasta', 'vegetables'): 130,
#  ('laundry detergent', 'pork'): 118,
#  ('laundry detergent', 'pork', 'vegetables'): 99,
#  ('laundry detergent', 'poultry'): 165,
#  ('laundry detergent', 'poultry', 'vegetables'): 137,
#  ('laundry detergent', 'sandwich bags'): 136,
#  ('laundry detergent', 'sandwich bags', 'vegetables'): 151,
#  ('laundry detergent', 'sandwich loaves'): 129,
#  ('laundry detergent', 'sandwich loaves', 'vegetables'): 95,
#  ('laundry detergent', 'shampoo'): 131,
#  ('laundry detergent', 'shampoo', 'vegetables'): 131,
#  ('laundry detergent', 'soap'): 146,
#  ('laundry detergent', 'soap', 'vegetables'): 122,
#  ('laundry detergent', 'soda'): 144,
#  ('laundry detergent', 'soda', 'vegetables'): 137,
#  ('laundry detergent', 'spaghetti sauce'): 131,
#  ('laundry detergent', 'spaghetti sauce', 'vegetables'): 118,
#  ('laundry detergent', 'sugar'): 144,
#  ('laundry detergent', 'sugar', 'vegetables'): 125,
#  ('laundry detergent', 'toilet paper'): 150,
#  ('laundry detergent', 'toilet paper', 'vegetables'): 138,
#  ('laundry detergent', 'tortillas'): 111,
#  ('laundry detergent', 'tortillas', 'vegetables'): 103,
#  ('laundry detergent', 'vegetables'): 439,
#  ('laundry detergent', 'vegetables', 'vegetables'): 187,
#  ('laundry detergent', 'vegetables', 'waffles'): 125,
#  ('laundry detergent', 'vegetables', 'yogurt'): 140,
#  ('laundry detergent', 'waffles'): 118,
#  ('laundry detergent', 'yogurt'): 123,
#  ('lunch meat', 'milk'): 161,
#  ('lunch meat', 'milk', 'vegetables'): 132,
#  ('lunch meat', 'mixes'): 156,
#  ('lunch meat', 'mixes', 'vegetables'): 131,
#  ('lunch meat', 'paper towels'): 154,
#  ('lunch meat', 'paper towels', 'vegetables'): 123,
#  ('lunch meat', 'pasta'): 131,
#  ('lunch meat', 'pasta', 'vegetables'): 113,
#  ('lunch meat', 'pork'): 135,
#  ('lunch meat', 'pork', 'vegetables'): 120,
#  ('lunch meat', 'poultry'): 168,
#  ('lunch meat', 'poultry', 'vegetables'): 146,
#  ('lunch meat', 'sandwich bags'): 130,
#  ('lunch meat', 'sandwich bags', 'vegetables'): 103,
#  ('lunch meat', 'sandwich loaves'): 135,
#  ('lunch meat', 'sandwich loaves', 'vegetables'): 114,
#  ('lunch meat', 'shampoo'): 143,
#  ('lunch meat', 'shampoo', 'vegetables'): 125,
#  ('lunch meat', 'soap'): 145,
#  ('lunch meat', 'soap', 'vegetables'): 113,
#  ('lunch meat', 'soda'): 135,
#  ('lunch meat', 'soda', 'vegetables'): 105,
#  ('lunch meat', 'spaghetti sauce'): 141,
#  ('lunch meat', 'spaghetti sauce', 'vegetables'): 119,
#  ('lunch meat', 'sugar'): 150,
#  ('lunch meat', 'sugar', 'vegetables'): 153,
#  ('lunch meat', 'toilet paper'): 156,
#  ('lunch meat', 'toilet paper', 'vegetables'): 117,
#  ('lunch meat', 'tortillas'): 126,
#  ('lunch meat', 'tortillas', 'vegetables'): 132,
#  ('lunch meat', 'vegetables'): 428,
#  ('lunch meat', 'vegetables', 'vegetables'): 170,
#  ('lunch meat', 'vegetables', 'waffles'): 144,
#  ('lunch meat', 'vegetables', 'yogurt'): 122,
#  ('lunch meat', 'waffles'): 156,
#  ('lunch meat', 'yogurt'): 132,
#  ('milk', 'mixes'): 150,
#  ('milk', 'mixes', 'vegetables'): 143,
#  ('milk', 'paper towels'): 138,
#  ('milk', 'paper towels', 'vegetables'): 106,
#  ('milk', 'pasta'): 145,
#  ('milk', 'pasta', 'vegetables'): 104,
#  ('milk', 'pork'): 111,
#  ('milk', 'pork', 'vegetables'): 81,
#  ('milk', 'poultry'): 159,
#  ('milk', 'poultry', 'vegetables'): 120,
#  ('milk', 'sandwich bags'): 146,
#  ('milk', 'sandwich bags', 'vegetables'): 114,
#  ('milk', 'sandwich loaves'): 125,
#  ('milk', 'sandwich loaves', 'vegetables'): 106,
#  ('milk', 'shampoo'): 136,
#  ('milk', 'shampoo', 'vegetables'): 95,
#  ('milk', 'soap'): 159,
#  ('milk', 'soap', 'vegetables'): 107,
#  ('milk', 'soda'): 177,
#  ('milk', 'soda', 'vegetables'): 141,
#  ('milk', 'spaghetti sauce'): 128,
#  ('milk', 'spaghetti sauce', 'vegetables'): 89,
#  ('milk', 'sugar'): 130,
#  ('milk', 'sugar', 'vegetables'): 104,
#  ('milk', 'toilet paper'): 164,
#  ('milk', 'toilet paper', 'vegetables'): 138,
#  ('milk', 'tortillas'): 142,
#  ('milk', 'tortillas', 'vegetables'): 128,
#  ('milk', 'vegetables'): 408,
#  ('milk', 'vegetables', 'vegetables'): 169,
#  ('milk', 'vegetables', 'waffles'): 128,
#  ('milk', 'vegetables', 'yogurt'): 147,
#  ('milk', 'waffles'): 138,
#  ('milk', 'yogurt'): 146,
#  ('mixes', 'mixes'): 92,
#  ('mixes', 'paper towels'): 150,
#  ('mixes', 'paper towels', 'vegetables'): 122,
#  ('mixes', 'pasta'): 148,
#  ('mixes', 'pasta', 'vegetables'): 117,
#  ('mixes', 'pork'): 147,
#  ('mixes', 'pork', 'vegetables'): 130,
#  ('mixes', 'poultry'): 163,
#  ('mixes', 'poultry', 'vegetables'): 166,
#  ('mixes', 'sandwich bags'): 143,
#  ('mixes', 'sandwich bags', 'vegetables'): 99,
#  ('mixes', 'sandwich loaves'): 136,
#  ('mixes', 'sandwich loaves', 'vegetables'): 112,
#  ('mixes', 'shampoo'): 139,
#  ('mixes', 'shampoo', 'vegetables'): 94,
#  ('mixes', 'soap'): 129,
#  ('mixes', 'soap', 'vegetables'): 113,
#  ('mixes', 'soda'): 144,
#  ('mixes', 'soda', 'vegetables'): 111,
#  ('mixes', 'spaghetti sauce'): 150,
#  ('mixes', 'spaghetti sauce', 'vegetables'): 127,
#  ('mixes', 'sugar'): 123,
#  ('mixes', 'sugar', 'vegetables'): 115,
#  ('mixes', 'toilet paper'): 145,
#  ('mixes', 'toilet paper', 'vegetables'): 139,
#  ('mixes', 'tortillas'): 160,
#  ('mixes', 'tortillas', 'vegetables'): 122,
#  ('mixes', 'vegetables'): 438,
#  ('mixes', 'vegetables', 'vegetables'): 223,
#  ('mixes', 'vegetables', 'waffles'): 149,
#  ('mixes', 'vegetables', 'yogurt'): 123,
#  ('mixes', 'waffles'): 155,
#  ('mixes', 'yogurt'): 145,
#  ('paper towels', 'pasta'): 152,
#  ('paper towels', 'pasta', 'vegetables'): 115,
#  ('paper towels', 'pork'): 121,
#  ('paper towels', 'pork', 'vegetables'): 98,
#  ('paper towels', 'poultry'): 135,
#  ('paper towels', 'poultry', 'vegetables'): 127,
#  ('paper towels', 'sandwich bags'): 128,
#  ('paper towels', 'sandwich bags', 'vegetables'): 94,
#  ('paper towels', 'sandwich loaves'): 126,
#  ('paper towels', 'sandwich loaves', 'vegetables'): 116,
#  ('paper towels', 'shampoo'): 134,
#  ('paper towels', 'shampoo', 'vegetables'): 113,
#  ('paper towels', 'soap'): 139,
#  ('paper towels', 'soap', 'vegetables'): 110,
#  ('paper towels', 'soda'): 133,
#  ('paper towels', 'soda', 'vegetables'): 120,
#  ('paper towels', 'spaghetti sauce'): 128,
#  ('paper towels', 'spaghetti sauce', 'vegetables'): 107,
#  ('paper towels', 'sugar'): 120,
#  ('paper towels', 'sugar', 'vegetables'): 102,
#  ('paper towels', 'toilet paper'): 129,
# ...
#  ('hand soap', 'milk'): (('vegetables',), 0.7769784172661871),
#  ('hand soap', 'mixes'): (('vegetables',), 0.8947368421052632),
#  ('hand soap', 'paper towels'): (('vegetables',), 0.8333333333333334),
#  ('hand soap', 'pasta'): (('vegetables',), 0.8760330578512396),
#  ('hand soap', 'poultry'): (('vegetables',), 0.9274193548387096),
#  ('hand soap', 'sandwich bags'): (('vegetables',), 0.7241379310344828),
#  ('hand soap', 'sandwich loaves'): (('vegetables',), 0.896551724137931),
#  ('hand soap', 'shampoo'): (('vegetables',), 0.8545454545454545),
#  ('hand soap', 'soda'): (('vegetables',), 0.9344262295081968),
#  ('hand soap', 'sugar'): (('vegetables',), 0.9703703703703703),
#  ('hand soap', 'toilet paper'): (('vegetables',), 0.8737864077669902),
#  ('hand soap', 'tortillas'): (('vegetables',), 0.8050847457627118),
#  ('hand soap', 'waffles'): (('vegetables',), 0.7361111111111112),
#  ('hand soap', 'yogurt'): (('vegetables',), 1.0),
#  ('ice cream', 'individual meals'): (('vegetables',), 0.8421052631578947),
#  ('ice cream', 'juice'): (('vegetables',), 0.9318181818181818),
#  ('ice cream', 'ketchup'): (('vegetables',), 0.8322147651006712),
#  ('ice cream', 'laundry detergent'): (('vegetables',), 0.9696969696969697),
#  ('ice cream', 'lunch meat'): (('vegetables',), 0.8357142857142857),
#  ('ice cream', 'milk'): (('vegetables',), 0.7358490566037735),
#  ('ice cream', 'mixes'): (('vegetables',), 0.8461538461538461),
#  ('ice cream', 'paper towels'): (('vegetables',), 0.831081081081081),
#  ('ice cream', 'pasta'): (('vegetables',), 0.7048192771084337),
#  ('ice cream', 'poultry'): (('vegetables',), 0.8323353293413174),
#  ('ice cream', 'sandwich bags'): (('vegetables',), 0.7226277372262774),
#  ('ice cream', 'sandwich loaves'): (('vegetables',), 0.875968992248062),
#  ('ice cream', 'shampoo'): (('vegetables',), 0.8869565217391304),
#  ('ice cream', 'soap'): (('vegetables',), 0.7181208053691275),
#  ('ice cream', 'soda'): (('vegetables',), 0.94375),
#  ('ice cream', 'spaghetti sauce'): (('vegetables',), 0.924812030075188),
#  ('ice cream', 'sugar'): (('vegetables',), 1.0359712230215827),
#  ('ice cream', 'toilet paper'): (('vegetables',), 0.896774193548387),
#  ('ice cream', 'tortillas'): (('vegetables',), 0.9411764705882353),
#  ('ice cream', 'yogurt'): (('vegetables',), 1.0285714285714285),
#  ('individual meals', 'juice'): (('vegetables',), 0.8571428571428571),
#  ('individual meals', 'ketchup'): (('vegetables',), 0.9047619047619048),
#  ('individual meals', 'laundry detergent'): (('vegetables',),
#                                              0.9384615384615385),
#  ('individual meals', 'lunch meat'): (('vegetables',), 0.8368794326241135),
#  ('individual meals', 'milk'): (('vegetables',), 0.7024793388429752),
#  ('individual meals', 'mixes'): (('vegetables',), 0.875),
#  ('individual meals', 'pork'): (('vegetables',), 0.8285714285714286),
#  ('individual meals', 'poultry'): (('vegetables',), 0.9631901840490797),
#  ('individual meals', 'sandwich bags'): (('vegetables',), 0.7565217391304347),
#  ('individual meals', 'sandwich loaves'): (('vegetables',), 0.7753623188405797),
#  ('individual meals', 'shampoo'): (('vegetables',), 0.781021897810219),
#  ('individual meals', 'soda'): (('vegetables',), 0.8611111111111112),
#  ('individual meals', 'sugar'): (('vegetables',), 0.9705882352941176),
#  ('individual meals', 'toilet paper'): (('vegetables',), 0.891156462585034),
#  ('individual meals', 'tortillas'): (('vegetables',), 0.7627118644067796),
#  ('individual meals', 'waffles'): (('vegetables',), 0.8702290076335878),
#  ('individual meals', 'yogurt'): (('vegetables',), 1.0076335877862594),
#  ('juice', 'ketchup'): (('vegetables',), 0.9672131147540983),
#  ('juice', 'laundry detergent'): (('vegetables',), 0.9849624060150376),
#  ('juice', 'lunch meat'): (('vegetables',), 0.9338842975206612),
#  ('juice', 'milk'): (('vegetables',), 0.7355371900826446),
#  ('juice', 'mixes'): (('vegetables',), 0.9225352112676056),
#  ('juice', 'paper towels'): (('vegetables',), 0.8222222222222222),
#  ('juice', 'pasta'): (('vegetables',), 0.7538461538461538),
#  ('juice', 'pork'): (('vegetables',), 0.875),
#  ('juice', 'poultry'): (('vegetables',), 1.0),
#  ('juice', 'sandwich bags'): (('vegetables',), 0.8189655172413793),
#  ('juice', 'sandwich loaves'): (('vegetables',), 0.7535211267605634),
#  ('juice', 'shampoo'): (('vegetables',), 0.9788732394366197),
#  ('juice', 'soap'): (('vegetables',), 0.8161764705882353),
#  ('juice', 'soda'): (('vegetables',), 0.9124087591240876),
#  ('juice', 'spaghetti sauce'): (('vegetables',), 0.9635036496350365),
#  ('juice', 'sugar'): (('vegetables',), 0.9111111111111111),
#  ('juice', 'toilet paper'): (('vegetables',), 0.821656050955414),
#  ('juice', 'tortillas'): (('vegetables',), 0.9174311926605505),
#  ('juice', 'waffles'): (('vegetables',), 0.9847328244274809),
#  ('juice', 'yogurt'): (('vegetables',), 1.0733333333333333),
#  ('ketchup', 'laundry detergent'): (('vegetables',), 0.8560606060606061),
#  ('ketchup', 'lunch meat'): (('vegetables',), 1.0495867768595042),
#  ('ketchup', 'milk'): (('vegetables',), 0.8549618320610687),
#  ('ketchup', 'mixes'): (('vegetables',), 0.8774193548387097),
#  ('ketchup', 'paper towels'): (('vegetables',), 0.8952380952380953),
#  ('ketchup', 'pasta'): (('vegetables',), 0.7876712328767124),
#  ('ketchup', 'pork'): (('vegetables',), 0.9558823529411765),
#  ('ketchup', 'poultry'): (('vegetables',), 0.7899159663865546),
#  ('ketchup', 'sandwich bags'): (('vegetables',), 0.84375),
#  ('ketchup', 'sandwich loaves'): (('vegetables',), 0.928),
#  ('ketchup', 'shampoo'): (('vegetables',), 0.8357142857142857),
#  ('ketchup', 'soap'): (('vegetables',), 0.8366013071895425),
#  ('ketchup', 'soda'): (('vegetables',), 0.95),
#  ('ketchup', 'spaghetti sauce'): (('vegetables',), 0.8283582089552238),
#  ('ketchup', 'sugar'): (('vegetables',), 0.944),
#  ('ketchup', 'toilet paper'): (('vegetables',), 0.746031746031746),
#  ('ketchup', 'tortillas'): (('vegetables',), 0.8780487804878049),
#  ('ketchup', 'waffles'): (('vegetables',), 0.835820895522388),
#  ('ketchup', 'yogurt'): (('vegetables',), 1.0677966101694916),
#  ('laundry detergent', 'lunch meat'): (('vegetables',), 0.9714285714285714),
#  ('laundry detergent', 'milk'): (('vegetables',), 0.9433962264150944),
#  ('laundry detergent', 'mixes'): (('vegetables',), 0.9416058394160584),
#  ('laundry detergent', 'paper towels'): (('vegetables',), 0.9396551724137931),
#  ('laundry detergent', 'pasta'): (('vegetables',), 0.8176100628930818),
#  ('laundry detergent', 'pork'): (('vegetables',), 0.8389830508474576),
#  ('laundry detergent', 'poultry'): (('vegetables',), 0.8303030303030303),
#  ('laundry detergent', 'sandwich bags'): (('vegetables',), 1.1102941176470589),
#  ('laundry detergent', 'sandwich loaves'): (('vegetables',),
#                                             0.7364341085271318),
#  ('laundry detergent', 'shampoo'): (('vegetables',), 1.0),
#  ('laundry detergent', 'soap'): (('vegetables',), 0.8356164383561644),
#  ('laundry detergent', 'soda'): (('vegetables',), 0.9513888888888888),
#  ('laundry detergent', 'spaghetti sauce'): (('vegetables',),
#                                             0.9007633587786259),
#  ('laundry detergent', 'sugar'): (('vegetables',), 0.8680555555555556),
#  ('laundry detergent', 'toilet paper'): (('vegetables',), 0.92),
#  ('laundry detergent', 'tortillas'): (('vegetables',), 0.9279279279279279),
#  ('laundry detergent', 'waffles'): (('vegetables',), 1.0593220338983051),
#  ('laundry detergent', 'yogurt'): (('vegetables',), 1.1382113821138211),
#  ('lunch meat', 'milk'): (('vegetables',), 0.8198757763975155),
#  ('lunch meat', 'mixes'): (('vegetables',), 0.8397435897435898),
#  ('lunch meat', 'paper towels'): (('vegetables',), 0.7987012987012987),
#  ('lunch meat', 'pasta'): (('vegetables',), 0.8625954198473282),
#  ('lunch meat', 'pork'): (('vegetables',), 0.8888888888888888),
#  ('lunch meat', 'poultry'): (('vegetables',), 0.8690476190476191),
#  ('lunch meat', 'sandwich bags'): (('vegetables',), 0.7923076923076923),
#  ('lunch meat', 'sandwich loaves'): (('vegetables',), 0.8444444444444444),
#  ('lunch meat', 'shampoo'): (('vegetables',), 0.8741258741258742),
#  ('lunch meat', 'soap'): (('vegetables',), 0.7793103448275862),
#  ('lunch meat', 'soda'): (('vegetables',), 0.7777777777777778),
#  ('lunch meat', 'spaghetti sauce'): (('vegetables',), 0.8439716312056738),
#  ('lunch meat', 'sugar'): (('vegetables',), 1.02),
#  ('lunch meat', 'toilet paper'): (('vegetables',), 0.75),
#  ('lunch meat', 'tortillas'): (('vegetables',), 1.0476190476190477),
#  ('lunch meat', 'waffles'): (('vegetables',), 0.9230769230769231),
#  ('lunch meat', 'yogurt'): (('vegetables',), 0.9242424242424242),
#  ('milk', 'mixes'): (('vegetables',), 0.9533333333333334),
#  ('milk', 'paper towels'): (('vegetables',), 0.7681159420289855),
#  ('milk', 'pasta'): (('vegetables',), 0.7172413793103448),
#  ('milk', 'pork'): (('vegetables',), 0.7297297297297297),
#  ('milk', 'poultry'): (('vegetables',), 0.7547169811320755),
#  ('milk', 'sandwich bags'): (('vegetables',), 0.7808219178082192),
#  ('milk', 'sandwich loaves'): (('vegetables',), 0.848),
#  ('milk', 'soda'): (('vegetables',), 0.7966101694915254),
#  ('milk', 'sugar'): (('vegetables',), 0.8),
#  ('milk', 'toilet paper'): (('vegetables',), 0.8414634146341463),
#  ('milk', 'tortillas'): (('vegetables',), 0.9014084507042254),
#  ('milk', 'waffles'): (('vegetables',), 0.927536231884058),
#  ('milk', 'yogurt'): (('vegetables',), 1.0068493150684932),
#  ('mixes', 'paper towels'): (('vegetables',), 0.8133333333333334),
#  ('mixes', 'pasta'): (('vegetables',), 0.7905405405405406),
#  ('mixes', 'pork'): (('vegetables',), 0.8843537414965986),
#  ('mixes', 'poultry'): (('vegetables',), 1.01840490797546),
#  ('mixes', 'sandwich loaves'): (('vegetables',), 0.8235294117647058),
#  ('mixes', 'soap'): (('vegetables',), 0.875968992248062),
#  ('mixes', 'soda'): (('vegetables',), 0.7708333333333334),
#  ('mixes', 'spaghetti sauce'): (('vegetables',), 0.8466666666666667),
#  ('mixes', 'sugar'): (('vegetables',), 0.9349593495934959),
#  ('mixes', 'toilet paper'): (('vegetables',), 0.9586206896551724),
#  ('mixes', 'tortillas'): (('vegetables',), 0.7625),
#  ('mixes', 'waffles'): (('vegetables',), 0.9612903225806452),
#  ('mixes', 'yogurt'): (('vegetables',), 0.8482758620689655),
#  ('paper towels', 'pasta'): (('vegetables',), 0.756578947368421),
#  ('paper towels', 'pork'): (('vegetables',), 0.8099173553719008),
#  ('paper towels', 'poultry'): (('vegetables',), 0.9407407407407408),
#  ('paper towels', 'sandwich bags'): (('vegetables',), 0.734375),
#  ('paper towels', 'sandwich loaves'): (('vegetables',), 0.9206349206349206),
#  ('paper towels', 'shampoo'): (('vegetables',), 0.8432835820895522),
#  ('paper towels', 'soap'): (('vegetables',), 0.7913669064748201),
#  ('paper towels', 'soda'): (('vegetables',), 0.9022556390977443),
#  ('paper towels', 'spaghetti sauce'): (('vegetables',), 0.8359375),
#  ('paper towels', 'sugar'): (('vegetables',), 0.85),
#  ('paper towels', 'toilet paper'): (('vegetables',), 0.7906976744186046),
#  ('paper towels', 'tortillas'): (('vegetables',), 0.8),
#  ('paper towels', 'waffles'): (('vegetables',), 0.8805970149253731),
#  ('paper towels', 'yogurt'): (('vegetables',), 0.923728813559322),
#  ('pasta', 'poultry'): (('vegetables',), 0.9477124183006536),
#  ('pasta', 'sandwich loaves'): (('vegetables',), 0.7593984962406015),
#  ('pasta', 'soap'): (('vegetables',), 0.75),
#  ('pasta', 'soda'): (('vegetables',), 0.7409638554216867),
#  ('pasta', 'spaghetti sauce'): (('vegetables',), 0.9741935483870968),
#  ('pasta', 'sugar'): (('vegetables',), 0.8445945945945946),
#  ('pasta', 'toilet paper'): (('vegetables',), 0.7364864864864865),
#  ('pasta', 'yogurt'): (('vegetables',), 0.8925619834710744),
#  ('pork', 'poultry'): (('vegetables',), 0.8859060402684564),
#  ('pork', 'sandwich loaves'): (('vegetables',), 0.75),
#  ('pork', 'shampoo'): (('vegetables',), 0.7456140350877193),
#  ('pork', 'soap'): (('vegetables',), 0.8412698412698413),
#  ('pork', 'soda'): (('vegetables',), 0.7795275590551181),
#  ('pork', 'spaghetti sauce'): (('vegetables',), 0.7264957264957265),
#  ('pork', 'sugar'): (('vegetables',), 0.753968253968254),
#  ('pork', 'toilet paper'): (('vegetables',), 0.9461538461538461),
#  ('pork', 'tortillas'): (('vegetables',), 0.8360655737704918),
#  ('pork', 'waffles'): (('vegetables',), 0.8872180451127819),
#  ('pork', 'yogurt'): (('vegetables',), 0.8962962962962963),
#  ('poultry', 'sandwich loaves'): (('vegetables',), 0.9310344827586207),
#  ('poultry', 'shampoo'): (('vegetables',), 0.7938931297709924),
#  ('poultry', 'soap'): (('vegetables',), 0.7987012987012987),
#  ('poultry', 'soda'): (('vegetables',), 0.8835616438356164),
#  ('poultry', 'spaghetti sauce'): (('vegetables',), 0.8243243243243243),
#  ('poultry', 'sugar'): (('vegetables',), 0.9225806451612903),
#  ('poultry', 'toilet paper'): (('vegetables',), 0.9342105263157895),
#  ('poultry', 'tortillas'): (('vegetables',), 0.8846153846153846),
#  ('poultry', 'waffles'): (('vegetables',), 0.9172932330827067),
#  ('poultry', 'yogurt'): (('vegetables',), 0.8795180722891566),
#  ('sandwich bags', 'sandwich loaves'): (('vegetables',), 0.7801418439716312),
#  ('sandwich bags', 'shampoo'): (('vegetables',), 0.7096774193548387),
#  ('sandwich bags', 'soda'): (('vegetables',), 0.7214285714285714),
#  ('sandwich bags', 'spaghetti sauce'): (('vegetables',), 0.7435897435897436),
#  ('sandwich bags', 'toilet paper'): (('vegetables',), 0.7419354838709677),
#  ('sandwich bags', 'tortillas'): (('vegetables',), 0.7593984962406015),
#  ('sandwich bags', 'waffles'): (('vegetables',), 0.8540145985401459),
#  ('sandwich bags', 'yogurt'): (('vegetables',), 0.9302325581395349),
#  ('sandwich loaves', 'shampoo'): (('vegetables',), 0.9236111111111112),
#  ('sandwich loaves', 'soda'): (('vegetables',), 0.875968992248062),
#  ('sandwich loaves', 'sugar'): (('vegetables',), 0.9015151515151515),
#  ('sandwich loaves', 'toilet paper'): (('vegetables',), 0.8951048951048951),
#  ('sandwich loaves', 'tortillas'): (('vegetables',), 0.7927927927927928),
#  ('sandwich loaves', 'waffles'): (('vegetables',), 0.9295774647887324),
#  ('sandwich loaves', 'yogurt'): (('vegetables',), 0.9180327868852459),
#  ('shampoo', 'soda'): (('vegetables',), 0.9285714285714286),
#  ('shampoo', 'spaghetti sauce'): (('vegetables',), 0.7768595041322314),
#  ('shampoo', 'sugar'): (('vegetables',), 0.8344370860927153),
#  ('shampoo', 'toilet paper'): (('vegetables',), 0.8716216216216216),
#  ('shampoo', 'tortillas'): (('vegetables',), 0.8),
#  ('shampoo', 'waffles'): (('vegetables',), 0.8620689655172413),
#  ('shampoo', 'yogurt'): (('vegetables',), 0.9538461538461539),
#  ('soap', 'soda'): (('vegetables',), 0.8098159509202454),
#  ('soap', 'spaghetti sauce'): (('vegetables',), 0.848),
#  ('soap', 'tortillas'): (('vegetables',), 0.8482142857142857),
#  ('soap', 'waffles'): (('vegetables',), 0.7549668874172185),
#  ('soap', 'yogurt'): (('vegetables',), 0.8852459016393442),
#  ('soda', 'spaghetti sauce'): (('vegetables',), 0.9485294117647058),
#  ('soda', 'sugar'): (('vegetables',), 0.9090909090909091),
#  ('soda', 'tortillas'): (('vegetables',), 0.78125),
#  ('soda', 'waffles'): (('vegetables',), 0.8525641025641025),
#  ('soda', 'yogurt'): (('vegetables',), 0.95625),
#  ('spaghetti sauce', 'spaghetti sauce'): (('vegetables',), 1.0),
#  ('spaghetti sauce', 'sugar'): (('vegetables',), 0.7941176470588235),
#  ('spaghetti sauce', 'toilet paper'): (('vegetables',), 0.7891156462585034),
#  ('spaghetti sauce', 'tortillas'): (('vegetables',), 0.7478260869565218),
#  ('spaghetti sauce', 'waffles'): (('vegetables',), 0.9545454545454546),
#  ('sugar', 'toilet paper'): (('vegetables',), 0.8169014084507042),
#  ('sugar', 'tortillas'): (('vegetables',), 1.0),
#  ('sugar', 'waffles'): (('vegetables',), 0.8089171974522293),
#  ('sugar', 'yogurt'): (('vegetables',), 1.0064516129032257),
#  ('toilet paper', 'tortillas'): (('vegetables',), 0.9722222222222222),
#  ('toilet paper', 'waffles'): (('vegetables',), 0.7283236994219653),
#  ('toilet paper', 'yogurt'): (('vegetables',), 1.0869565217391304),
#  ('tortillas', 'waffles'): (('vegetables',), 0.9338842975206612),
#  ('tortillas', 'yogurt'): (('vegetables',), 0.9925373134328358),
#  ('waffles', 'yogurt'): (('vegetables',), 0.9797297297297297)}

# %% [markdown]
# # End of Tutorial. Many Thanks.
