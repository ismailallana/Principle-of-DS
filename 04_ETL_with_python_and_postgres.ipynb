# %% [markdown]
# # Week 4: Data transformation, cleaning and loading with Python
#
# ## WaterInfo Data Set
# We are considering a water data set this week about Murray River Basin in NSW. In Canvas (Module 4 section), there is an Excel sheet available with an excerpt of the original data set. We also have made available the content of the Excel workbook as a set of four different CSV files. Please upload those CSV files to Jupyter first.
#
# **Important:** Make sure that the naming of all the files is as follows:
#  1. Measurements.csv
#  2. Organisations.csv
#  3. Sensors.csv
#  4. Stations.csv

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 2: Data Loading and Database Creation with Python
#
# Next we are back to Python. We continue with the same Python environment than last week: the `DictReader` from the `csv` module which support reading and writing of files in comma-separated values (CSV).
#
# Make sure that you have uploaded the 'Organisations.csv' CSV file into Jupyter.
# We will first load the content of this file into Python with the same  csv.DictReader()  mechanism than last week:

# %%
import csv
import pprint
data_organisations = list(csv.DictReader(open('Organisations.csv')))
pprint.pprint(data_organisations[0])
# Out:
# OrderedDict([('Code', 'DNR'),
#              ('Organisation',
#               'NSW Department of Water and Energy (and predecessors)')])

# %% [markdown]
# For larger data sets, the following would normally be executed as a stand alone Python program on a shell.
# First, you need to establish a connection to the postgresql database.
# __Please edit the unikey and SID variables in below's code to match your Jupyter login.__

# %%
import psycopg2

def pgconnect():
    # please replace with your own details
    YOUR_DBNAME = 'comp5310'    
    YOUR_USERNAME = 'postgres'
    YOUR_PW     = '277698'
    try: 
        conn = psycopg2.connect(host='localhost',
                                database=YOUR_DBNAME,
                                user=YOUR_USERNAME, 
                                password=YOUR_PW)
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return conn

# %% [markdown]
# We will need to execute some SQL statements against the database. As we will have to do so multiple times, we write a dedicated function for executing an arbitrary SQL statement, where we do not expect any result. This handles then also all failures and using psycopg2's 'with' statements also the transaction processing of the database. Below's code will for example automatically commit our SQL statements, as well as rollback if there was any error.

# %%
def pgexec( conn, sqlcmd, args, msg, silent=False ):
   """ utility function to execute some SQL statement
       can take optional arguments to fill in (dictionary)
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
               cur.execute(sqlcmd)
            else:
               cur.execute(sqlcmd, args)
            if silent == False: 
                print("success: " + msg)
            retval = True
         except Exception as e:
            if silent == False: 
                print("db error: ")
                print(e)
   return retval

# %% [markdown]
# Now let's load our previous data.
# Important: whenever you use this approach, make sure that the header line of your CSV file has no spaces in its column titles and also no quotes. Otherwise, the csv.DictReader might be fine to read it, but not the psycopg2's cursor.execute() function. We are using named placeholders in out INSERT statement below (eg. '%(SiteName)s' ) which expects to put a string (%s) into that place of the INSERT statement as been found in the given dictionary for the execute() call with the key 'SiteName'.

# %%
# 1st: login to database
conn = pgconnect()

# if you want to reset the table
pgexec (conn, "DROP TABLE IF EXISTS Organisation", None, "Reset Table Organisation")

# 2nd: ensure that the schema is in place

organisation_schema = """CREATE TABLE IF NOT EXISTS Organisation (
                         code VARCHAR(20) PRIMARY KEY,
                         orgName VARCHAR(150)
                   )"""
pgexec (conn, organisation_schema, None, "Create Table Organisation")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Organisation(code,orgName) VALUES (%(Code)s, %(Organisation)s)"""
for row in data_organisations:
    pgexec (conn, insert_stmt, row, "row inserted")
# Out:
# connected
# success: Reset Table Organisation
# success: Create Table Organisation
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %% [markdown]
# Next let's check whether this has all worked fine by querying our PostgreSQL database again.
# You of course can go back to the Terminal page and in pgsql simply type   SELECT * FROM Organisation
#
# Or we do it here in Python again. To do so, we introduce first another utility function which again encapsulates all error and transaction handling. Then we query the new Organisation table and simply print out all tuples found.

# %%
def pgquery( conn, sqlcmd, args, silent=False ):
   """ utility function to execute some SQL query statement
       can take optional arguments to fill in (dictionary)
       will print out on screen the result set of the query
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
                cur.execute(sqlcmd)
            else:
                cur.execute(sqlcmd, args)
            if silent == False:
                for record in cur:
                    print(record)
            retval = True
         except Exception as e:
            if silent == False:
                print("db read error: ")
                print(e)
   return retval

# %%
# check content of Organisation table
query_stmt = "SELECT * FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)

# cleanup...   Needed already?  Better not now... 
# But keep in mind to close connection eventually!
# conn.close()
# Out:
# SELECT * FROM Organisation
# ('DNR', 'NSW Department of Water and Energy (and predecessors)')
# ('DWR', 'NSW Department of Water and Energy (and predecessors)')
# ('MIL', 'Murray Irrigation Ltd')
# ('PWD', 'Manly Hydraulics Laboratory')
# ('QWR', 'Qld Department of Natural Resources and Water')
# ('SCA', 'Sydney Catchment Authority')
# ('SMA', 'Snowy Mountains Authority')
# ('SWB', 'Sydney Catchment Authority')
# ('VRW', 'Vic Government')
# True

# %% [markdown]
# ## Your Task: Data Loading
#
# Try to create and load the Measurement table.
#
#     1.read the Measurements csv file
#     2. Create a matching 'Measurement' table to hold the CSV data
#     3. Load the content of the csv file into a local 'data_measurements' dictionary in Python
#     4. Load the data from the 'data_measurements' dictionary into your PostgreSQL table
#     5. Query and print its content

# %%
# TODO: replace the content of this cell with your Python + psycopg2 solution
#raise NotImplementedError

##1st: read the Measurements csv file

data_measurements = list(csv.DictReader(open('Measurements.csv')))
pprint.pprint(data_measurements[0])



# 2nd: ensure that the schema is in place
pgexec (conn, "DROP TABLE IF EXISTS Measurement", None, "Reset Table Measurement")
measurement_schema = """CREATE TABLE IF NOT EXISTS Measurement (
                         station   VARCHAR(20),
                         date DATE,
                         level  FLOAT,
                         meanDischarge FLOAT,
                         discharge  FLOAT,
                         temp FLOAT,
                         ec  FLOAT
                      )"""
pgexec (conn, measurement_schema, None, "Create Table Measurement")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,level,meandischarge,discharge,temp,ec)
                      VALUES (%(Station)s, %(Date)s, %(Level)s,%(MeanDischarge)s,%(Discharge)s,%(Temp)s,%(EC)s)"""
# 4th: insert the data into the table
for row in data_measurements:
    pgexec (conn, insert_stmt, row, "row inserted")
   
#5th: Query  content of Measurement table
query_stmt = "SELECT * FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)

query_stmt = "SELECT count(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)
# Out:
# OrderedDict([('Station', '409204C'),
#              ('Date', '31-Dec-04'),
#              ('Level', '1.196'),
#              ('MeanDischarge', '5876.087'),
#              ('Discharge', '5873.837'),
#              ('Temp', '23.217'),
#              ('EC', '57.583')])
# success: Reset Table Measurement
# success: Create Table Measurement
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '31-Dec-04', '0.219','1.996','1.731','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '1-Jan-05', '0.208','1.406','1.273','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '2-Jan-05', '0.201','1.096','1.166','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...ALUES ('219018', '3-Jan-05', '0.198','0.96','0.989','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...ALUES ('219018', '4-Jan-05', '0.195','0.852','0.94','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '5-Jan-05', '0.191','0.706','0.724','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '6-Jan-05', '0.194','0.795','0.915','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '7-Jan-05', '0.186','0.579','0.552','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...VALUES ('219018', '8-Jan-05', '0.19','0.661','0.61','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '9-Jan-05', '0.181','0.431','0.399','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '10-Jan-05', '0.178','0.354','0.409','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '11-Jan-05', '0.184','0.498','0.498','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '12-Jan-05', '0.185','0.515','0.552','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '13-Jan-05', '0.179','0.399','0.393','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '14-Jan-05', '0.167','0.198','0.089','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ... VALUES ('219018', '15-Jan-05', '0.154','0.066','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '16-Jan-05', '0.115','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '17-Jan-05', '0.078','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '18-Jan-05', '0.047','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '19-Jan-05', '0.013','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '20-Jan-05', '-0.018','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '21-Jan-05', '-0.036','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '22-Jan-05', '-0.007','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '23-Jan-05', '-0.029','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '24-Jan-05', '-0.068','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '25-Jan-05', '-0.113','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '26-Jan-05', '-0.166','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '27-Jan-05', '-0.225','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '28-Jan-05', '-0.248','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '29-Jan-05', '-0.246','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '30-Jan-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '31-Jan-05', '-0.248','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '1-Feb-05', '-0.248','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '2-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '3-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '4-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '5-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '6-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '7-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '8-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '9-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '10-Feb-05', '-0.246','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '11-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '12-Feb-05', '-0.248','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '13-Feb-05', '-0.248','0','0','x','x')
#                                                                ^
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '14-Feb-05', '-0.248','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '15-Feb-05', '-0.247','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '16-Feb-05', '-0.243','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '17-Feb-05', '-0.206','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '18-Feb-05', '-0.157','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '19-Feb-05', '-0.093','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '20-Feb-05', '-0.064','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '21-Feb-05', '-0.02','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '22-Feb-05', '0.021','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '23-Feb-05', '0.046','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '24-Feb-05', '0.053','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '25-Feb-05', '0.055','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '26-Feb-05', '0.045','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '27-Feb-05', '0.033','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '28-Feb-05', '0.017','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '1-Mar-05', '0.004','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '2-Mar-05', '0.024','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '3-Mar-05', '0.037','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '4-Mar-05', '0.048','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '5-Mar-05', '0.057','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '6-Mar-05', '0.049','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '7-Mar-05', '0.031','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...       VALUES ('219018', '8-Mar-05', '0.01','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...      VALUES ('219018', '9-Mar-05', '0.004','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '10-Mar-05', '-0.001','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '11-Mar-05', '0.037','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '12-Mar-05', '0.049','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '13-Mar-05', '0.052','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '14-Mar-05', '0.067','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '15-Mar-05', '0.104','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '16-Mar-05', '0.119','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '17-Mar-05', '0.117','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '18-Mar-05', '0.102','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '19-Mar-05', '0.082','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '20-Mar-05', '0.053','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '21-Mar-05', '0.024','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '22-Mar-05', '-0.002','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '23-Mar-05', '-0.031','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '24-Mar-05', '-0.065','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '25-Mar-05', '-0.093','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '26-Mar-05', '-0.104','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '27-Mar-05', '-0.122','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '28-Mar-05', '-0.143','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '29-Mar-05', '-0.168','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '30-Mar-05', '-0.195','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...    VALUES ('219018', '31-Mar-05', '-0.173','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...     VALUES ('219018', '1-Apr-05', '-0.098','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...       VALUES ('219018', '2-Apr-05', '0.04','0','0','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '3-Apr-05', '0.166','0.198','0.371','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                    VALUES ('219018', '4-Apr-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                    VALUES ('219018', '5-Apr-05', 'x','x','0...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '6-Apr-05', '0.166','0.159','0.119','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '7-Apr-05', '0.162','0.105','0.091','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '8-Apr-05', '0.164','0.127','0.122','x','x')
#                                                                ^
#
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                    VALUES ('409017', '8-Apr-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '9-Apr-05', '0.163','0.117','0.116','x','x')
#                                                                ^
#
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                    VALUES ('409017', '9-Apr-05', 'x','x','6...
#                                                              ^
#
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '10-Apr-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '11-Apr-05', 'x','x','0...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '12-Apr-05', '0.171','0.223','0.256','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '13-Apr-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '14-Apr-05', 'x','x','0...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '15-Apr-05', '0.174','0.278','0.264','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '16-Apr-05', '0.173','0.257','0.256','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '17-Apr-05', '0.168','0.184','0.232','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '18-Apr-05', '0.174','0.279','0.278','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '19-Apr-05', '0.178','0.351','0.373','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '20-Apr-05', '0.174','0.283','0.268','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '21-Apr-05', '0.18','0.399','0.483','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '22-Apr-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '23-Apr-05', 'x','x','0...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '24-Apr-05', '0.188','0.59','0.581','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '25-Apr-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '26-Apr-05', 'x','x','0...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '27-Apr-05', '0.189','0.622','0.61','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '28-Apr-05', '0.188','0.612','0.625','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '29-Apr-05', '0.19','0.658','0.703','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '30-Apr-05', '0.191','0.697','0.655','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '1-May-05', '0.182','0.477','0.403','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '2-May-05', '0.185','0.532','0.545','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '3-May-05', '0.186','0.545','0.545','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '4-May-05', '0.187','0.561','0.588','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '5-May-05', '0.189','0.644','0.719','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '6-May-05', '0.193','0.746','0.735','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...LUES ('219018', '7-May-05', '0.192','0.728','0.727','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                    VALUES ('219018', '8-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                    VALUES ('219018', '9-May-05', 'x','x','0...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '10-May-05', '0.196','0.852','0.794','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '11-May-05', '0.191','0.705','0.903','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '12-May-05', '0.193','0.772','0.925','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...UES ('219018', '13-May-05', '0.193','0.753','0.812','x','x')
#                                                                ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '14-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '15-May-05', 'x','x','x...
#                                                              ^
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '16-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '17-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '18-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '19-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '20-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '21-May-05', 'x','x','x...
#                                                              ^
#
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('409017', '23-May-05', 'x','x','x...
#                                                              ^
#
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('409017', '24-May-05', 'x','x','x...
#                                                              ^
#
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('409017', '25-May-05', 'x','x','x...
#                                                              ^
#
# SELECT * FROM Measurement
# ('409204C', datetime.date(2004, 12, 31), 1.196, 5876.087, 5873.837, 23.217, 57.583)
# ('409017', datetime.date(2004, 12, 31), 2.552, 9615.444, 9689.209, 21.072, 46.104)
# ('409204C', datetime.date(2005, 1, 1), 1.19, 5835.842, 5795.7, 23.167, 58.0)
# ('409017', datetime.date(2005, 1, 1), 2.558, 9694.446, 9749.228, 21.219, 45.865)
# ('409204C', datetime.date(2005, 1, 2), 1.184, 5794.465, 5782.514, 22.775, 57.583)
# ('409017', datetime.date(2005, 1, 2), 2.543, 9518.819, 8279.382, 21.023, 45.052)
# ('409204C', datetime.date(2005, 1, 3), 1.179, 5759.608, 5730.083, 22.875, 56.583)
# ('409017', datetime.date(2005, 1, 3), 2.442, 8322.135, 8604.148, 21.496, 46.406)
# ('409204C', datetime.date(2005, 1, 4), 1.173, 5720.694, 5710.436, 23.233, 56.583)
# ('409017', datetime.date(2005, 1, 4), 2.478, 8746.874, 8676.057, 22.052, 47.646)
# ('409204C', datetime.date(2005, 1, 5), 1.16, 5634.963, 5605.041, 23.807, 57.51)
# ('409017', datetime.date(2005, 1, 5), 2.468, 8622.648, 8676.057, 22.079, 47.875)
# ('409204C', datetime.date(2005, 1, 6), 1.149, 5564.604, 5531.891, 24.342, 58.917)
# ('409017', datetime.date(2005, 1, 6), 2.492, 8909.587, 9380.974, 22.055, 48.333)
# ('409204C', datetime.date(2005, 1, 7), 1.139, 5498.776, 5452.358, 24.742, 59.333)
# ('409017', datetime.date(2005, 1, 7), 2.526, 9312.978, 9252.527, 22.12, 48.823)
# ('409204C', datetime.date(2005, 1, 8), 1.124, 5396.04, 5325.046, 24.417, 59.167)
# ('409017', datetime.date(2005, 1, 8), 2.515, 9177.221, 9183.041, 21.732, 48.932)
# ('409204C', datetime.date(2005, 1, 9), 1.104, 5264.306, 5217.446, 23.955, 58.99)
# ('409017', datetime.date(2005, 1, 9), 2.545, 9540.767, 10102.03, 21.713, 48.349)
# ('409204C', datetime.date(2005, 1, 10), 1.094, 5194.897, 5149.761, 24.375, 59.0)
# ('409017', datetime.date(2005, 1, 10), 2.591, 10092.65, 10076.58, 21.8, 49.104)
# ('409204C', datetime.date(2005, 1, 11), 1.082, 5115.996, 5068.527, 24.608, 58.917)
# ('409017', datetime.date(2005, 1, 11), 2.595, 10133.16, 10102.03, 22.237, 49.729)
# ('409204C', datetime.date(2005, 1, 12), 1.056, 4941.781, 4870.048, 24.9, 59.063)
# ('409017', datetime.date(2005, 1, 12), 2.587, 10042.89, 10052.67, 23.021, 51.104)
# ('409204C', datetime.date(2005, 1, 13), 1.043, 4848.959, 4842.284, 25.509, 63.375)
# ('409017', datetime.date(2005, 1, 13), 2.586, 10030.66, 10028.78, 23.31, 52.063)
# ('409204C', datetime.date(2005, 1, 14), 1.036, 4804.328, 4759.556, 26.058, 63.417)
# ('409017', datetime.date(2005, 1, 14), 2.593, 10112.89, 10114.02, 23.426, 52.562)
# ('409204C', datetime.date(2005, 1, 15), 1.018, 4676.125, 4599.231, 25.644, 64.854)
# ('409017', datetime.date(2005, 1, 15), 2.607, 10265.58, 10708.28, 22.666, 51.427)
# ('409204C', datetime.date(2005, 1, 16), 0.995, 4528.845, 4471.516, 24.846, 67.958)
# ('409017', datetime.date(2005, 1, 16), 2.65, 10747.68, 10317.29, 22.238, 50.125)
# ('409204C', datetime.date(2005, 1, 17), 0.976, 4421.733, 4370.791, 24.2, 71.0)
# ('409017', datetime.date(2005, 1, 17), 2.622, 10432.47, 10708.28, 22.438, 50.63)
# ('409204C', datetime.date(2005, 1, 18), 0.951, 4290.13, 4185.903, 24.529, 72.542)
# ('409017', datetime.date(2005, 1, 18), 2.638, 10611.93, 10489.84, 22.706, 51.583)
# ('409204C', datetime.date(2005, 1, 19), 0.918, 4108.789, 4040.266, 25.251, 76.677)
# ('409017', datetime.date(2005, 1, 19), 2.634, 10570.7, 10884.72, 23.222, 52.781)
# ('409204C', datetime.date(2005, 1, 20), 0.896, 3982.64, 3965.955, 25.827, 76.5)
# ('409017', datetime.date(2005, 1, 20), 2.672, 10983.38, 11209.69, 23.386, 53.786)
# ('409204C', datetime.date(2005, 1, 21), 0.894, 3969.267, 3971.749, 26.258, 75.583)
# ('409017', datetime.date(2005, 1, 21), 2.718, 11491.34, 11798.08, 23.415, 53.609)
# ('409204C', datetime.date(2005, 1, 22), 0.89, 3948.216, 3908.021, 26.431, 76.813)
# ('409017', datetime.date(2005, 1, 22), 2.741, 11744.65, 11645.94, 23.079, 54.266)
# ('409204C', datetime.date(2005, 1, 23), 0.878, 3877.969, 3890.587, 25.837, 82.417)
# ('409017', datetime.date(2005, 1, 23), 2.701, 11309.01, 10796.96, 23.485, 55.49)
# ('409204C', datetime.date(2005, 1, 24), 0.881, 3893.509, 3902.157, 25.475, 81.833)
# ('409017', datetime.date(2005, 1, 24), 2.653, 10773.74, 10741.82, 23.63, 55.458)
# ('409204C', datetime.date(2005, 1, 25), 0.888, 3935.448, 3983.142, 25.668, 81.521)
# ('409017', datetime.date(2005, 1, 25), 2.65, 10741.03, 10676.15, 23.854, 55.833)
# ('409204C', datetime.date(2005, 1, 26), 0.909, 4059.794, 4107.924, 26.052, 79.5)
# ('409017', datetime.date(2005, 1, 26), 2.688, 11160.62, 11688.53, 24.319, 56.01)
# ('409204C', datetime.date(2005, 1, 27), 0.923, 4137.738, 4163.759, 26.608, 77.417)
# ('409017', datetime.date(2005, 1, 27), 2.725, 11573.6, 11439.68, 24.846, 57.438)
# ('409204C', datetime.date(2005, 1, 28), 0.937, 4211.079, 4268.132, 27.342, 79.583)
# ('409017', datetime.date(2005, 1, 28), 2.717, 11482.88, 11493.67, 25.103, 57.734)
# ('409204C', datetime.date(2005, 1, 29), 0.956, 4319.614, 4376.179, 28.058, 79.833)
# ('409017', datetime.date(2005, 1, 29), 2.741, 11745.53, 12197.27, 25.328, 58.109)
# ('409204C', datetime.date(2005, 1, 30), 0.981, 4451.973, 4523.952, 28.807, 62.438)
# ('409017', datetime.date(2005, 1, 30), 2.814, 12552.3, 12669.22, 25.609, 58.547)
# ('409204C', datetime.date(2005, 1, 31), 1.001, 4557.796, 4578.273, 29.35, 51.333)
# ('409017', datetime.date(2005, 1, 31), 2.814, 12547.43, 12454.25, 25.475, 57.005)
# ('409204C', datetime.date(2005, 2, 1), 1.006, 4594.456, 4591.963, 29.525, 52.083)
# ('409017', datetime.date(2005, 2, 1), 2.816, 12572.83, 12691.77, 25.813, 55.495)
# ('409204C', datetime.date(2005, 2, 2), 0.999, 4545.158, 4539.531, 29.805, 53.25)
# ('409017', datetime.date(2005, 2, 2), 2.784, 12220.94, 11504.23, 25.656, 55.76)
# ('409204C', datetime.date(2005, 2, 3), 0.996, 4530.465, 4534.448, 29.55, 53.417)
# ('409017', datetime.date(2005, 2, 3), 2.714, 11454.19, 11471.27, 26.006, 56.417)
# ('409204C', datetime.date(2005, 2, 4), 0.995, 4521.785, 4497.791, 29.483, 53.333)
# ('409017', datetime.date(2005, 2, 4), 2.766, 12016.96, 12921.25, 26.104, 57.13)
# ('409204C', datetime.date(2005, 2, 5), 0.99, 4495.623, 4482.104, 29.592, 53.75)
# ('409017', datetime.date(2005, 2, 5), 2.85, 12948.16, 12953.46, 26.204, 57.688)
# ('409204C', datetime.date(2005, 2, 6), 0.987, 4482.584, 4529.202, 29.523, 54.198)
# ('409017', datetime.date(2005, 2, 6), 2.832, 12751.79, 12298.66, 26.292, 56.891)
# ('409204C', datetime.date(2005, 2, 7), 1.01, 4623.3, 4717.61, 29.371, 54.0)
# ('409017', datetime.date(2005, 2, 7), 2.787, 12250.68, 12197.27, 25.967, 54.172)
# ('409204C', datetime.date(2005, 2, 8), 1.043, 4849.606, 4966.026, 28.697, 53.656)
# ('409017', datetime.date(2005, 2, 8), 2.758, 11934.6, 11558.41, 25.753, 53.297)
# ('409204C', datetime.date(2005, 2, 9), 1.069, 5027.186, 5115.821, 26.839, 54.0)
# ('409017', datetime.date(2005, 2, 9), 2.753, 11879.14, 11863.83, 25.748, 52.792)
# ('409204C', datetime.date(2005, 2, 10), 1.088, 5155.57, 5197.25, 25.35, 54.0)
# ('409017', datetime.date(2005, 2, 10), 2.765, 12010.92, 12442.44, 25.55, 52.188)
# ('409204C', datetime.date(2005, 2, 11), 1.101, 5247.334, 5298.411, 24.083, 53.667)
# ('409017', datetime.date(2005, 2, 11), 2.807, 12479.89, 12454.25, 24.833, 52.479)
# ('409204C', datetime.date(2005, 2, 12), 1.115, 5341.475, 5372.075, 23.583, 53.583)
# ('409017', datetime.date(2005, 2, 12), 2.806, 12468.03, 12485.76, 23.96, 51.229)
# ('409204C', datetime.date(2005, 2, 13), 1.128, 5424.43, 5465.366, 23.333, 53.0)
# ('409017', datetime.date(2005, 2, 13), 2.774, 12106.49, 11358.97, 23.417, 50.698)
# ('409204C', datetime.date(2005, 2, 14), 1.138, 5488.884, 5505.552, 23.8, 53.0)
# ('409017', datetime.date(2005, 2, 14), 2.699, 11283.06, 11213.83, 23.644, 50.771)
# ('409204C', datetime.date(2005, 2, 15), 1.146, 5544.16, 5571.936, 24.067, 52.583)
# ('409017', datetime.date(2005, 2, 15), 2.7, 11301.17, 11471.27, 23.4, 51.0)
# ('409204C', datetime.date(2005, 2, 16), 1.149, 5563.634, 5565.066, 24.424, 52.333)
# ('409017', datetime.date(2005, 2, 16), 2.721, 11525.66, 11569.0, 23.34, 50.104)
# ('409204C', datetime.date(2005, 2, 17), 1.157, 5619.547, 5670.678, 24.681, 52.583)
# ('409017', datetime.date(2005, 2, 17), 2.72, 11510.47, 11311.23, 23.439, 49.417)
# ('409204C', datetime.date(2005, 2, 18), 1.172, 5717.402, 5756.116, 24.842, 52.583)
# ('409017', datetime.date(2005, 2, 18), 2.696, 11252.64, 11142.32, 23.4, 49.417)
# ('409204C', datetime.date(2005, 2, 19), 1.183, 5791.2, 5808.478, 24.933, 52.167)
# ('409017', datetime.date(2005, 2, 19), 2.681, 11088.36, 11062.88, 23.358, 49.167)
# ('409204C', datetime.date(2005, 2, 20), 1.187, 5815.127, 5834.807, 24.908, 51.583)
# ('409017', datetime.date(2005, 2, 20), 2.694, 11226.56, 11537.25, 23.278, 49.005)
# ('409204C', datetime.date(2005, 2, 21), 1.192, 5850.977, 5860.703, 24.4, 51.0)
# ('409017', datetime.date(2005, 2, 21), 2.722, 11536.13, 11537.25, 23.593, 48.146)
# ('409204C', datetime.date(2005, 2, 22), 1.198, 5888.596, 5906.601, 24.292, 51.583)
# ('409017', datetime.date(2005, 2, 22), 2.72, 11520.16, 11504.23, 23.798, 48.917)
# ('409204C', datetime.date(2005, 2, 23), 1.202, 5913.932, 5900.082, 24.233, 52.25)
# ('409017', datetime.date(2005, 2, 23), 2.721, 11523.67, 11483.13, 23.338, 47.042)
# ('409204C', datetime.date(2005, 2, 24), 1.206, 5940.869, 5986.724, 23.542, 53.75)
# ('409017', datetime.date(2005, 2, 24), 2.721, 11528.02, 11558.41, 23.041, 47.042)
# ('409204C', datetime.date(2005, 2, 25), 1.223, 6055.816, 6099.318, 23.242, 55.083)
# ('409017', datetime.date(2005, 2, 25), 2.723, 11547.6, 11602.13, 22.908, 45.542)
# ('409204C', datetime.date(2005, 2, 26), 1.234, 6129.162, 6139.283, 23.408, 55.5)
# ('409017', datetime.date(2005, 2, 26), 2.728, 11605.12, 11602.13, 22.967, 44.708)
# ('409204C', datetime.date(2005, 2, 27), 1.24, 6163.335, 6178.778, 23.817, 54.25)
# ('409017', datetime.date(2005, 2, 27), 2.714, 11453.5, 11164.29, 23.102, 46.188)
# ('409204C', datetime.date(2005, 2, 28), 1.239, 6155.675, 6152.187, 23.767, 53.25)
# ('409017', datetime.date(2005, 2, 28), 2.684, 11119.79, 11086.13, 23.417, 46.917)
# ('409204C', datetime.date(2005, 3, 1), 1.237, 6148.455, 6132.425, 23.475, 52.0)
# ('409017', datetime.date(2005, 3, 1), 2.683, 11111.87, 11097.08, 22.987, 44.813)
# ('409204C', datetime.date(2005, 3, 2), 1.229, 6090.398, 6092.852, 23.496, 51.417)
# ('409017', datetime.date(2005, 3, 2), 2.692, 11209.14, 11364.86, 22.972, 44.833)
# ('409204C', datetime.date(2005, 3, 3), 1.228, 6087.296, 6106.185, 23.396, 51.333)
# ('409017', datetime.date(2005, 3, 3), 2.683, 11110.59, 10664.11, 22.757, 41.589)
# ('409204C', datetime.date(2005, 3, 4), 1.226, 6072.396, 6079.512, 22.384, 52.271)
# ('409017', datetime.date(2005, 3, 4), 2.612, 10308.47, 9629.412, 22.473, 39.604)
# ('409204C', datetime.date(2005, 3, 5), 1.23, 6096.688, 6112.647, 21.4, 50.583)
# ('409017', datetime.date(2005, 3, 5), 2.536, 9423.867, 9288.1, 21.876, 38.224)
# ('409204C', datetime.date(2005, 3, 6), 1.232, 6115.472, 6106.185, 21.167, 50.0)
# ('409017', datetime.date(2005, 3, 6), 2.535, 9418.73, 9785.934, 21.766, 37.958)
# ('409204C', datetime.date(2005, 3, 7), 1.23, 6099.484, 6092.852, 21.358, 49.75)
# ('409017', datetime.date(2005, 3, 7), 2.562, 9738.154, 9725.779, 21.704, 38.729)
# ('409204C', datetime.date(2005, 3, 8), 1.228, 6088.438, 6079.512, 21.467, 48.417)
# ('409017', datetime.date(2005, 3, 8), 2.559, 9706.951, 9714.068, 21.517, 39.688)
# ('409204C', datetime.date(2005, 3, 9), 1.227, 6081.331, 6073.041, 21.591, 48.333)
# ('409017', datetime.date(2005, 3, 9), 2.559, 9702.34, 9677.524, 21.956, 39.917)
# ('409204C', datetime.date(2005, 3, 10), 1.226, 6075.245, 6152.187, 21.602, 49.354)
# ('409017', datetime.date(2005, 3, 10), 2.56, 9718.266, 9906.911, 22.2, 40.521)
# ('409204C', datetime.date(2005, 3, 11), 1.224, 6062.256, 5986.724, 21.843, 49.365)
# ('409017', datetime.date(2005, 3, 11), 2.597, 10141.95, 10577.43, 22.203, 40.729)
# ('409204C', datetime.date(2005, 3, 12), 1.203, 5922.568, 5847.958, 22.074, 48.333)
# ('409017', datetime.date(2005, 3, 12), 2.633, 10552.73, 10566.79, 21.415, 39.563)
# ('409204C', datetime.date(2005, 3, 13), 1.186, 5809.724, 5756.116, 22.6, 48.75)
# ('409017', datetime.date(2005, 3, 13), 2.626, 10480.19, 10263.64, 21.894, 38.563)
# ('409204C', datetime.date(2005, 3, 14), 1.169, 5700.031, 5617.945, 22.753, 49.0)
# ('409017', datetime.date(2005, 3, 14), 2.6, 10196.94, 10150.04, 21.975, 39.13)
# ('409204C', datetime.date(2005, 3, 15), 1.146, 5543.637, 5478.771, 21.533, 49.5)
# ('409017', datetime.date(2005, 3, 15), 2.589, 10070.62, 9991.531, 21.357, 39.063)
# ('409204C', datetime.date(2005, 3, 16), 1.127, 5416.049, 5352.051, 20.775, 49.0)
# ('409017', datetime.date(2005, 3, 16), 2.581, 9969.706, 9918.762, 21.092, 37.875)
# ('409204C', datetime.date(2005, 3, 17), 1.106, 5275.877, 5190.651, 20.45, 48.5)
# ('409017', datetime.date(2005, 3, 17), 2.559, 9702.991, 9310.91, 21.143, 36.568)
# ('409204C', datetime.date(2005, 3, 18), 1.078, 5090.985, 5014.019, 20.519, 49.167)
# ('409017', datetime.date(2005, 3, 18), 2.496, 8956.753, 8325.721, 21.061, 37.458)
# ('409204C', datetime.date(2005, 3, 19), 1.056, 4938.992, 4856.172, 21.017, 49.969)
# ('409017', datetime.date(2005, 3, 19), 2.44, 8303.226, 8511.203, 20.835, 38.271)
# ('409204C', datetime.date(2005, 3, 20), 1.028, 4745.601, 4641.062, 21.525, 50.208)
# ('409017', datetime.date(2005, 3, 20), 2.459, 8517.099, 8499.806, 20.942, 40.479)
# ('409204C', datetime.date(2005, 3, 21), 0.997, 4539.281, 4450.444, 21.91, 51.073)
# ('409017', datetime.date(2005, 3, 21), 2.452, 8436.218, 8394.813, 21.44, 42.125)
# ('409204C', datetime.date(2005, 3, 22), 0.964, 4357.956, 4262.809, 22.339, 52.396)
# ('409017', datetime.date(2005, 3, 22), 2.45, 8417.97, 8522.61, 21.329, 42.313)
# ('409204C', datetime.date(2005, 3, 23), 0.929, 4169.248, 4113.567, 22.123, 52.104)
# ('409017', datetime.date(2005, 3, 23), 2.452, 8442.421, 8394.813, 21.303, 43.161)
# ('409204C', datetime.date(2005, 3, 24), 0.903, 4023.131, 3954.349, 21.981, 50.875)
# ('409017', datetime.date(2005, 3, 24), 2.442, 8324.127, 8279.382, 21.056, 43.146)
# ('409204C', datetime.date(2005, 3, 25), 0.878, 3876.197, 3808.137, 22.358, 51.333)
# ('409017', datetime.date(2005, 3, 25), 2.45, 8415.95, 8722.267, 20.869, 42.859)
# ('409204C', datetime.date(2005, 3, 26), 0.851, 3715.097, 3626.89, 22.4, 52.208)
# ('409017', datetime.date(2005, 3, 26), 2.456, 8486.47, 8153.792, 20.886, 44.5)
# ('409204C', datetime.date(2005, 3, 27), 0.821, 3536.073, 3451.473, 21.805, 53.344)
# ('409017', datetime.date(2005, 3, 27), 2.405, 7911.949, 7137.658, 20.846, 46.036)
# ('409204C', datetime.date(2005, 3, 28), 0.793, 3357.718, 3262.693, 21.543, 55.771)
# ('409017', datetime.date(2005, 3, 28), 2.319, 7021.347, 6977.009, 20.819, 46.75)
# ('409204C', datetime.date(2005, 3, 29), 0.764, 3173.371, 3073.623, 21.447, 55.917)
# ('409017', datetime.date(2005, 3, 29), 2.312, 6949.455, 6948.036, 20.969, 46.75)
# ('409204C', datetime.date(2005, 3, 30), 0.734, 2968.548, 2881.561, 21.252, 54.948)
# ('409017', datetime.date(2005, 3, 30), 2.307, 6899.906, 6879.513, 20.954, 44.417)
# ('409204C', datetime.date(2005, 3, 31), 0.713, 2821.487, 2773.949, 21.558, 54.0)
# ('409017', datetime.date(2005, 3, 31), 2.331, 7152.066, 8499.806, 20.921, 45.0)
# ('409204C', datetime.date(2005, 4, 1), 0.698, 2721.779, 2667.749, 21.833, 53.5)
# ('409017', datetime.date(2005, 4, 1), 2.497, 8972.182, 10741.82, 21.167, 45.766)
# ('409204C', datetime.date(2005, 4, 2), 0.677, 2609.139, 2552.696, 22.194, 54.458)
# ('409017', datetime.date(2005, 4, 2), 2.638, 10596.43, 9263.902, 21.505, 47.51)
# ('409204C', datetime.date(2005, 4, 3), 0.653, 2470.194, 2409.639, 22.102, 55.0)
# ('409017', datetime.date(2005, 4, 3), 2.472, 8684.356, 7817.866, 21.569, 49.823)
# ('409204C', datetime.date(2005, 4, 4), 0.637, 2373.525, 2358.659, 20.633, 51.75)
# ('409017', datetime.date(2005, 4, 4), 2.389, 7734.209, 7744.308, 21.125, 52.604)
# ('409204C', datetime.date(2005, 4, 5), 0.637, 2368.798, 2390.783, 20.125, 51.5)
# ('409017', datetime.date(2005, 4, 5), 2.403, 7883.954, 7861.138, 20.715, 52.688)
# ('409204C', datetime.date(2005, 4, 6), 0.637, 2372.584, 2358.659, 19.157, 50.24)
# ('409017', datetime.date(2005, 4, 6), 2.39, 7747.374, 7649.435, 20.281, 44.875)
# ('409204C', datetime.date(2005, 4, 7), 0.628, 2310.373, 2271.601, 18.583, 49.417)
# ('409017', datetime.date(2005, 4, 7), 2.368, 7511.15, 7299.264, 19.925, 40.771)
# ('409204C', datetime.date(2005, 4, 8), 0.615, 2221.495, 2185.795, 18.604, 49.094)
# ('409204C', datetime.date(2005, 4, 9), 0.601, 2131.538, 2101.01, 18.816, 49.469)
# ('409204C', datetime.date(2005, 4, 10), 0.591, 2096.919, 2086.492, 19.183, 49.25)
# ('409017', datetime.date(2005, 4, 10), 2.251, 6325.03, 6489.158, 19.017, 41.391)
# ('409204C', datetime.date(2005, 4, 11), 0.585, 2087.177, 2094.728, 19.175, 48.667)
# ('409017', datetime.date(2005, 4, 11), 2.265, 6472.418, 6571.326, 18.807, 41.786)
# ('409204C', datetime.date(2005, 4, 12), 0.599, 2119.16, 2163.558, 19.212, 48.323)
# ('409017', datetime.date(2005, 4, 12), 2.269, 6508.126, 6448.307, 18.731, 42.521)
# ('409204C', datetime.date(2005, 4, 13), 0.611, 2195.531, 2222.185, 19.158, 49.0)
# ('409017', datetime.date(2005, 4, 13), 2.233, 6157.826, 5650.233, 18.693, 42.448)
# ('409204C', datetime.date(2005, 4, 14), 0.617, 2232.954, 2236.552, 19.117, 49.833)
# ('409017', datetime.date(2005, 4, 14), 2.167, 5519.764, 5228.071, 18.615, 43.229)
# ('409204C', datetime.date(2005, 4, 15), 0.612, 2197.167, 2200.561, 18.451, 50.917)
# ('409017', datetime.date(2005, 4, 15), 2.132, 5200.286, 5309.387, 18.1, 44.396)
# ('409204C', datetime.date(2005, 4, 16), 0.609, 2180.781, 2171.088, 17.8, 50.083)
# ('409017', datetime.date(2005, 4, 16), 2.162, 5471.384, 5915.979, 17.324, 44.104)
# ('409204C', datetime.date(2005, 4, 17), 0.61, 2183.995, 2178.576, 17.875, 49.833)
# ('409017', datetime.date(2005, 4, 17), 2.211, 5934.655, 5935.946, 17.437, 45.042)
# ('409204C', datetime.date(2005, 4, 18), 0.603, 2131.784, 2108.537, 17.808, 49.833)
# ('409017', datetime.date(2005, 4, 18), 2.208, 5909.564, 5887.859, 16.983, 44.667)
# ('409204C', datetime.date(2005, 4, 19), 0.593, 2099.381, 2096.335, 17.758, 48.917)
# ('409017', datetime.date(2005, 4, 19), 2.201, 5838.415, 5801.55, 16.925, 43.979)
# ('409204C', datetime.date(2005, 4, 20), 0.589, 2092.563, 2093.105, 17.792, 49.417)
# ('409017', datetime.date(2005, 4, 20), 2.192, 5756.547, 5725.014, 17.152, 43.646)
# ('409204C', datetime.date(2005, 4, 21), 0.594, 2100.963, 2105.551, 17.867, 54.0)
# ('409017', datetime.date(2005, 4, 21), 2.205, 5885.326, 6448.307, 16.747, 43.563)
# ('409204C', datetime.date(2005, 4, 22), 0.591, 2095.512, 2086.492, 17.842, 56.625)
# ('409017', datetime.date(2005, 4, 22), 2.247, 6287.819, 5781.778, 16.63, 43.521)
# ('409204C', datetime.date(2005, 4, 23), 0.58, 2078.372, 2066.723, 17.641, 57.281)
# ('409017', datetime.date(2005, 4, 23), 2.154, 5409.875, 4708.878, 16.318, 44.042)
# ('409204C', datetime.date(2005, 4, 24), 0.571, 2060.331, 2048.4, 17.49, 55.896)
# ('409017', datetime.date(2005, 4, 24), 2.033, 4381.212, 3676.306, 15.901, 44.49)
# ('409204C', datetime.date(2005, 4, 25), 0.571, 2060.272, 2084.833, 16.908, 53.292)
# ('409017', datetime.date(2005, 4, 25), 1.9, 3386.888, 2929.769, 15.91, 44.302)
# ('409204C', datetime.date(2005, 4, 26), 0.588, 2091.45, 2117.899, 15.771, 49.167)
# ('409017', datetime.date(2005, 4, 26), 1.784, 2657.027, 1964.472, 15.157, 45.182)
# ('409204C', datetime.date(2005, 4, 27), 0.625, 2289.382, 2471.024, 14.909, 46.979)
# ('409017', datetime.date(2005, 4, 27), 1.692, 2131.873, 2083.215, 14.251, 43.859)
# ('409204C', datetime.date(2005, 4, 28), 0.667, 2552.438, 2635.823, 14.722, 45.271)
# ('409017', datetime.date(2005, 4, 28), 1.615, 1758.802, 1676.276, 13.436, 40.844)
# ('409204C', datetime.date(2005, 4, 29), 0.692, 2689.099, 2724.934, 14.317, 41.25)
# ('409017', datetime.date(2005, 4, 29), 1.574, 1577.205, 1509.18, 12.341, 37.0)
# ('409204C', datetime.date(2005, 4, 30), 0.694, 2698.293, 2709.609, 14.056, 39.042)
# ('409017', datetime.date(2005, 4, 30), 1.555, 1495.291, 1356.156, 11.939, 32.401)
# ('409204C', datetime.date(2005, 5, 1), 0.694, 2697.464, 2699.206, 14.35, 39.917)
# ('409017', datetime.date(2005, 5, 1), 1.502, 1279.157, 1332.366, 11.841, 32.938)
# ('409204C', datetime.date(2005, 5, 2), 0.693, 2694.377, 2651.866, 14.642, 41.25)
# ('409017', datetime.date(2005, 5, 2), 1.52, 1346.752, 1300.959, 12.494, 35.896)
# ('409204C', datetime.date(2005, 5, 3), 0.67, 2568.416, 2529.784, 14.453, 40.552)
# ('409017', datetime.date(2005, 5, 3), 1.486, 1218.943, 1203.015, 12.777, 38.563)
# ('409204C', datetime.date(2005, 5, 4), 0.653, 2469.567, 2446.629, 14.483, 40.75)
# ('409017', datetime.date(2005, 5, 4), 1.48, 1195.763, 1166.714, 12.99, 41.0)
# ('409204C', datetime.date(2005, 5, 5), 0.644, 2415.753, 2409.639, 14.373, 39.479)
# ('409017', datetime.date(2005, 5, 5), 1.47, 1158.526, 1141.872, 13.06, 41.813)
# ('409204C', datetime.date(2005, 5, 6), 0.641, 2394.94, 2384.377, 14.25, 39.0)
# ('409017', datetime.date(2005, 5, 6), 1.471, 1161.829, 1281.528, 13.165, 42.854)
# ('409204C', datetime.date(2005, 5, 7), 0.634, 2348.499, 2292.12, 14.05, 38.083)
# ('409017', datetime.date(2005, 5, 7), 1.524, 1365.544, 1388.599, 13.127, 43.396)
# ('409204C', datetime.date(2005, 5, 8), 0.617, 2233.26, 2185.795, 14.019, 37.385)
# ('409017', datetime.date(2005, 5, 8), 1.507, 1298.944, 1072.179, 13.105, 43.578)
# ('409204C', datetime.date(2005, 5, 9), 0.588, 2099.64, 2060.874, 14.15, 37.76)
# ('409017', datetime.date(2005, 5, 9), 1.472, 1166.936, 1225.026, 12.873, 42.333)
# ('409204C', datetime.date(2005, 5, 10), 0.555, 2023.948, 1994.499, 14.104, 38.385)
# ('409017', datetime.date(2005, 5, 10), 1.494, 1246.048, 1192.099, 12.998, 40.958)
# ('409204C', datetime.date(2005, 5, 11), 0.534, 1958.392, 1959.86, 14.054, 38.646)
# ('409017', datetime.date(2005, 5, 11), 1.473, 1168.779, 1192.099, 12.958, 40.958)
# ('409204C', datetime.date(2005, 5, 12), 0.538, 1975.382, 1991.358, 14.017, 38.667)
# ('409017', datetime.date(2005, 5, 12), 1.486, 1219.034, 1217.812, 12.877, 40.771)
# ('409204C', datetime.date(2005, 5, 13), 0.546, 2000.689, 2011.907, 13.792, 38.5)
# ('409017', datetime.date(2005, 5, 13), 1.484, 1212.056, 1217.812, 12.571, 40.583)
# ('409204C', datetime.date(2005, 5, 14), 0.553, 2018.924, 2043.983, 13.757, 45.438)
# ('409017', datetime.date(2005, 5, 14), 1.487, 1222.575, 1228.869, 12.677, 40.104)
# ('409204C', datetime.date(2005, 5, 15), 0.577, 2072.097, 2094.728, 13.851, 38.01)
# ('409017', datetime.date(2005, 5, 15), 1.492, 1239.378, 1251.162, 12.888, 40.75)
# ('409204C', datetime.date(2005, 5, 16), 0.604, 2153.007, 2312.337, 14.198, 39.729)
# ('409017', datetime.date(2005, 5, 16), 1.471, 1170.961, 895.048, 13.187, 41.469)
# ('409204C', datetime.date(2005, 5, 17), 0.66, 2508.258, 2678.357, 13.862, 39.063)
# ('409017', datetime.date(2005, 5, 17), 1.537, 1485.14, 1979.05, 11.971, 37.385)
# ('409204C', datetime.date(2005, 5, 18), 0.705, 2771.722, 2824.684, 13.815, 38.708)
# ('409017', datetime.date(2005, 5, 18), 1.597, 1681.742, 1376.256, 11.011, 31.115)
# ('409204C', datetime.date(2005, 5, 19), 0.713, 2827.017, 2824.684, 13.85, 39.5)
# ('409017', datetime.date(2005, 5, 19), 1.489, 1229.131, 1141.872, 10.983, 30.646)
# ('409204C', datetime.date(2005, 5, 20), 0.716, 2844.83, 2881.561, 14.058, 41.75)
# ('409017', datetime.date(2005, 5, 20), 1.48, 1196.098, 1225.026, 11.454, 32.125)
# ('409204C', datetime.date(2005, 5, 21), 0.731, 2951.734, 3033.432, 14.04, 41.813)
# ('409017', datetime.date(2005, 5, 21), 1.488, 1227.102, 1266.311, 11.583, 32.813)
# ('409204C', datetime.date(2005, 5, 22), 0.756, 3121.649, 3230.753, 13.95, 42.521)
# ('409017', datetime.date(2005, 5, 22), 1.5, 1269.301, 1254.824, 11.585, 32.271)
# SELECT count(*) FROM Measurement
# (284,)
# True

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 2: Data Cleaning
#
# ### Data Cleaning
# We re-use the clean() function from last week.

# %%
import numpy as np
DEFAULT_VALUE = np.nan

def clean(data, column_key, convert_function, default_value):
    special_values= {} # no special values yet
    for row in data:
        old_value = row[column_key]
        new_value = default_value
        try:
            if old_value in special_values.keys():
                new_value = special_values[old_value]
            else:
                new_value = convert_function(old_value)
        except (ValueError, TypeError):
            print('Replacing {} with {} in column {}'.format(row[column_key], new_value, column_key))
        row[column_key] = new_value

# %%
# this conversion strips any leading or trailing spaces from the 'Station' values
clean(data_measurements, 'Station', str.strip, DEFAULT_VALUE)

# the following converts the two measurment  columns to float  values - or NaN
clean(data_measurements, 'Discharge', float, DEFAULT_VALUE)
clean(data_measurements, 'MeanDischarge', float, DEFAULT_VALUE)
clean(data_measurements, 'Level', float, DEFAULT_VALUE)
clean(data_measurements, 'Temp', float, DEFAULT_VALUE)
clean(data_measurements, 'EC', float, DEFAULT_VALUE)

##now we insert the  data_measurements into the 'Measurement' table 
# 1st: login to database
if(conn):
    conn.close();
conn = pgconnect()

# 2nd: ensure that the schema is in place
pgexec (conn, "DROP TABLE IF EXISTS Measurement", None, "Reset Table Measurement")
measurement_schema = """CREATE TABLE IF NOT EXISTS Measurement (
                         station   VARCHAR(20),
                         date DATE,
                         level  FLOAT,
                         meanDischarge FLOAT,
                         discharge  FLOAT,
                         temp FLOAT,
                         ec  FLOAT
                      )"""
pgexec (conn, measurement_schema, None, "Create Table Measurement")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,level,meandischarge,discharge,temp,ec)
                      VALUES (%(Station)s, %(Date)s, %(Level)s,%(MeanDischarge)s,%(Discharge)s,%(Temp)s,%(EC)s)"""
for row in data_measurements:
    pgexec (conn, insert_stmt, row, "row inserted")
    
query_stmt = "SELECT COUNT(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)
# Out:
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# connected
# success: Reset Table Measurement
# success: Create Table Measurement
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# SELECT COUNT(*) FROM Measurement
# (431,)
# True

# %% [markdown]
# ## Your Task: Data Cleaning
#
# Use above's  clean()  function to clean the other give data set too.
#  1. read the Stations csv file into data_stations
#  2. Clean the  'data_stations'  data set
#  3. Reload the 'data_stations'  dictionary into your database
#  4. Query the 'Stations' table - which difference do you see?
#
#  5. If you have time: Do all of the above (reading - cleaning - loading) also for the 'Sensors.csv' data set

# %% [markdown]
# Note: You might encounter a few warning and error messages.
#    - If a connection is closed, you have to open the databse connection again first
#    - If the clean() function returns a warning that some string was replaced with NaN, as long as this is indeed a number attribute, you are Ok to ignore this message. It just tells you that it is doing what it is supposed to do.
#    - If you try to insert data into an already existing table with data inside, you might get 'duplicate primary key' error messages. Again, you can ignore those for the moment.
#    - If you want to see who much data is already in your table, use the following SQL query:
#      -  SELECT COUNT(*) FROM Stations;

# %%
# TODO: replace the content of this cell with your Python solution
#raise NotImplementedError


data_stations = list(csv.DictReader(open('Stations.csv')))
pprint.pprint(data_stations[0])

# this conversion strips any leading or trailing spaces from the 'Station' values
clean(data_stations, 'BasinNo', str.strip, DEFAULT_VALUE)
clean(data_stations, 'Site', str.strip, DEFAULT_VALUE)
clean(data_stations, 'Commence', str.strip, DEFAULT_VALUE)


##now we inser the  data_stations into the 'Stations' table 
# 1st: login to database
if(conn):
    conn.close();
conn = pgconnect()

# 2nd: ensure that the schema is in place
pgexec (conn, "DROP TABLE IF EXISTS Station", None, "Reset Table Station")
stations_schema = """CREATE TABLE IF NOT EXISTS Station (
                         basinNO   VARCHAR(50),
                         site VARCHAR(50),
                         siteName  VARCHAR(50),
                         lon VARCHAR(50),
                         lat  VARCHAR(50),
                         commence Date,
                         orgCode  VARCHAR(50)                         
                      )"""
pgexec (conn, stations_schema, None, "Create Table Station")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Station(basinNO,site,siteName,lon,lat,commence,orgCode)
                      VALUES (%(BasinNo)s, %(Site)s, %(SiteName)s,%(Long)s,%(Lat)s,%(Commence)s,%(OrgCode)s)"""
for row in data_stations:
    pgexec (conn, insert_stmt, row, "row inserted")

query_stmt = "SELECT * FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)

query_stmt = "SELECT COUNT(*) FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)

   
    
###Sensors data

data_sensors = list(csv.DictReader(open('Sensors.csv')))
pprint.pprint(data_sensors[0])


##now we insert the  data_stations into the 'Stations' table 
# 1st: login to database
if(conn):
    conn.close();
conn = pgconnect()

# 2nd: ensure that the schema is in place
pgexec (conn, "DROP TABLE IF EXISTS Sensor", None, "Reset Table Sensor")
stations_schema = """CREATE TABLE IF NOT EXISTS Sensor (
                         sensor   VARCHAR(20) PRIMARY KEY,
                         description  VARCHAR(150),
                         metric  VARCHAR(150)                   
                      )"""
pgexec (conn, stations_schema, None, "Create Table Sensor")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Sensor(sensor,description,metric)
                      VALUES (%(sensor)s, %(description)s, %(metric)s)"""
for row in data_sensors:
    pgexec (conn, insert_stmt, row, "row inserted")

query_stmt = "SELECT COUNT(*) FROM Sensor"
print(query_stmt)
pgquery (conn, query_stmt, None)
# Out:
# OrderedDict([('BasinNo', '409'),
#              ('Site', '001'),
#              ('SiteName', 'Murray River at Albury (Union Bridge)'),
#              ('Long', '146.8957 E'),
#              ('Lat', '36.0929 S'),
#              ('Commence', '14/04/1892'),
#              ('OrgCode', 'DWR')])
# connected
# success: Reset Table Station
# success: Create Table Station
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# SELECT * FROM Station
# ('409', '001', 'Murray River at Albury (Union Bridge)', '146.8957 E', '36.0929 S', datetime.date(1892, 4, 14), 'DWR')
# ('409', '002', 'Murray River at Corowa', '146.3954 E', '36.0076 S', datetime.date(1894, 4, 1), 'DWR')
# ('409', '003', 'Murray River at Denuquin', '144.9663 E', '35.5301 S', datetime.date(1896, 9, 1), 'DWR')
# ('409', '005', 'Murray River at Barham', '144.1235 E', '35.6304 S', datetime.date(1900, 12, 31), 'DWR')
# ('409', '204C', 'Murray River @ Swan Hill', '143.5680 E', '35.3318 S', datetime.date(1904, 12, 31), 'VRW')
# ('409', '017', 'Murray River @ Doctors Point', '146.9401 E', '36.1129 S', datetime.date(1925, 8, 22), 'DWR')
# ('409', '019', 'Wakool River at Offtake Regulator', '144.8846 E', '35.4985 S', datetime.date(1931, 2, 7), 'DWR')
# ('409', '202', 'Murray River @ Tocumwal', '145.5596 E', '35.8151 S', datetime.date(1886, 6, 6), 'VRW')
# ('219', '018', 'Murray River @ Quaama', '149.8526 E', '36.4762 S', datetime.date(1962, 11, 7), 'DWR')
# SELECT COUNT(*) FROM Station
# (9,)
# OrderedDict([('sensor', 'levl'),
#              ('description', 'Level - Stream Water (Gauge Height)'),
#              ('metric', 'meter')])
# connected
# success: Reset Table Sensor
# success: Create Table Sensor
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# SELECT COUNT(*) FROM Sensor
# (7,)
# True

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## Demo: Data Modelling & DB Creation
# Next, we will look in the lecture at modelling the data correctly for a normalised relational star schema. We will discuss an example solution for the given water data model in the class.
#
# ## Your Homework Task: Data Modelling
# Have a look at the Excel workbook and check how we have modeled its content into a normalised relational data model as shown in our proposed relational schema further down in this notebook.

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 3: Database Creation
# After we discussed the model, we will give you an example solution (see below).
# The next step is to create the corresponding SQL schema in your PostgreSQL database.
#
# ### Your Task: DB Creation in PostgreSQL
# Create the corresponding tables in PostgreSQL which follow from the data model.

# %% [markdown]
# <pre>
# DROP TABLE IF EXISTS Organisation CASCADE;
# CREATE TABLE IF NOT EXISTS Organisation (
#    code VARCHAR(20) PRIMARY KEY,
#    organisation    VARCHAR(150)
# );
#
# DROP TABLE IF EXISTS Station CASCADE;
# CREATE TABLE IF NOT EXISTS Station (
#      station   VARCHAR(50) PRIMARY KEY,
#      siteName  VARCHAR(50),
#      commence Date,
#      orgCode  VARCHAR(50),
#      CONSTRAINT orgCodeFK FOREIGN KEY (orgCode)   REFERENCES Organisation (code)
#  );
#
# DROP TABLE IF EXISTS Sensor CASCADE;
# CREATE TABLE IF NOT EXISTS Sensor (
#      sensor   VARCHAR(20) PRIMARY KEY,
#      description  VARCHAR(150) ,
#      metric VARCHAR(20)
#   );
#
# DROP TABLE IF EXISTS Measurement CASCADE;
# CREATE TABLE IF NOT EXISTS Measurement (
#      station   VARCHAR(20),
#      sensor   VARCHAR(20),
#      date DATE,
#      value  FLOAT,
#      CONSTRAINT stationFK FOREIGN KEY (station)   REFERENCES Station (Station),
#      CONSTRAINT sensorFK FOREIGN KEY (sensor)   REFERENCES sensor (sensor)
#   );
#
# </pre>

# %%
# TODO: replace the content of this cell with your Python + SQL solution
##raise NotImplementedError
# make sure we are still connected to database 
if conn is None or conn.closed:
    conn = pgconnect()
    
table_schema = """
DROP TABLE IF EXISTS Organisation CASCADE;
CREATE TABLE IF NOT EXISTS Organisation (
   code VARCHAR(20) PRIMARY KEY,
   organisation    VARCHAR(150)
);

DROP TABLE IF EXISTS Station CASCADE;
CREATE TABLE IF NOT EXISTS Station (
     station   VARCHAR(50) PRIMARY KEY,
     siteName  VARCHAR(50),
     commence Date,
     orgCode  VARCHAR(50),
     CONSTRAINT orgCodeFK FOREIGN KEY (orgCode)   REFERENCES Organisation (code)
 );

DROP TABLE IF EXISTS Sensor CASCADE;
CREATE TABLE IF NOT EXISTS Sensor (
     sensor   VARCHAR(20) PRIMARY KEY,
     description  VARCHAR(150) ,       
     metric VARCHAR(20)                 
  );

DROP TABLE IF EXISTS Measurement CASCADE;
CREATE TABLE IF NOT EXISTS Measurement (
     station   VARCHAR(20),
     date DATE,
     sensor   VARCHAR(20),
     value  FLOAT,
     CONSTRAINT stationFK FOREIGN KEY (station)   REFERENCES Station (station),
     CONSTRAINT sensorFK FOREIGN KEY (sensor)   REFERENCES sensor (sensor)
  );"""   

pgexec (conn, table_schema, None, "Created New Schema")

conn.close();
# Out:
# success: Created New Schema

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 4: Data Loading and Storage
#
# Up-to this point, we have
#  - analysed and modelled the given data set
#  - created a corresponding relational star schema
#  - read the individual CSV files into Python dictionary data structures
#  - cleaned the raw data with regard to missing or inconsistent entries and data types
#
# The final step is to load this cleaned data into the corresponding tables of the star schema which we defined so far.
#
# For this to work, you probably will need to write some logic to load different parts of different data dictionaries (holding the content of CSV files) into different tables.

# %%
import numpy as np
import csv
import pprint
# Organisation table
data_organisations = list(csv.DictReader(open('Organisations.csv')))

# make sure we are still connected to database 
if conn is None or conn.closed:
    conn = pgconnect()

# check for any existing content of the Organisations table
query_stmt = "SELECT COUNT(*) FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)

# Try to load data - 9 tupels should be created
insert_stmt = """INSERT INTO Organisation(code,organisation) VALUES (%(Code)s, %(Organisation)s)"""
for row in data_organisations:
    pgexec (conn, insert_stmt, row, "row inserted")
    
#####################
# Station table    
data_stations = list(csv.DictReader(open('Stations.csv')))

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Station(station,siteName,commence,orgCode)
                      VALUES (%(station)s, %(siteName)s, %(commence)s,%(orgCode)s)"""
stationData = dict()
for row in data_stations:
    stationData['station'] = row['BasinNo']+row['Site']
    stationData['siteName']  = row['SiteName']
    stationData['commence'] = row['Commence']
    stationData['orgCode'] = row['OrgCode']
    pgexec (conn, insert_stmt, stationData, "station inserted")

# check content of Station table
query_stmt = "SELECT * FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)



#####################
# Sensor table    
data_sensors = list(csv.DictReader(open('Sensors.csv')))

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Sensor(sensor,description,metric)
                      VALUES (%(sensor)s, %(description)s, %(metric)s)"""

for row in data_sensors:
    pgexec (conn, insert_stmt, row, "sensor inserted")

# check content of Station table
query_stmt = "SELECT * FROM Sensor"
print(query_stmt)
pgquery (conn, query_stmt, None)


#####################
# Measurement table    
data_measurements = list(csv.DictReader(open('Measurements.csv')))

# the following converts the two measurment  columns to float  values - or NaN
clean(data_measurements, 'Discharge', float, DEFAULT_VALUE)
clean(data_measurements, 'MeanDischarge', float, DEFAULT_VALUE)
clean(data_measurements, 'Level', float, DEFAULT_VALUE)
clean(data_measurements, 'Temp', float, DEFAULT_VALUE)
clean(data_measurements, 'EC', float, DEFAULT_VALUE)

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,sensor,value)
                      VALUES (%(station)s, %(date)s, %(sensor)s, %(value)s)"""

measurementData = dict()
sensorCodes = ['levl', 'disvol','disc','temp', 'ec']
sensor_columns = ['Level', 'MeanDischarge', 'Discharge','Temp', 'EC']
for row in data_measurements:
    measurementData['station'] = row['Station']
    measurementData['date'] = row['Date']
    for i in range(len(sensorCodes)):
        if(np.isnan(row[sensor_columns[i]])):
            continue;
        measurementData['sensor'] = sensorCodes[i]
        measurementData['value']  = row[sensor_columns[i]]
        pgexec (conn, insert_stmt, measurementData, "measurement inserted")
    

# check content of Measurement table
query_stmt = "SELECT * FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)

query_stmt = "SELECT count(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)
conn.close();
# Out:
# connected
# SELECT COUNT(*) FROM Organisation
# (0,)
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# SELECT * FROM Station
# ('409001', 'Murray River at Albury (Union Bridge)', datetime.date(1892, 4, 14), 'DWR')
# ('409002', 'Murray River at Corowa', datetime.date(1894, 4, 1), 'DWR')
# ('409003', 'Murray River at Denuquin', datetime.date(1896, 9, 1), 'DWR')
# ('409005', 'Murray River at Barham', datetime.date(1900, 12, 31), 'DWR')
# ('409204C', 'Murray River @ Swan Hill', datetime.date(1904, 12, 31), 'VRW')
# ('409017', 'Murray River @ Doctors Point', datetime.date(1925, 8, 22), 'DWR')
# ('409019', 'Wakool River at Offtake Regulator', datetime.date(1931, 2, 7), 'DWR')
# ('409202', 'Murray River @ Tocumwal', datetime.date(1886, 6, 6), 'VRW')
# ('219018', 'Murray River @ Quaama', datetime.date(1962, 11, 7), 'DWR')
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# SELECT * FROM Sensor
# ('levl', 'Level - Stream Water (Gauge Height)', 'meter')
# ('temp', 'Water Temperature', 'celsius')
# ('disc', 'Discharge Rate', 'ML/d')
# ('disvol', 'Discharge Volume', 'ML')
# ('ph', 'pH Value', 'pH')
# ('ec25', 'Electrical Conductivity @25 C', 'us/cm')
# ('ec', 'Electrical Conductivity (uncorrected)', 'us/cm')
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# ...
# ('219018', datetime.date(2005, 4, 28), 'levl', 0.188)
# ('219018', datetime.date(2005, 4, 28), 'disvol', 0.612)
# ('219018', datetime.date(2005, 4, 28), 'disc', 0.625)
# ('409017', datetime.date(2005, 4, 28), 'levl', 1.615)
# ('409017', datetime.date(2005, 4, 28), 'disvol', 1758.802)
# ('409017', datetime.date(2005, 4, 28), 'disc', 1676.276)
# ('409017', datetime.date(2005, 4, 28), 'temp', 13.436)
# ('409017', datetime.date(2005, 4, 28), 'ec', 40.844)
# ('409204C', datetime.date(2005, 4, 29), 'levl', 0.692)
# ('409204C', datetime.date(2005, 4, 29), 'disvol', 2689.099)
# ('409204C', datetime.date(2005, 4, 29), 'disc', 2724.934)
# ('409204C', datetime.date(2005, 4, 29), 'temp', 14.317)
# ('409204C', datetime.date(2005, 4, 29), 'ec', 41.25)
# ('219018', datetime.date(2005, 4, 29), 'levl', 0.19)
# ('219018', datetime.date(2005, 4, 29), 'disvol', 0.658)
# ('219018', datetime.date(2005, 4, 29), 'disc', 0.703)
# ('409017', datetime.date(2005, 4, 29), 'levl', 1.574)
# ('409017', datetime.date(2005, 4, 29), 'disvol', 1577.205)
# ('409017', datetime.date(2005, 4, 29), 'disc', 1509.18)
# ('409017', datetime.date(2005, 4, 29), 'temp', 12.341)
# ('409017', datetime.date(2005, 4, 29), 'ec', 37.0)
# ('409204C', datetime.date(2005, 4, 30), 'levl', 0.694)
# ('409204C', datetime.date(2005, 4, 30), 'disvol', 2698.293)
# ('409204C', datetime.date(2005, 4, 30), 'disc', 2709.609)
# ('409204C', datetime.date(2005, 4, 30), 'temp', 14.056)
# ('409204C', datetime.date(2005, 4, 30), 'ec', 39.042)
# ('219018', datetime.date(2005, 4, 30), 'levl', 0.191)
# ('219018', datetime.date(2005, 4, 30), 'disvol', 0.697)
# ('219018', datetime.date(2005, 4, 30), 'disc', 0.655)
# ('409017', datetime.date(2005, 4, 30), 'levl', 1.555)
# ('409017', datetime.date(2005, 4, 30), 'disvol', 1495.291)
# ('409017', datetime.date(2005, 4, 30), 'disc', 1356.156)
# ('409017', datetime.date(2005, 4, 30), 'temp', 11.939)
# ('409017', datetime.date(2005, 4, 30), 'ec', 32.401)
# ('409204C', datetime.date(2005, 5, 1), 'levl', 0.694)
# ('409204C', datetime.date(2005, 5, 1), 'disvol', 2697.464)
# ('409204C', datetime.date(2005, 5, 1), 'disc', 2699.206)
# ('409204C', datetime.date(2005, 5, 1), 'temp', 14.35)
# ('409204C', datetime.date(2005, 5, 1), 'ec', 39.917)
# ('219018', datetime.date(2005, 5, 1), 'levl', 0.182)
# ('219018', datetime.date(2005, 5, 1), 'disvol', 0.477)
# ('219018', datetime.date(2005, 5, 1), 'disc', 0.403)
# ('409017', datetime.date(2005, 5, 1), 'levl', 1.502)
# ('409017', datetime.date(2005, 5, 1), 'disvol', 1279.157)
# ('409017', datetime.date(2005, 5, 1), 'disc', 1332.366)
# ('409017', datetime.date(2005, 5, 1), 'temp', 11.841)
# ('409017', datetime.date(2005, 5, 1), 'ec', 32.938)
# ('409204C', datetime.date(2005, 5, 2), 'levl', 0.693)
# ('409204C', datetime.date(2005, 5, 2), 'disvol', 2694.377)
# ('409204C', datetime.date(2005, 5, 2), 'disc', 2651.866)
# ('409204C', datetime.date(2005, 5, 2), 'temp', 14.642)
# ('409204C', datetime.date(2005, 5, 2), 'ec', 41.25)
# ('219018', datetime.date(2005, 5, 2), 'levl', 0.185)
# ('219018', datetime.date(2005, 5, 2), 'disvol', 0.532)
# ('219018', datetime.date(2005, 5, 2), 'disc', 0.545)
# ('409017', datetime.date(2005, 5, 2), 'levl', 1.52)
# ('409017', datetime.date(2005, 5, 2), 'disvol', 1346.752)
# ('409017', datetime.date(2005, 5, 2), 'disc', 1300.959)
# ('409017', datetime.date(2005, 5, 2), 'temp', 12.494)
# ('409017', datetime.date(2005, 5, 2), 'ec', 35.896)
# ('409204C', datetime.date(2005, 5, 3), 'levl', 0.67)
# ('409204C', datetime.date(2005, 5, 3), 'disvol', 2568.416)
# ('409204C', datetime.date(2005, 5, 3), 'disc', 2529.784)
# ('409204C', datetime.date(2005, 5, 3), 'temp', 14.453)
# ('409204C', datetime.date(2005, 5, 3), 'ec', 40.552)
# ('219018', datetime.date(2005, 5, 3), 'levl', 0.186)
# ('219018', datetime.date(2005, 5, 3), 'disvol', 0.545)
# ('219018', datetime.date(2005, 5, 3), 'disc', 0.545)
# ('409017', datetime.date(2005, 5, 3), 'levl', 1.486)
# ('409017', datetime.date(2005, 5, 3), 'disvol', 1218.943)
# ('409017', datetime.date(2005, 5, 3), 'disc', 1203.015)
# ('409017', datetime.date(2005, 5, 3), 'temp', 12.777)
# ('409017', datetime.date(2005, 5, 3), 'ec', 38.563)
# ('409204C', datetime.date(2005, 5, 4), 'levl', 0.653)
# ('409204C', datetime.date(2005, 5, 4), 'disvol', 2469.567)
# ('409204C', datetime.date(2005, 5, 4), 'disc', 2446.629)
# ('409204C', datetime.date(2005, 5, 4), 'temp', 14.483)
# ('409204C', datetime.date(2005, 5, 4), 'ec', 40.75)
# ('219018', datetime.date(2005, 5, 4), 'levl', 0.187)
# ('219018', datetime.date(2005, 5, 4), 'disvol', 0.561)
# ('219018', datetime.date(2005, 5, 4), 'disc', 0.588)
# ('409017', datetime.date(2005, 5, 4), 'levl', 1.48)
# ('409017', datetime.date(2005, 5, 4), 'disvol', 1195.763)
# ('409017', datetime.date(2005, 5, 4), 'disc', 1166.714)
# ('409017', datetime.date(2005, 5, 4), 'temp', 12.99)
# ('409017', datetime.date(2005, 5, 4), 'ec', 41.0)
# ('409204C', datetime.date(2005, 5, 5), 'levl', 0.644)
# ('409204C', datetime.date(2005, 5, 5), 'disvol', 2415.753)
# ('409204C', datetime.date(2005, 5, 5), 'disc', 2409.639)
# ('409204C', datetime.date(2005, 5, 5), 'temp', 14.373)
# ('409204C', datetime.date(2005, 5, 5), 'ec', 39.479)
# ('219018', datetime.date(2005, 5, 5), 'levl', 0.189)
# ('219018', datetime.date(2005, 5, 5), 'disvol', 0.644)
# ('219018', datetime.date(2005, 5, 5), 'disc', 0.719)
# ('409017', datetime.date(2005, 5, 5), 'levl', 1.47)
# ('409017', datetime.date(2005, 5, 5), 'disvol', 1158.526)
# ('409017', datetime.date(2005, 5, 5), 'disc', 1141.872)
# ('409017', datetime.date(2005, 5, 5), 'temp', 13.06)
# ('409017', datetime.date(2005, 5, 5), 'ec', 41.813)
# ('409204C', datetime.date(2005, 5, 6), 'levl', 0.641)
# ('409204C', datetime.date(2005, 5, 6), 'disvol', 2394.94)
# ('409204C', datetime.date(2005, 5, 6), 'disc', 2384.377)
# ('409204C', datetime.date(2005, 5, 6), 'temp', 14.25)
# ('409204C', datetime.date(2005, 5, 6), 'ec', 39.0)
# ('219018', datetime.date(2005, 5, 6), 'levl', 0.193)
# ('219018', datetime.date(2005, 5, 6), 'disvol', 0.746)
# ('219018', datetime.date(2005, 5, 6), 'disc', 0.735)
# ('409017', datetime.date(2005, 5, 6), 'levl', 1.471)
# ('409017', datetime.date(2005, 5, 6), 'disvol', 1161.829)
# ('409017', datetime.date(2005, 5, 6), 'disc', 1281.528)
# ('409017', datetime.date(2005, 5, 6), 'temp', 13.165)
# ('409017', datetime.date(2005, 5, 6), 'ec', 42.854)
# ('409204C', datetime.date(2005, 5, 7), 'levl', 0.634)
# ('409204C', datetime.date(2005, 5, 7), 'disvol', 2348.499)
# ('409204C', datetime.date(2005, 5, 7), 'disc', 2292.12)
# ('409204C', datetime.date(2005, 5, 7), 'temp', 14.05)
# ('409204C', datetime.date(2005, 5, 7), 'ec', 38.083)
# ('219018', datetime.date(2005, 5, 7), 'levl', 0.192)
# ('219018', datetime.date(2005, 5, 7), 'disvol', 0.728)
# ('219018', datetime.date(2005, 5, 7), 'disc', 0.727)
# ('409017', datetime.date(2005, 5, 7), 'levl', 1.524)
# ('409017', datetime.date(2005, 5, 7), 'disvol', 1365.544)
# ('409017', datetime.date(2005, 5, 7), 'disc', 1388.599)
# ('409017', datetime.date(2005, 5, 7), 'temp', 13.127)
# ('409017', datetime.date(2005, 5, 7), 'ec', 43.396)
# ('409204C', datetime.date(2005, 5, 8), 'levl', 0.617)
# ('409204C', datetime.date(2005, 5, 8), 'disvol', 2233.26)
# ('409204C', datetime.date(2005, 5, 8), 'disc', 2185.795)
# ('409204C', datetime.date(2005, 5, 8), 'temp', 14.019)
# ('409204C', datetime.date(2005, 5, 8), 'ec', 37.385)
# ('409017', datetime.date(2005, 5, 8), 'levl', 1.507)
# ('409017', datetime.date(2005, 5, 8), 'disvol', 1298.944)
# ('409017', datetime.date(2005, 5, 8), 'disc', 1072.179)
# ('409017', datetime.date(2005, 5, 8), 'temp', 13.105)
# ('409017', datetime.date(2005, 5, 8), 'ec', 43.578)
# ('409204C', datetime.date(2005, 5, 9), 'levl', 0.588)
# ('409204C', datetime.date(2005, 5, 9), 'disvol', 2099.64)
# ('409204C', datetime.date(2005, 5, 9), 'disc', 2060.874)
# ('409204C', datetime.date(2005, 5, 9), 'temp', 14.15)
# ('409204C', datetime.date(2005, 5, 9), 'ec', 37.76)
# ('219018', datetime.date(2005, 5, 9), 'disc', 0.801)
# ('409017', datetime.date(2005, 5, 9), 'levl', 1.472)
# ('409017', datetime.date(2005, 5, 9), 'disvol', 1166.936)
# ('409017', datetime.date(2005, 5, 9), 'disc', 1225.026)
# ('409017', datetime.date(2005, 5, 9), 'temp', 12.873)
# ('409017', datetime.date(2005, 5, 9), 'ec', 42.333)
# ('409204C', datetime.date(2005, 5, 10), 'levl', 0.555)
# ('409204C', datetime.date(2005, 5, 10), 'disvol', 2023.948)
# ('409204C', datetime.date(2005, 5, 10), 'disc', 1994.499)
# ('409204C', datetime.date(2005, 5, 10), 'temp', 14.104)
# ('409204C', datetime.date(2005, 5, 10), 'ec', 38.385)
# ('219018', datetime.date(2005, 5, 10), 'levl', 0.196)
# ('219018', datetime.date(2005, 5, 10), 'disvol', 0.852)
# ('219018', datetime.date(2005, 5, 10), 'disc', 0.794)
# ('409017', datetime.date(2005, 5, 10), 'levl', 1.494)
# ('409017', datetime.date(2005, 5, 10), 'disvol', 1246.048)
# ('409017', datetime.date(2005, 5, 10), 'disc', 1192.099)
# ('409017', datetime.date(2005, 5, 10), 'temp', 12.998)
# ('409017', datetime.date(2005, 5, 10), 'ec', 40.958)
# ('409204C', datetime.date(2005, 5, 11), 'levl', 0.534)
# ('409204C', datetime.date(2005, 5, 11), 'disvol', 1958.392)
# ('409204C', datetime.date(2005, 5, 11), 'disc', 1959.86)
# ('409204C', datetime.date(2005, 5, 11), 'temp', 14.054)
# ('409204C', datetime.date(2005, 5, 11), 'ec', 38.646)
# ('219018', datetime.date(2005, 5, 11), 'levl', 0.191)
# ('219018', datetime.date(2005, 5, 11), 'disvol', 0.705)
# ('219018', datetime.date(2005, 5, 11), 'disc', 0.903)
# ('409017', datetime.date(2005, 5, 11), 'levl', 1.473)
# ('409017', datetime.date(2005, 5, 11), 'disvol', 1168.779)
# ('409017', datetime.date(2005, 5, 11), 'disc', 1192.099)
# ('409017', datetime.date(2005, 5, 11), 'temp', 12.958)
# ('409017', datetime.date(2005, 5, 11), 'ec', 40.958)
# ('409204C', datetime.date(2005, 5, 12), 'levl', 0.538)
# ('409204C', datetime.date(2005, 5, 12), 'disvol', 1975.382)
# ('409204C', datetime.date(2005, 5, 12), 'disc', 1991.358)
# ('409204C', datetime.date(2005, 5, 12), 'temp', 14.017)
# ('409204C', datetime.date(2005, 5, 12), 'ec', 38.667)
# ('219018', datetime.date(2005, 5, 12), 'levl', 0.193)
# ('219018', datetime.date(2005, 5, 12), 'disvol', 0.772)
# ('219018', datetime.date(2005, 5, 12), 'disc', 0.925)
# ('409017', datetime.date(2005, 5, 12), 'levl', 1.486)
# ('409017', datetime.date(2005, 5, 12), 'disvol', 1219.034)
# ('409017', datetime.date(2005, 5, 12), 'disc', 1217.812)
# ('409017', datetime.date(2005, 5, 12), 'temp', 12.877)
# ('409017', datetime.date(2005, 5, 12), 'ec', 40.771)
# ('409204C', datetime.date(2005, 5, 13), 'levl', 0.546)
# ('409204C', datetime.date(2005, 5, 13), 'disvol', 2000.689)
# ('409204C', datetime.date(2005, 5, 13), 'disc', 2011.907)
# ('409204C', datetime.date(2005, 5, 13), 'temp', 13.792)
# ('409204C', datetime.date(2005, 5, 13), 'ec', 38.5)
# ('219018', datetime.date(2005, 5, 13), 'levl', 0.193)
# ('219018', datetime.date(2005, 5, 13), 'disvol', 0.753)
# ('219018', datetime.date(2005, 5, 13), 'disc', 0.812)
# ('409017', datetime.date(2005, 5, 13), 'levl', 1.484)
# ('409017', datetime.date(2005, 5, 13), 'disvol', 1212.056)
# ('409017', datetime.date(2005, 5, 13), 'disc', 1217.812)
# ('409017', datetime.date(2005, 5, 13), 'temp', 12.571)
# ('409017', datetime.date(2005, 5, 13), 'ec', 40.583)
# ('409204C', datetime.date(2005, 5, 14), 'levl', 0.553)
# ('409204C', datetime.date(2005, 5, 14), 'disvol', 2018.924)
# ('409204C', datetime.date(2005, 5, 14), 'disc', 2043.983)
# ('409204C', datetime.date(2005, 5, 14), 'temp', 13.757)
# ('409204C', datetime.date(2005, 5, 14), 'ec', 45.438)
# ('409017', datetime.date(2005, 5, 14), 'levl', 1.487)
# ('409017', datetime.date(2005, 5, 14), 'disvol', 1222.575)
# ('409017', datetime.date(2005, 5, 14), 'disc', 1228.869)
# ('409017', datetime.date(2005, 5, 14), 'temp', 12.677)
# ('409017', datetime.date(2005, 5, 14), 'ec', 40.104)
# ('409204C', datetime.date(2005, 5, 15), 'levl', 0.577)
# ('409204C', datetime.date(2005, 5, 15), 'disvol', 2072.097)
# ('409204C', datetime.date(2005, 5, 15), 'disc', 2094.728)
# ('409204C', datetime.date(2005, 5, 15), 'temp', 13.851)
# ('409204C', datetime.date(2005, 5, 15), 'ec', 38.01)
# ('409017', datetime.date(2005, 5, 15), 'levl', 1.492)
# ('409017', datetime.date(2005, 5, 15), 'disvol', 1239.378)
# ('409017', datetime.date(2005, 5, 15), 'disc', 1251.162)
# ('409017', datetime.date(2005, 5, 15), 'temp', 12.888)
# ('409017', datetime.date(2005, 5, 15), 'ec', 40.75)
# ('409204C', datetime.date(2005, 5, 16), 'levl', 0.604)
# ('409204C', datetime.date(2005, 5, 16), 'disvol', 2153.007)
# ('409204C', datetime.date(2005, 5, 16), 'disc', 2312.337)
# ('409204C', datetime.date(2005, 5, 16), 'temp', 14.198)
# ('409204C', datetime.date(2005, 5, 16), 'ec', 39.729)
# ('409017', datetime.date(2005, 5, 16), 'levl', 1.471)
# ('409017', datetime.date(2005, 5, 16), 'disvol', 1170.961)
# ('409017', datetime.date(2005, 5, 16), 'disc', 895.048)
# ('409017', datetime.date(2005, 5, 16), 'temp', 13.187)
# ('409017', datetime.date(2005, 5, 16), 'ec', 41.469)
# ('409204C', datetime.date(2005, 5, 17), 'levl', 0.66)
# ('409204C', datetime.date(2005, 5, 17), 'disvol', 2508.258)
# ('409204C', datetime.date(2005, 5, 17), 'disc', 2678.357)
# ('409204C', datetime.date(2005, 5, 17), 'temp', 13.862)
# ('409204C', datetime.date(2005, 5, 17), 'ec', 39.063)
# ('409017', datetime.date(2005, 5, 17), 'levl', 1.537)
# ('409017', datetime.date(2005, 5, 17), 'disvol', 1485.14)
# ('409017', datetime.date(2005, 5, 17), 'disc', 1979.05)
# ('409017', datetime.date(2005, 5, 17), 'temp', 11.971)
# ('409017', datetime.date(2005, 5, 17), 'ec', 37.385)
# ('409204C', datetime.date(2005, 5, 18), 'levl', 0.705)
# ('409204C', datetime.date(2005, 5, 18), 'disvol', 2771.722)
# ('409204C', datetime.date(2005, 5, 18), 'disc', 2824.684)
# ('409204C', datetime.date(2005, 5, 18), 'temp', 13.815)
# ('409204C', datetime.date(2005, 5, 18), 'ec', 38.708)
# ('409017', datetime.date(2005, 5, 18), 'levl', 1.597)
# ('409017', datetime.date(2005, 5, 18), 'disvol', 1681.742)
# ('409017', datetime.date(2005, 5, 18), 'disc', 1376.256)
# ('409017', datetime.date(2005, 5, 18), 'temp', 11.011)
# ('409017', datetime.date(2005, 5, 18), 'ec', 31.115)
# ('409204C', datetime.date(2005, 5, 19), 'levl', 0.713)
# ('409204C', datetime.date(2005, 5, 19), 'disvol', 2827.017)
# ('409204C', datetime.date(2005, 5, 19), 'disc', 2824.684)
# ('409204C', datetime.date(2005, 5, 19), 'temp', 13.85)
# ('409204C', datetime.date(2005, 5, 19), 'ec', 39.5)
# ('409017', datetime.date(2005, 5, 19), 'levl', 1.489)
# ('409017', datetime.date(2005, 5, 19), 'disvol', 1229.131)
# ('409017', datetime.date(2005, 5, 19), 'disc', 1141.872)
# ('409017', datetime.date(2005, 5, 19), 'temp', 10.983)
# ('409017', datetime.date(2005, 5, 19), 'ec', 30.646)
# ('409204C', datetime.date(2005, 5, 20), 'levl', 0.716)
# ('409204C', datetime.date(2005, 5, 20), 'disvol', 2844.83)
# ('409204C', datetime.date(2005, 5, 20), 'disc', 2881.561)
# ('409204C', datetime.date(2005, 5, 20), 'temp', 14.058)
# ('409204C', datetime.date(2005, 5, 20), 'ec', 41.75)
# ('409017', datetime.date(2005, 5, 20), 'levl', 1.48)
# ('409017', datetime.date(2005, 5, 20), 'disvol', 1196.098)
# ('409017', datetime.date(2005, 5, 20), 'disc', 1225.026)
# ('409017', datetime.date(2005, 5, 20), 'temp', 11.454)
# ('409017', datetime.date(2005, 5, 20), 'ec', 32.125)
# ('409204C', datetime.date(2005, 5, 21), 'levl', 0.731)
# ('409204C', datetime.date(2005, 5, 21), 'disvol', 2951.734)
# ('409204C', datetime.date(2005, 5, 21), 'disc', 3033.432)
# ('409204C', datetime.date(2005, 5, 21), 'temp', 14.04)
# ('409204C', datetime.date(2005, 5, 21), 'ec', 41.813)
# ('409017', datetime.date(2005, 5, 21), 'levl', 1.488)
# ('409017', datetime.date(2005, 5, 21), 'disvol', 1227.102)
# ('409017', datetime.date(2005, 5, 21), 'disc', 1266.311)
# ('409017', datetime.date(2005, 5, 21), 'temp', 11.583)
# ('409017', datetime.date(2005, 5, 21), 'ec', 32.813)
# ('409204C', datetime.date(2005, 5, 22), 'levl', 0.756)
# ('409204C', datetime.date(2005, 5, 22), 'disvol', 3121.649)
# ('409204C', datetime.date(2005, 5, 22), 'disc', 3230.753)
# ('409204C', datetime.date(2005, 5, 22), 'temp', 13.95)
# ('409204C', datetime.date(2005, 5, 22), 'ec', 42.521)
# ('409017', datetime.date(2005, 5, 22), 'levl', 1.5)
# ('409017', datetime.date(2005, 5, 22), 'disvol', 1269.301)
# ('409017', datetime.date(2005, 5, 22), 'disc', 1254.824)
# ('409017', datetime.date(2005, 5, 22), 'temp', 11.585)
# ('409017', datetime.date(2005, 5, 22), 'ec', 32.271)
# SELECT count(*) FROM Measurement
# (1793,)

# %% [markdown]
# # End of Tutorial. Many Thanks.
